# %% [markdown]
# https://stackabuse.com/python-for-nlp-getting-started-with-the-stanfordcorenlp-library/ <br>
# https://github.com/Lynten/stanford-corenlp

# %%
from stanfordcorenlp import StanfordCoreNLP
import logging
import json
import pandas as pd
# from nltk.parse.stanford import StanfordDependencyParser
import os

from graphviz import Source

# %%
class StanfordNLP:
    def __init__(self, host='http://localhost', port=9000):
        self.nlp = StanfordCoreNLP(host, port=port,
                                   timeout=30000)  # , quiet=False, logging_level=logging.DEBUG)
        self.props = {
            'annotators': 'tokenize,ssplit,pos,lemma,ner,parse,depparse,dcoref,relation',
            'pipelineLanguage': 'en',
            'outputFormat': 'json'
        }

    def word_tokenize(self, sentence):
        return self.nlp.word_tokenize(sentence)

    def pos(self, sentence):
        return self.nlp.pos_tag(sentence)

    def ner(self, sentence):
        return self.nlp.ner(sentence)

    def parse(self, sentence):
        return self.nlp.parse(sentence)

    def dependency_parse(self, sentence):
        return self.nlp.dependency_parse(sentence)

    def annotate(self, sentence):
        return json.loads(self.nlp.annotate(sentence, properties=self.props))

    @staticmethod
    def tokens_to_dict(_tokens):
        tokens = defaultdict(dict)
        for token in _tokens:
            tokens[int(token['index'])] = {
                'word': token['word'],
                'lemma': token['lemma'],
                'pos': token['pos'],
                'ner': token['ner']
            }
        return tokens

# %%
df = pd.read_csv('newsdataset1.csv')
df.event_summary=df.event_summary.astype(str)

# %%
df['event_summary'].str.replace('(','').astype(str)
df['event_summary'].str.replace(')','').astype(str)
df['event_summary'].str.replace('[','').astype(str)
df['event_summary'].str.replace(']','').astype(str)
df['event_summary'].str.replace('"','').astype(str)
df['event_summary'].str.replace('’','').astype(str)
# Out:
# 0             The death toll of the suicide bombing in Ibb
# 1        A shooting kills one and injures six people in...
# 2        Lithuania adopts the euro as its official curr...
# 3        U.S. fast-food restaurant chain Chick-fil-A wa...
# 4        The Palestine Authority signs a treaty to join...
# 5               The Eurasian Economic Union between Russia
# 6               Vietnams new marriage law goes into effect
# 7                                              Mario Cuomo
# 8        Somali al-Shabaab militants attack an army bas...
# 9                Boko Haram militants attack a bus in Waza
# 10                                        Abu Anas al-Libi
# 11       The MS Norman Atlantic ferry fire death toll r...
# 12       The United States enacts more sanctions on Nor...
# 13       Fleeing villagers from a remote part of the Bo...
# 14       Turkey permits the building of a Syriac church...
# 15       The Singapore-registered cargo ship MV Höegh O...
# 16                                         MS Bulk Jupiter
# 17       The Cypriot-registered cargo ship Cemfjord sin...
# 18                                      A prison in Bruges
# 19                                        _January_2015"]"
# 20       A U.S. drone strike kills eight Uzbek people c...
# 21                                                     nan
# 22                                          /wiki/Al-Qaeda
# 23       A vehicle carrying United Nations peacekeepers...
# 24       A bombing at a local Houthi movement headquart...
# 25       A suicide car bomber detonates near a military...
# 26                A six-story building collapse in Nairobi
# 27       Pope Francis announces the appointment of 20 n...
# 28                                                In darts
# 29       A Libyan warplane bombs a Greek-operated oil t...
#                                ...
# 12787                                             _2017"]"
# 12788    California moves its 2020 presidential primary...
# 12789                                             Facebook
# 12790                         The University of Louisville
# 12791    The Islamic State of Iraq and the Levant relea...
# 12792                                   Whole Foods Market
# 12793                              /wiki/Hurricane_Maria]"
# 12794                                        More than 134
# 12795                          At least 14 Rohingya people
# 12796                                             _2017"]"
# 12797                                             _2017"]"
# 12798    Aquatic species from Japan hitched a ride on d...
# 12799    Al-Shabaab militants attack a military base ou...
# 12800    At least 22 people are killed and over 30 are ...
# 12801    A Mexico City borough president says previous ...
# 12802                                             _2017"]"
# 12803    The U.S. State Department removes all families...
# 12804                                             _2017"]"
# 12805    Tom Price resigns as the Secretary of Health a...
# 12806    Sun Zhengcai is expelled from the Communist Pa...
# 12807    /wiki/Central_Commission_for_Discipline_Inspec...
# 12808    The journal Protein & Cell publishes Sun Yat-s...
# 12809                                          In Edmonton
# 12810             A fire at a retirement home in Bucharest
# 12811    A military transport plane crashes after take-...
# 12812    A crowd surge collapses a barrier during a soc...
# 12813    /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814    Tens of thousands of protesters march through ...
# 12815    About 600 members of the Swedish neo-Nazi grou...
# 12816    The Australian rules football club Richmond Fo...
# Name: event_summary, Length: 12817, dtype: object

# %%
# for i in range(0,30):
#     df=df.drop([df['event_summary'].map(len)==i])
# #     df=df.drop(df[df['event_summary']=='nan'].index)
# #     df=df.drop(df[df['event_summary']=='Vietnam’s new marriage law goes into effect'].index)
# # #     print("yes")




indexes=df[df['event_summary'].map(len)  < 35].index
# print(indexes)
df=df.drop(indexes)
index2=df[df['event_summary']=='nan'].index
df=df.drop(index2)

# %%
df=df.reset_index()

# %%
df['event_summary']
# Out:
# 0            The death toll of the suicide bombing in Ibb
# 1       A shooting kills one and injures six people in...
# 2       Lithuania adopts the euro as its official curr...
# 3       U.S. fast-food restaurant chain Chick-fil-A wa...
# 4       The Palestine Authority signs a treaty to join...
# 5              The Eurasian Economic Union between Russia
# 6             Vietnam’s new marriage law goes into effect
# 7       Somali al-Shabaab militants attack an army bas...
# 8               Boko Haram militants attack a bus in Waza
# 9       The MS Norman Atlantic ferry fire death toll r...
# 10      The United States enacts more sanctions on Nor...
# 11      Fleeing villagers from a remote part of the Bo...
# 12      Turkey permits the building of a Syriac church...
# 13      The Singapore-registered cargo ship MV Höegh O...
# 14      The Cypriot-registered cargo ship Cemfjord sin...
# 15      A U.S. drone strike kills eight Uzbek people c...
# 16      A vehicle carrying United Nations peacekeepers...
# 17      A bombing at a local Houthi movement headquart...
# 18      A suicide car bomber detonates near a military...
# 19               A six-story building collapse in Nairobi
# 20      Pope Francis announces the appointment of 20 n...
# 21      A Libyan warplane bombs a Greek-operated oil t...
# 22      News emerges that two days prior hundreds of B...
# 23      Bangladeshi police report that two opposition ...
# 24      A suicide car bomber hits the headquarters of ...
# 25      A Czech archaeological team discovers the tomb...
# 26               The site where Jesus may have been tried
# 27      China relaxes controls over the export of rare...
# 28      Ireland becomes the first European nation to b...
# 29      For the second day in a row a multi-story resi...
#                               ...
# 9457    Russian President Vladimir Putin dismisses Niz...
# 9458    Acting U.S. Drug Enforcement Administration ch...
# 9459    Africa's Great Green Wall is successfully reve...
# 9460    Russian aircraft carry out air strikes on the ...
# 9461     and causing large number of civilians to flee...
# 9462    Russia announces it has completed the destruct...
# 9463    Thirty thousand people are evacuated from Kaly...
# 9464    /wiki/United_States_Department_of_Homeland_Sec...
# 9465    Uzbekistan dissident writer Nurulloh Muhammad ...
# 9466    Former Thai Prime Minister Yingluck Shinawatra...
# 9467    The Republic of Ireland announces a referendum...
# 9468    https://www.bbc.com/news/world-middle-east-414...
# 9469    California moves its 2020 presidential primary...
# 9470    The Islamic State of Iraq and the Levant relea...
# 9471    Aquatic species from Japan hitched a ride on d...
# 9472    Al-Shabaab militants attack a military base ou...
# 9473    At least 22 people are killed and over 30 are ...
# 9474    A Mexico City borough president says previous ...
# 9475    The U.S. State Department removes all families...
# 9476    Tom Price resigns as the Secretary of Health a...
# 9477    Sun Zhengcai is expelled from the Communist Pa...
# 9478    /wiki/Central_Commission_for_Discipline_Inspec...
# 9479    The journal Protein & Cell publishes Sun Yat-s...
# 9480             A fire at a retirement home in Bucharest
# 9481    A military transport plane crashes after take-...
# 9482    A crowd surge collapses a barrier during a soc...
# 9483    /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 9484    Tens of thousands of protesters march through ...
# 9485    About 600 members of the Swedish neo-Nazi grou...
# 9486    The Australian rules football club Richmond Fo...
# Name: event_summary, Length: 9487, dtype: object

# %%
df['event_summary'][1]
# Out:
# 'A shooting kills one and injures six people in Killarney'

# %%
from nltk.parse.corenlp import CoreNLPParser
from nltk.parse.stanford import StanfordDependencyParser

# %% [markdown]
# https://towardsdatascience.com/a-practitioners-guide-to-natural-language-processing-part-i-processing-understanding-text-9f4abfd13e72

# %%
if __name__ == '__main__':
    sNLP = StanfordNLP()
    for i in range(0, 100):
        print(i)
        text = df['event_summary'][i]
#         print ("Annotate:", sNLP.annotate(text))
        print('\n\n')
        print(text)
        print('\n\n')
        print ("POS:", sNLP.pos(text))
        print('\n\n')
        print ("Tokens:", sNLP.word_tokenize(text))
        print('\n\n')
        print ("NER:", sNLP.ner(text))
        print('\n\n')
        print ("Parse:", sNLP.parse(text))
#         print ("Dep Parse:", sNLP.dependency_parse(text))
        sentence=sNLP.parse(text)
        parser = CoreNLPParser()
        next(parser.raw_parse(text)).pretty_print()
        
#         sdp =  StanfordDependencyParser()
#         next(sdp.raw_parse(text)).pretty_print()
#         result = list(sdp.raw_parse(text))

#         dep_tree_dot_repr = [parse for parse in result][0].to_dot()
#         source = Source(dep_tree_dot_repr, filename="dep_tree", format="png")
#         source.view()

        
        print('\n\n .......................................................................... \n\n')
# Out:
# 0
#
#
#
# The death toll of the suicide bombing in Ibb
#
#
#
# POS: [('The', 'DT'), ('death', 'NN'), ('toll', 'NN'), ('of', 'IN'), ('the', 'DT'), ('suicide', 'NN'), ('bombing', 'NN'), ('in', 'IN'), ('Ibb', 'NNP')]
#
#
#
# Tokens: ['The', 'death', 'toll', 'of', 'the', 'suicide', 'bombing', 'in', 'Ibb']
#
#
#
# NER: [('The', 'O'), ('death', 'O'), ('toll', 'O'), ('of', 'O'), ('the', 'O'), ('suicide', 'CRIMINAL_CHARGE'), ('bombing', 'CRIMINAL_CHARGE'), ('in', 'O'), ('Ibb', 'O')]
#
#
#
# Parse: (ROOT
#   (NP
#     (NP (DT The) (NN death))
#     (NP
#       (NP (NN toll))
#       (PP (IN of)
#         (NP
#           (NP (DT the) (NN suicide) (NN bombing))
#           (PP (IN in)
#             (NP (NNP Ibb))))))))
#          ROOT
#           |
#           NP
#       ____|_________
#      |              NP
#      |          ____|_________
#      |         |              PP
#      |         |     _________|_______
#      |         |    |                 NP
#      |         |    |          _______|_________
#      |         |    |         |                 PP
#      |         |    |         |              ___|___
#      NP        NP   |         NP            |       NP
#   ___|____     |    |    _____|_______      |       |
#  DT       NN   NN   IN  DT    NN      NN    IN     NNP
#  |        |    |    |   |     |       |     |       |
# The     death toll  of the suicide bombing  in     Ibb
#
#
#
#  ..........................................................................
#
#
# 1
#
#
#
# A shooting kills one and injures six people in Killarney
#
#
#
# POS: [('A', 'DT'), ('shooting', 'NN'), ('kills', 'VBZ'), ('one', 'CD'), ('and', 'CC'), ('injures', 'VBZ'), ('six', 'CD'), ('people', 'NNS'), ('in', 'IN'), ('Killarney', 'NNP')]
#
#
#
# Tokens: ['A', 'shooting', 'kills', 'one', 'and', 'injures', 'six', 'people', 'in', 'Killarney']
#
#
#
# NER: [('A', 'O'), ('shooting', 'CAUSE_OF_DEATH'), ('kills', 'O'), ('one', 'NUMBER'), ('and', 'O'), ('injures', 'O'), ('six', 'NUMBER'), ('people', 'O'), ('in', 'O'), ('Killarney', 'CITY')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT A) (NN shooting))
#     (VP
#       (VP (VBZ kills)
#         (NP (CD one)))
#       (CC and)
#       (VP (VBZ injures)
#         (NP
#           (NP (CD six) (NNS people))
#           (PP (IN in)
#             (NP (NNP Killarney))))))))
#                                ROOT
#                                 |
#                                 S
#       __________________________|______
#      |                                 VP
#      |                   ______________|______________
#      |                  |       |                     VP
#      |                  |       |       ______________|_____
#      |                  |       |      |                    NP
#      |                  |       |      |          __________|_______
#      |                  VP      |      |         |                  PP
#      |              ____|___    |      |         |               ___|______
#      NP            |        NP  |      |         NP             |          NP
#   ___|_____        |        |   |      |      ___|____          |          |
#  DT        NN     VBZ       CD  CC    VBZ    CD      NNS        IN        NNP
#  |         |       |        |   |      |     |        |         |          |
#  A      shooting kills     one and  injures six     people      in     Killarney
#
#
#
#  ..........................................................................
#
#
# 2
#
#
#
# Lithuania adopts the euro as its official currency
#
#
#
# POS: [('Lithuania', 'NNP'), ('adopts', 'VBZ'), ('the', 'DT'), ('euro', 'NN'), ('as', 'IN'), ('its', 'PRP$'), ('official', 'JJ'), ('currency', 'NN')]
#
#
#
# Tokens: ['Lithuania', 'adopts', 'the', 'euro', 'as', 'its', 'official', 'currency']
#
#
#
# NER: [('Lithuania', 'COUNTRY'), ('adopts', 'O'), ('the', 'O'), ('euro', 'O'), ('as', 'O'), ('its', 'O'), ('official', 'O'), ('currency', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Lithuania))
#     (VP (VBZ adopts)
#       (NP
#         (NP (DT the) (NN euro))
#         (PP (IN as)
#           (NP (PRP$ its) (JJ official) (NN currency)))))))
#            ROOT
#             |
#             S
#      _______|_____
#     |             VP
#     |        _____|____________
#     |       |                  NP
#     |       |          ________|________
#     |       |         |                 PP
#     |       |         |         ________|_____
#     NP      |         NP       |              NP
#     |       |      ___|___     |    __________|________
#    NNP     VBZ    DT      NN   IN PRP$        JJ       NN
#     |       |     |       |    |   |          |        |
# Lithuania adopts the     euro  as its      official currency
#
#
#
#  ..........................................................................
#
#
# 3
#
#
#
# U.S. fast-food restaurant chain Chick-fil-A warns that a security breach may have leaked credit card details of 9
#
#
#
# POS: [('U.S.', 'NNP'), ('fast-food', 'NN'), ('restaurant', 'NN'), ('chain', 'NN'), ('Chick-fil-A', 'NN'), ('warns', 'VBZ'), ('that', 'IN'), ('a', 'DT'), ('security', 'NN'), ('breach', 'NN'), ('may', 'MD'), ('have', 'VB'), ('leaked', 'VBN'), ('credit', 'NN'), ('card', 'NN'), ('details', 'NNS'), ('of', 'IN'), ('9', 'CD')]
#
#
#
# Tokens: ['U.S.', 'fast-food', 'restaurant', 'chain', 'Chick-fil-A', 'warns', 'that', 'a', 'security', 'breach', 'may', 'have', 'leaked', 'credit', 'card', 'details', 'of', '9']
#
#
#
# NER: [('U.S.', 'COUNTRY'), ('fast-food', 'O'), ('restaurant', 'O'), ('chain', 'O'), ('Chick-fil-A', 'ORGANIZATION'), ('warns', 'O'), ('that', 'O'), ('a', 'O'), ('security', 'O'), ('breach', 'O'), ('may', 'O'), ('have', 'O'), ('leaked', 'O'), ('credit', 'O'), ('card', 'O'), ('details', 'O'), ('of', 'O'), ('9', 'NUMBER')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (NNP U.S.) (NN fast-food) (NN restaurant) (NN chain))
#       (NP (NN Chick-fil-A)))
#     (VP (VBZ warns)
#       (SBAR (IN that)
#         (S
#           (NP (DT a) (NN security) (NN breach))
#           (VP (MD may)
#             (VP (VB have)
#               (VP (VBN leaked)
#                 (NP
#                   (NP (NN credit) (NN card) (NNS details))
#                   (PP (IN of)
#                     (NP (CD 9))))))))))))
#                                     ROOT
#                                      |
#                                      S
#                     _________________|_____________
#                    |                               VP
#                    |                           ____|____
#                    |                          |        SBAR
#                    |                          |     ____|______________
#                    |                          |    |                   S
#                    |                          |    |            _______|_________
#                    |                          |    |           |                 VP
#                    |                          |    |           |              ___|_____
#                    |                          |    |           |             |         VP
#                    |                          |    |           |             |    _____|____________
#                    |                          |    |           |             |   |                  VP
#                    |                          |    |           |             |   |      ____________|______
#                    |                          |    |           |             |   |     |                   NP
#                    |                          |    |           |             |   |     |             ______|_________
#                    NP                         |    |           |             |   |     |            |                PP
#           _________|_________________         |    |           |             |   |     |            |             ___|___
#          NP                          NP       |    |           NP            |   |     |            NP           |       NP
#   _______|__________________         |        |    |     ______|_______      |   |     |       _____|______      |       |
# NNP      NN        NN       NN       NN      VBZ   IN   DT     NN      NN    MD  VB   VBN     NN    NN    NNS    IN      CD
#  |       |         |        |        |        |    |    |      |       |     |   |     |      |     |      |     |       |
# U.S. fast-food restaurant chain Chick-fil-A warns that  a   security breach may have leaked credit card details  of      9
#
#
#
#  ..........................................................................
#
#
# 4
#
#
#
# The Palestine Authority signs a treaty to join and participate in the International Criminal Court. (Wall Street Journal)
#
#
#
# POS: [('The', 'DT'), ('Palestine', 'NNP'), ('Authority', 'NNP'), ('signs', 'NNS'), ('a', 'DT'), ('treaty', 'NN'), ('to', 'TO'), ('join', 'VB'), ('and', 'CC'), ('participate', 'VB'), ('in', 'IN'), ('the', 'DT'), ('International', 'NNP'), ('Criminal', 'NNP'), ('Court', 'NNP'), ('.', '.'), ('(', '-LRB-'), ('Wall', 'NNP'), ('Street', 'NNP'), ('Journal', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'Palestine', 'Authority', 'signs', 'a', 'treaty', 'to', 'join', 'and', 'participate', 'in', 'the', 'International', 'Criminal', 'Court', '.', '(', 'Wall', 'Street', 'Journal', ')']
# NER: [('The', 'O'), ('Palestine', 'ORGANIZATION'), ('Authority', 'ORGANIZATION'), ('signs', 'O'), ('a', 'O'), ('treaty', 'O'), ('to', 'O'), ('join', 'O'), ('and', 'O'), ('participate', 'O'), ('in', 'O'), ('the', 'O'), ('International', 'ORGANIZATION'), ('Criminal', 'ORGANIZATION'), ('Court', 'ORGANIZATION'), ('.', 'O'), ('(', 'O'), ('Wall', 'ORGANIZATION'), ('Street', 'ORGANIZATION'), ('Journal', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (NP
#     (NP
#       (NP (DT The) (NNP Palestine) (NNP Authority) (NNS signs))
#       (NP (DT a) (NN treaty)))
#     (SBAR
#       (S
#         (VP (TO to)
#           (VP (VB join)
#             (CC and)
#             (VB participate)
#             (PP (IN in)
#               (NP (DT the) (NNP International) (NNP Criminal) (NNP Court)))))))
#     (. .)))
#                                                                   ROOT
#                                                                    |
#                                                                    S
#          __________________________________________________________|_____________
#         |                                                                        VP
#         |                                                   _____________________|_______________________________________
#         |                                                  NP                                                            |
#         |                       ___________________________|_______                                                      |
#         |                      |    |                              S                                                     |
#         |                      |    |                              |                                                     |
#         |                      |    |                              VP                                                    |
#         |                      |    |      ________________________|____                                                 |
#         |                      |    |     |                             VP                                               |
#         |                      |    |     |    _________________________|________                                        |
#         |                      |    |     |   |    |       |                     PP                                     PRN
#         |                      |    |     |   |    |       |        _____________|__________                   __________|______________
#         NP                     |    |     |   |    |       |       |                        NP                |          NP             |
#   ______|_________________     |    |     |   |    |       |       |     ___________________|____________     |     _____|_______       |
#  DT    NNP       NNP     NNS   DT   NN    TO  VB   CC      VB      IN   DT      NNP        NNP     NNP   .  -LRB- NNP   NNP     NNP   -RRB-
#  |      |         |       |    |    |     |   |    |       |       |    |        |          |       |    |    |    |     |       |      |
# The Palestine Authority signs  a  treaty  to join and participate  in  the International Criminal Court  .  -LRB- Wall Street Journal -RRB-
#
#
#
#  ..........................................................................
#
#
# 5
#
#
#
# The Eurasian Economic Union between Russia
#
#
#
# POS: [('The', 'DT'), ('Eurasian', 'JJ'), ('Economic', 'NNP'), ('Union', 'NNP'), ('between', 'IN'), ('Russia', 'NNP')]
#
#
#
# Tokens: ['The', 'Eurasian', 'Economic', 'Union', 'between', 'Russia']
#
#
#
# NER: [('The', 'O'), ('Eurasian', 'O'), ('Economic', 'O'), ('Union', 'O'), ('between', 'O'), ('Russia', 'COUNTRY')]
#
#
#
# Parse: (ROOT
#   (FRAG
#     (NP (DT The) (JJ Eurasian) (NNP Economic) (NNP Union))
#     (PP (IN between)
#       (NP (NNP Russia)))))
#                ROOT
#                 |
#                FRAG
#         ________|____________________
#        |                             PP
#        |                        _____|____
#        NP                      |          NP
#   _____|________________       |          |
#  DT    JJ      NNP     NNP     IN        NNP
#  |     |        |       |      |          |
# The Eurasian Economic Union between     Russia
#
#
#
#  ..........................................................................
#
#
# 6
#
#
#
# Vietnam’s new marriage law goes into effect
#
#
#
# POS: [('Vietnam', 'NNP'), ('’s', 'POS'), ('new', 'JJ'), ('marriage', 'NN'), ('law', 'NN'), ('goes', 'VBZ'), ('into', 'IN'), ('effect', 'NN')]
#
#
#
# Tokens: ['Vietnam', '’s', 'new', 'marriage', 'law', 'goes', 'into', 'effect']
#
#
#
# NER: [('Vietnam', 'COUNTRY'), ('’s', 'O'), ('new', 'O'), ('marriage', 'O'), ('law', 'O'), ('goes', 'O'), ('into', 'O'), ('effect', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (NNP Vietnam) (POS 's))
#       (JJ new) (NN marriage) (NN law))
#     (VP (VBZ goes)
#       (PP (IN into)
#         (NP (NN effect))))))
#                       ROOT
#                        |
#                        S
#                   _____|_______________
#                  |                     VP
#                  |                 ____|____
#                  NP               |         PP
#           _______|____________    |     ____|____
#          NP      |     |      |   |    |         NP
#     _____|___    |     |      |   |    |         |
#   NNP       POS  JJ    NN     NN VBZ   IN        NN
#    |         |   |     |      |   |    |         |
# Vietnam      's new marriage law goes into     effect
#
#
#
#  ..........................................................................
#
#
# 7
#
#
#
# Somali al-Shabaab militants attack an army base on the outskirts of Baidoa
#
#
#
# POS: [('Somali', 'JJ'), ('al-Shabaab', 'JJ'), ('militants', 'NNS'), ('attack', 'VBP'), ('an', 'DT'), ('army', 'NN'), ('base', 'NN'), ('on', 'IN'), ('the', 'DT'), ('outskirts', 'NNS'), ('of', 'IN'), ('Baidoa', 'NNP')]
#
#
#
# Tokens: ['Somali', 'al-Shabaab', 'militants', 'attack', 'an', 'army', 'base', 'on', 'the', 'outskirts', 'of', 'Baidoa']
#
#
#
# NER: [('Somali', 'NATIONALITY'), ('al-Shabaab', 'O'), ('militants', 'O'), ('attack', 'O'), ('an', 'O'), ('army', 'O'), ('base', 'O'), ('on', 'O'), ('the', 'O'), ('outskirts', 'O'), ('of', 'O'), ('Baidoa', 'LOCATION')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (JJ Somali) (JJ al-Shabaab) (NNS militants))
#     (VP (VBP attack)
#       (NP (DT an) (NN army) (NN base))
#       (PP (IN on)
#         (NP
#           (NP (DT the) (NNS outskirts))
#           (PP (IN of)
#             (NP (NNP Baidoa))))))))
#                                        ROOT
#                                         |
#                                         S
#             ____________________________|_________
#            |                                      VP
#            |                   ___________________|______________
#            |                  |         |                        PP
#            |                  |         |          ______________|______
#            |                  |         |         |                     NP
#            |                  |         |         |        _____________|_______
#            |                  |         |         |       |                     PP
#            |                  |         |         |       |                  ___|____
#            NP                 |         NP        |       NP                |        NP
#    ________|__________        |      ___|____     |    ___|______           |        |
#   JJ       JJ        NNS     VBP    DT  NN   NN   IN  DT        NNS         IN      NNP
#   |        |          |       |     |   |    |    |   |          |          |        |
# Somali al-Shabaab militants attack  an army base  on the     outskirts      of     Baidoa
#
#
#
#  ..........................................................................
#
#
# 8
#
#
#
# Boko Haram militants attack a bus in Waza
#
#
#
# POS: [('Boko', 'NNP'), ('Haram', 'NNP'), ('militants', 'NNS'), ('attack', 'VBP'), ('a', 'DT'), ('bus', 'NN'), ('in', 'IN'), ('Waza', 'NNP')]
#
#
#
# Tokens: ['Boko', 'Haram', 'militants', 'attack', 'a', 'bus', 'in', 'Waza']
#
#
#
# NER: [('Boko', 'PERSON'), ('Haram', 'PERSON'), ('militants', 'O'), ('attack', 'O'), ('a', 'O'), ('bus', 'O'), ('in', 'O'), ('Waza', 'PERSON')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Boko) (NNP Haram) (NNS militants))
#     (VP (VBP attack)
#       (NP
#         (NP (DT a) (NN bus))
#         (PP (IN in)
#           (NP (NNP Waza)))))))
#                       ROOT
#                        |
#                        S
#         _______________|_____________
#        |                             VP
#        |                _____________|___
#        |               |                 NP
#        |               |          _______|_______
#        |               |         |               PP
#        |               |         |            ___|___
#        NP              |         NP          |       NP
#   _____|_______        |      ___|___        |       |
# NNP   NNP     NNS     VBP    DT      NN      IN     NNP
#  |     |       |       |     |       |       |       |
# Boko Haram militants attack  a      bus      in     Waza
#
#
#
#  ..........................................................................
#
#
# 9
#
#
#
# The MS Norman Atlantic ferry fire death toll rises to at least eleven with as many as 19 people still unaccounted for. (The Independent)
#
#
#
# POS: [('The', 'DT'), ('MS', 'NN'), ('Norman', 'NNP'), ('Atlantic', 'NNP'), ('ferry', 'NN'), ('fire', 'NN'), ('death', 'NN'), ('toll', 'NN'), ('rises', 'VBZ'), ('to', 'TO'), ('at', 'IN'), ('least', 'JJS'), ('eleven', 'NNS'), ('with', 'IN'), ('as', 'RB'), ('many', 'JJ'), ('as', 'IN'), ('19', 'CD'), ('people', 'NNS'), ('still', 'RB'), ('unaccounted', 'JJ'), ('for', 'IN'), ('.', '.'), ('(', '-LRB-'), ('The', 'DT'), ('Independent', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'MS', 'Norman', 'Atlantic', 'ferry', 'fire', 'death', 'toll', 'rises', 'to', 'at', 'least', 'eleven', 'with', 'as', 'many', 'as', '19', 'people', 'still', 'unaccounted', 'for', '.', '(', 'The', 'Independent', ')']
#
#
#
# NER: [('The', 'O'), ('MS', 'STATE_OR_PROVINCE'), ('Norman', 'PERSON'), ('Atlantic', 'PERSON'), ('ferry', 'O'), ('fire', 'CAUSE_OF_DEATH'), ('death', 'O'), ('toll', 'O'), ('rises', 'O'), ('to', 'O'), ('at', 'O'), ('least', 'O'), ('eleven', 'NUMBER'), ('with', 'O'), ('as', 'O'), ('many', 'O'), ('as', 'O'), ('19', 'NUMBER'), ('people', 'O'), ('still', 'O'), ('unaccounted', 'O'), ('for', 'O'), ('.', 'O'), ('(', 'O'), ('The', 'O'), ('Independent', 'RELIGION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN MS) (NNP Norman) (NNP Atlantic) (NN ferry))
#       (NP (NN fire) (NN death) (NN toll)))
#     (VP (VBZ rises)
#       (PP (TO to)
#         (NP
#           (NP
#             (ADVP (IN at) (JJS least))
#             (NNS eleven))
#           (PP (IN with)
#             (NP
#               (NP
#                 (QP (RB as) (JJ many) (IN as) (CD 19))
#                 (NNS people))
#               (ADJP (RB still) (JJ unaccounted))))))
#       (PP (IN for)))
#     (. .)))
#                                                                                       ROOT
#                                                                                        |
#                                                                                        S
#       _________________________________________________________________________________|____
#      |                                                                                      VP
#      |                                                                            __________|____________________________________________________________
#      |                                                                           NP                                                                      |
#      |               ____________________________________________________________|_____                                                                  |
#      |              |                                                                 SBAR                                                               |
#      |              |                                                                  |                                                                 |
#      |              |                                                                 FRAG                                                               |
#      |              |                   _______________________________________________|_______________________________________________________          |
#      |              |                  |                                                    S                                                  |         |
#      |              |                  |                                                    |                                                  |         |
#      |              |                  |                                                    VP                                                 |         |
#      |              |                  |                 ___________________________________|______________________________________________    |         |
#      |              |                  |                |                                   PP                                             |   |         |
#      |              |                  |                |     ______________________________|___                                           |   |         |
#      |              |                  |                |    |                                  NP                                         |   |         |
#      |              |                  |                |    |              ____________________|____                                      |   |         |
#      |              |                  |                |    |             |                         PP                                    |   |         |
#      |              |                  |                |    |             |            _____________|___                                  |   |         |
#      |              |                  |                |    |             |           |                 NP                                |   |         |
#      |              |                  |                |    |             |           |              ___|________________                 |   |         |
#      |              |                  |                |    |             NP          |             NP                   |                |   |        PRN
#      |              |                  |                |    |        _____|_____      |         ____|________            |                |   |     ____|____________________
#      NP             NP                 NP               |    |      ADVP         |     |        QP            |          ADJP              PP  |    |        NP               |
#   ___|___      _____|_____         ____|__________      |    |    ___|_____      |     |     ___|________     |       ____|________        |   |    |     ___|_______         |
#  DT      NN  NNP         NNP      NN   NN    NN   NN   VBZ   TO  IN       JJS   NNS    IN   RB  JJ   IN  CD  NNS     RB            JJ      IN  .  -LRB-  DT         NNP     -RRB-
#  |       |    |           |       |    |     |    |     |    |   |         |     |     |    |   |    |   |    |      |             |       |   |    |    |           |        |
# The      MS Norman     Atlantic ferry fire death toll rises  to  at      least eleven with  as many  as  19 people still      unaccounted for  .  -LRB- The     Independent -RRB-
#
#
#
#  ..........................................................................
#
#
# 10
#
#
#
# The United States enacts more sanctions on North Korea in response to their alleged involvement in the hacking attack on Sony. The sanctions target the North Korean Special Operation Force and 10 government officials. (Reuters)
#
#
#
# POS: [('The', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('enacts', 'VBZ'), ('more', 'JJR'), ('sanctions', 'NNS'), ('on', 'IN'), ('North', 'NNP'), ('Korea', 'NNP'), ('in', 'IN'), ('response', 'NN'), ('to', 'TO'), ('their', 'PRP$'), ('alleged', 'JJ'), ('involvement', 'NN'), ('in', 'IN'), ('the', 'DT'), ('hacking', 'NN'), ('attack', 'NN'), ('on', 'IN'), ('Sony', 'NNP'), ('.', '.'), ('The', 'DT'), ('sanctions', 'NNS'), ('target', 'VBP'), ('the', 'DT'), ('North', 'JJ'), ('Korean', 'JJ'), ('Special', 'JJ'), ('Operation', 'NNP'), ('Force', 'NNP'), ('and', 'CC'), ('10', 'CD'), ('government', 'NN'), ('officials', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('Reuters', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'United', 'States', 'enacts', 'more', 'sanctions', 'on', 'North', 'Korea', 'in', 'response', 'to', 'their', 'alleged', 'involvement', 'in', 'the', 'hacking', 'attack', 'on', 'Sony', '.', 'The', 'sanctions', 'target', 'the', 'North', 'Korean', 'Special', 'Operation', 'Force', 'and', '10', 'government', 'officials', '.', '(', 'Reuters', ')']
# NER: [('The', 'O'), ('United', 'COUNTRY'), ('States', 'COUNTRY'), ('enacts', 'O'), ('more', 'O'), ('sanctions', 'O'), ('on', 'O'), ('North', 'COUNTRY'), ('Korea', 'COUNTRY'), ('in', 'O'), ('response', 'O'), ('to', 'O'), ('their', 'O'), ('alleged', 'O'), ('involvement', 'O'), ('in', 'O'), ('the', 'O'), ('hacking', 'O'), ('attack', 'CAUSE_OF_DEATH'), ('on', 'O'), ('Sony', 'ORGANIZATION'), ('.', 'O'), ('The', 'O'), ('sanctions', 'O'), ('target', 'O'), ('the', 'O'), ('North', 'NATIONALITY'), ('Korean', 'NATIONALITY'), ('Special', 'O'), ('Operation', 'O'), ('Force', 'O'), ('and', 'O'), ('10', 'NUMBER'), ('government', 'O'), ('officials', 'O'), ('.', 'O'), ('(', 'O'), ('Reuters', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT The) (NNP United) (NNPS States))
#     (VP (VBZ enacts)
#       (NP
#         (NP (JJR more) (NNS sanctions))
#         (PP (IN on)
#           (NP
#             (NP (NNP North) (NNP Korea))
#             (PP (IN in)
#               (NP (NN response))))))
#       (PP (TO to)
#         (NP
#           (NP (PRP$ their) (JJ alleged) (NN involvement))
#           (PP (IN in)
#             (NP
#               (NP (DT the) (NN hacking) (NN attack))
#               (PP (IN on)
#                 (NP (NNP Sony))))))))
#     (. .)))
#                    ROOT
#                     |
#                     S
#        _____________|________________________
#       |                                      VP
#       |              ________________________|_____________________________________________
#       |             |          |                            |                              PP
#       |             |          |                            |                          ____|________________
#       |             |          |                            |                         |                     NP
#       |             |          |                            |                         |            _________|___________
#       |             |          |                            |                         |           |                     PP
#       |             |          |                            |                         |           |                  ___|____________
#       |             |          |                            |                         |           |                 |                NP
#       |             |          |                            |                         |           |                 |          ______|_________
#       |             |          |                            |                         |           |                 |         |                PP
#       |             |          |                            |                         |           |                 |         |             ___|____________
#       |             |          |                            |                         |           |                 |         |            |                NP
#       |             |          |                            |                         |           |                 |         |            |         _______|__________________
#       |             |          |                            |                         |           |                 |         |            |        |                         SBAR
#       |             |          |                            |                         |           |                 |         |            |        |                          |
#       |             |          |                            |                         |           |                 |         |            |        |                          S
#       |             |          |                            |                         |           |                 |         |            |        |            ______________|________________
#       |             |          |                            PP                        |           |                 |         |            |        |           |                               VP
#       |             |          |              ______________|____                     |           |                 |         |            |        |           |               ________________|_____________________________
#       |             |          |             |                   NP                   |           |                 |         |            |        |           |              |                                              NP
#       |             |          |             |          _________|_______             |           |                 |         |            |        |           |              |                                          ____|________________________________________
#       |             |          |             |         |                 PP           |           |                 |         |            |        |           |              |                                         NP                                           PRN
#       |             |          |             |         |              ___|_____       |           |                 |         |            |        |           |              |                 ________________________|_________________________________      ______|______
#       NP            |          NP            |         NP            |         NP     |           NP                |         NP           |        NP          NP             |                NP                            |          NP                |    |      NP     |
#   ____|______       |      ____|______       |     ____|____         |         |      |     ______|_________        |    _____|______      |    ____|___     ___|______        |      __________|________________________     |    ______|__________       |    |      |      |
#  DT  NNP    NNPS   VBZ   JJR         NNS     IN  NNP       NNP       IN        NN     TO  PRP$    JJ        NN      IN  DT    NN     NN    IN NNP       .   DT        NNS     VBP    DT   JJ    JJ      JJ      NNP     NNP   CC  CD     NN        NNS     .  -LRB-   NNP   -RRB-
#  |    |      |      |     |           |      |    |         |        |         |      |    |      |         |       |   |     |      |     |   |        |   |          |       |     |    |     |       |        |       |    |   |      |          |      |    |      |      |
# The United States enacts more     sanctions  on North     Korea      in     response  to their alleged involvement  in the hacking attack  on Sony      .  The     sanctions target the North Korean Special Operation Force and  10 government officials  .  -LRB- Reuters -RRB-
#
#
#
#  ..........................................................................
#
#
# 11
#
#
#
# Fleeing villagers from a remote part of the Borno State report that Boko Haram had three days prior kidnapped around 40 boys and young men. (BBC)
#
#
#
# POS: [('Fleeing', 'VBG'), ('villagers', 'NNS'), ('from', 'IN'), ('a', 'DT'), ('remote', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Borno', 'NNP'), ('State', 'NNP'), ('report', 'NN'), ('that', 'IN'), ('Boko', 'NNP'), ('Haram', 'NNP'), ('had', 'VBD'), ('three', 'CD'), ('days', 'NNS'), ('prior', 'RB'), ('kidnapped', 'VBN'), ('around', 'IN'), ('40', 'CD'), ('boys', 'NNS'), ('and', 'CC'), ('young', 'JJ'), ('men', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('BBC', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['Fleeing', 'villagers', 'from', 'a', 'remote', 'part', 'of', 'the', 'Borno', 'State', 'report', 'that', 'Boko', 'Haram', 'had', 'three', 'days', 'prior', 'kidnapped', 'around', '40', 'boys', 'and', 'young', 'men', '.', '(', 'BBC', ')']
# NER: [('Fleeing', 'O'), ('villagers', 'O'), ('from', 'O'), ('a', 'O'), ('remote', 'O'), ('part', 'O'), ('of', 'O'), ('the', 'O'), ('Borno', 'ORGANIZATION'), ('State', 'ORGANIZATION'), ('report', 'O'), ('that', 'O'), ('Boko', 'PERSON'), ('Haram', 'PERSON'), ('had', 'O'), ('three', 'DURATION'), ('days', 'DURATION'), ('prior', 'O'), ('kidnapped', 'O'), ('around', 'O'), ('40', 'NUMBER'), ('boys', 'O'), ('and', 'O'), ('young', 'O'), ('men', 'O'), ('.', 'O'), ('(', 'O'), ('BBC', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (NP
#     (NP (VBG Fleeing) (NNS villagers))
#     (PP (IN from)
#       (NP (DT a) (JJ remote) (NN part)))
#     (PP (IN of)
#       (NP
#         (NP (DT the) (NNP Borno) (NNP State) (NN report))
#         (SBAR (IN that)
#           (S
#             (NP (NNP Boko) (NNP Haram))
#             (VP (VBD had)
#               (ADVP
#                 (NP (CD three) (NNS days))
#                 (RB prior))
#               (VP (VBN kidnapped)
#                 (PP (IN around)
#                   (NP
#                     (NP (CD 40) (NNS boys))
#                     (CC and)
#                     (NP (JJ young) (NNS men))))))))))
#     (. .)))
#                             ROOT
#                              |
#                              S
#                              |
#                              VP
#     _________________________|__________________________________________
#    |        |                |                                         SBAR
#    |        |                |                                      ____|______________
#    |        |                |                                     |                   S
#    |        |                |                                     |          _________|_____________
#    |        |                |                                     |         |                       VP
#    |        |                |                                     |         |          _____________|___________________________
#    |        |                |                                     |         |         |             |                           VP
#    |        |                |                                     |         |         |             |              _____________|_________________
#    |        |                PP                                    |         |         |             |             |                               PP
#    |        |       _________|__________                           |         |         |             |             |        _______________________|________
#    |        |      |                    NP                         |         |         |             |             |       |                                NP
#    |        |      |          __________|___                       |         |         |             |             |       |                   _____________|_____________
#    |        |      |         |              PP                     |         |         |            ADVP           |       |                  NP                         PRN
#    |        |      |         |           ___|____                  |         |         |          ___|_____        |       |          ________|_________________      ____|____
#    |        NP     |         NP         |        NP                |         NP        |         NP        |       |       |         NP       |         NP      |    |    NP   |
#    |        |      |     ____|_____     |    ____|___________      |     ____|____     |     ____|___      |       |       |      ___|___     |     ____|___    |    |    |    |
#   VBG      NNS     IN   DT   JJ    NN   IN  DT  NNP   NNP    NN    IN  NNP       NNP  VBD   CD      NNS    RB     VBN      IN    CD     NNS   CC   JJ      NNS  .  -LRB- NNP -RRB-
#    |        |      |    |    |     |    |   |    |     |     |     |    |         |    |    |        |     |       |       |     |       |    |    |        |   |    |    |    |
# Fleeing villagers from  a  remote part  of the Borno State report that Boko     Haram had three     days prior kidnapped around  40     boys and young     men  .  -LRB- BBC -RRB-
#
#
#
#  ..........................................................................
#
#
# 12
#
#
#
# Turkey permits the building of a Syriac church in Istanbul
#
#
#
# POS: [('Turkey', 'NNP'), ('permits', 'VBZ'), ('the', 'DT'), ('building', 'NN'), ('of', 'IN'), ('a', 'DT'), ('Syriac', 'JJ'), ('church', 'NN'), ('in', 'IN'), ('Istanbul', 'NNP')]
#
#
#
# Tokens: ['Turkey', 'permits', 'the', 'building', 'of', 'a', 'Syriac', 'church', 'in', 'Istanbul']
#
#
#
# NER: [('Turkey', 'COUNTRY'), ('permits', 'O'), ('the', 'O'), ('building', 'O'), ('of', 'O'), ('a', 'O'), ('Syriac', 'MISC'), ('church', 'O'), ('in', 'O'), ('Istanbul', 'CITY')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Turkey))
#     (VP (VBZ permits)
#       (NP
#         (NP (DT the) (NN building))
#         (PP (IN of)
#           (NP
#             (NP (DT a) (JJ Syriac) (NN church))
#             (PP (IN in)
#               (NP (NNP Istanbul)))))))))
#          ROOT
#           |
#           S
#    _______|_______________
# ...
#            _______________|____________
#           |                            VP
#           |                       _____|_________
#           |                      |              SBAR
#           |                      |               |
#           |                      |               S
#           |                      |      _________|_________
#           |                      |     |                   VP
#           |                      |     |     ______________|____________________________
#           |                      |     |    |                                           PP
#           |                      |     |    |     ______________________________________|_________
#           |                      |     |    |    |                                                NP
#           |                      |     |    |    |                         _______________________|__________________________
#           |                      |     |    |    |                        NP                            |                    NP
#           |                      |     |    |    |                 _______|_________________            |            ________|______
#           |                      |     |    |    |                |                         PP          |           |              PRN
#           |                      |     |    |    |                |                      ___|_____      |           |         ______|______
#           NP                     |     NP   |    |                NP                    |         NP    |           NP       |      NP     |
#     ______|_______________       |     |    |    |     ___________|_______________      |         |     |      _____|___     |      |      |
#    JJ     NN     NN      NNS    VBP    DT  VBZ   IN   DT  NNP    NNPS    NNP      NN    IN       NNP    CC   NNP        .  -LRB-   NNP   -RRB-
#    |      |      |        |      |     |    |    |    |    |      |       |       |     |         |     |     |         |    |      |      |
# Apparent ISIL computer hackers attack the feeds for  the United States Central Command for     Twitter and YouTube      .  -LRB- Reuters -RRB-
#
#
#
#  ..........................................................................
#
#
# 97
#
#
#
# Cameroon kills 143 Boko Haram fighters in clashes. (Reuters)
#
#
#
# POS: [('Cameroon', 'NNP'), ('kills', 'VBZ'), ('143', 'CD'), ('Boko', 'NNP'), ('Haram', 'NNP'), ('fighters', 'NNS'), ('in', 'IN'), ('clashes', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('Reuters', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['Cameroon', 'kills', '143', 'Boko', 'Haram', 'fighters', 'in', 'clashes', '.', '(', 'Reuters', ')']
#
#
#
# NER: [('Cameroon', 'COUNTRY'), ('kills', 'O'), ('143', 'NUMBER'), ('Boko', 'PERSON'), ('Haram', 'PERSON'), ('fighters', 'O'), ('in', 'O'), ('clashes', 'O'), ('.', 'O'), ('(', 'O'), ('Reuters', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Cameroon))
#     (VP (VBZ kills)
#       (NP
#         (NP (CD 143) (NNP Boko) (NNP Haram) (NNS fighters))
#         (PP (IN in)
#           (NP (NNS clashes)))))
#     (. .)))
#           ROOT
#            |
#            S
#     _______|________
#    |                VP
#    |        ________|___________________
#    |       |                            NP
#    |       |                      ______|_______________________
#    |       |                     NP                             |
#    |       |         ____________|____________                  |
#    |       |        |                        PRN                |
#    |       |        |                         |                 |
#    |       |        NP                        PP               PRN
#    |       |     ___|____________        _____|_____      ______|______
#    NP      |    QP  |     |      |      |     NP    |    |      NP     |
#    |       |    |   |     |      |      |     |     |    |      |      |
#   NNP     VBZ   CD NNP   NNP    NNS     IN   NNS    .  -LRB-   NNP   -RRB-
#    |       |    |   |     |      |      |     |     |    |      |      |
# Cameroon kills 143 Boko Haram fighters  in clashes  .  -LRB- Reuters -RRB-
#
#
#
#  ..........................................................................
#
#
# 98
#
#
#
# The eruption of the Hunga Tonga volcano disrupts flights to and from Tonga. (Radio New Zealand)
#
#
#
# POS: [('The', 'DT'), ('eruption', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Hunga', 'NNP'), ('Tonga', 'NNP'), ('volcano', 'NN'), ('disrupts', 'VBZ'), ('flights', 'NNS'), ('to', 'TO'), ('and', 'CC'), ('from', 'IN'), ('Tonga', 'NNP'), ('.', '.'), ('(', '-LRB-'), ('Radio', 'NNP'), ('New', 'NNP'), ('Zealand', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'eruption', 'of', 'the', 'Hunga', 'Tonga', 'volcano', 'disrupts', 'flights', 'to', 'and', 'from', 'Tonga', '.', '(', 'Radio', 'New', 'Zealand', ')']
#
#
#
# NER: [('The', 'O'), ('eruption', 'O'), ('of', 'O'), ('the', 'O'), ('Hunga', 'LOCATION'), ('Tonga', 'COUNTRY'), ('volcano', 'O'), ('disrupts', 'O'), ('flights', 'O'), ('to', 'O'), ('and', 'O'), ('from', 'O'), ('Tonga', 'COUNTRY'), ('.', 'O'), ('(', 'O'), ('Radio', 'O'), ('New', 'COUNTRY'), ('Zealand', 'COUNTRY'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN eruption))
#       (PP (IN of)
#         (NP (DT the) (NNP Hunga) (NNP Tonga) (NN volcano))))
#     (VP (VBZ disrupts)
#       (NP (NNS flights))
#       (PP (TO to)
#         (CC and)
#         (IN from)
#         (NP (NNP Tonga))))
#     (. .)))
#                                                               ROOT
#                                                                |
#                                                                S
#             ___________________________________________________|______________
#            |                                                                  VP
#            |                                     _____________________________|________
#            |                                    |        |                             PP
#            |                                    |        |      _______________________|__________
#            NP                                   |        |     |    |   |                         NP
#       _____|__________                          |        |     |    |   |           ______________|____
#      |                PP                        |        |     |    |   |          |                  PRN
#      |             ___|____                     |        |     |    |   |          |         __________|____________
#      NP           |        NP                   |        NP    |    |   |          NP       |          NP           |
#   ___|_____       |    ____|____________        |        |     |    |   |      ____|___     |      ____|_____       |
#  DT        NN     IN  DT  NNP   NNP     NN     VBZ      NNS    TO   CC  IN   NNP       .  -LRB-  NNP  NNP   NNP   -RRB-
#  |         |      |   |    |     |      |       |        |     |    |   |     |        |    |     |    |     |      |
# The     eruption  of the Hunga Tonga volcano disrupts flights  to  and from Tonga      .  -LRB- Radio New Zealand -RRB-
#
#
#
#  ..........................................................................
#
#
# 99
#
#
#
# A school bus plunges off of a cliff on the Caribbean island of St. Vincent leaving at least five people dead and two missing. (AP)
#
#
#
# POS: [('A', 'DT'), ('school', 'NN'), ('bus', 'NN'), ('plunges', 'VBZ'), ('off', 'IN'), ('of', 'IN'), ('a', 'DT'), ('cliff', 'NN'), ('on', 'IN'), ('the', 'DT'), ('Caribbean', 'NNP'), ('island', 'NN'), ('of', 'IN'), ('St.', 'NNP'), ('Vincent', 'NNP'), ('leaving', 'VBG'), ('at', 'IN'), ('least', 'JJS'), ('five', 'CD'), ('people', 'NNS'), ('dead', 'JJ'), ('and', 'CC'), ('two', 'CD'), ('missing', 'VBG'), ('.', '.'), ('(', '-LRB-'), ('AP', 'NN'), (')', '-RRB-')]
#
#
#
# Tokens: ['A', 'school', 'bus', 'plunges', 'off', 'of', 'a', 'cliff', 'on', 'the', 'Caribbean', 'island', 'of', 'St.', 'Vincent', 'leaving', 'at', 'least', 'five', 'people', 'dead', 'and', 'two', 'missing', '.', '(', 'AP', ')']
# NER: [('A', 'O'), ('school', 'O'), ('bus', 'O'), ('plunges', 'O'), ('off', 'O'), ('of', 'O'), ('a', 'O'), ('cliff', 'O'), ('on', 'O'), ('the', 'O'), ('Caribbean', 'LOCATION'), ('island', 'O'), ('of', 'O'), ('St.', 'LOCATION'), ('Vincent', 'LOCATION'), ('leaving', 'O'), ('at', 'O'), ('least', 'O'), ('five', 'NUMBER'), ('people', 'O'), ('dead', 'O'), ('and', 'O'), ('two', 'NUMBER'), ('missing', 'O'), ('.', 'O'), ('(', 'O'), ('AP', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT A) (NN school) (NN bus))
#     (VP (VBZ plunges)
#       (PRT (IN off))
#       (PP (IN of)
#         (NP
#           (NP (DT a) (NN cliff))
#           (PP (IN on)
#             (NP
#               (NP
#                 (NP (DT the) (NNP Caribbean) (NN island))
#                 (PP (IN of)
#                   (NP
#                     (NP (NNP St.) (NNP Vincent))
#                     (VP (VBG leaving)
#                       (NP
#                         (QP (IN at) (JJS least) (CD five))
#                         (NNS people))
#                       (S
#                         (ADJP (JJ dead)))))))
#               (CC and)
#               (NP
#                 (NP (CD two))
#                 (VP (VBG missing))))))))
#     (. .)))
#                  ROOT
#                   |
#                   S
#        ___________|_________
#       |                     VP
#       |            _________|____________________________
#       |           |     |                                PP
#       |           |     |    ____________________________|_________________________________________
#       |           |     |   |                                                                      NP
#       |           |     |   |        ______________________________________________________________|____
#       |           |     |   |       |                                                                   PP
#       |           |     |   |       |          _________________________________________________________|________
#       |           |     |   |       |         |                                                                  NP
#       |           |     |   |       |         |           _______________________________________________________|_______________________________________________
#       |           |     |   |       |         |          |                                   PP                                                                  |
#       |           |     |   |       |         |          |              _____________________|___________________                                                |
#       |           |     |   |       |         |          |             |                                         NP                                              |
#       |           |     |   |       |         |          |             |                            _____________|__________________________                     |
#       |           |     |   |       |         |          |             |                           NP                             |         NP                   |
#       |           |     |   |       |         |          |             |        ___________________|____                          |    _____|_____               |
#       |           |     |   |       |         |          |             |       |                        VP                        |   |          SBAR            |
#       |           |     |   |       |         |          |             |       |              __________|____________________     |   |           |              |
#       |           |     |   |       |         |          |             |       |             |               NP              S    |   |          FRAG           PRN
#       |           |     |   |       |         |          |             |       |             |           ____|_________      |    |   |      _____|____      ____|____
#       NP          |    PRT  |       NP        |          NP            |       NP            |          QP             |    ADJP  |   NP   ADJP        |    |    NP   |
#   ____|_____      |     |   |    ___|____     |    ______|_______      |    ___|_____        |      ____|________      |     |    |   |     |          |    |    |    |
#  DT   NN    NN   VBZ    IN  IN  DT       NN   IN  DT    NNP      NN    IN NNP       NNP     VBG    IN  JJS       CD   NNS    JJ   CC  CD   VBG         .  -LRB-  NN -RRB-
#  |    |     |     |     |   |   |        |    |   |      |       |     |   |         |       |     |    |        |     |     |    |   |     |          |    |    |    |
#  A  school bus plunges off  of  a      cliff  on the Caribbean island  of St.     Vincent leaving  at least     five people dead and two missing       .  -LRB-  AP -RRB-
#
#
#
#  ..........................................................................

# %%
df['event_summary'].count()
# Out:
# 9487

# %%
tokens=[]

# %%
# if __name__ == '__main__':
#     sNLP = StanfordNLP()
#     for i in range(0, 12817):
#         text = df['event_summary'][i]
# #         print ("Annotate:", sNLP.annotate(text))
        
#         print ("Tokens:", sNLP.word_tokenize(text))
#         tokens=sNLP.word_tokenize(text)
#         df['tokens'][i]=tokens
# #         print('\n\n .......................................................................... \n\n')
# #         print ("Dep Parse:", sNLP.dependency_parse(text))

# %%
 text = df['event_summary'][2]

# %%
text
# Out:
# 'Lithuania adopts the euro as its official currency'

# %%
from nltk.tree import Tree
parsestr=sNLP.parse(text)
parsestr
# Out:
# '(ROOT\r\n  (S\r\n    (NP (NNP Lithuania))\r\n    (VP (VBZ adopts)\r\n      (NP\r\n        (NP (DT the) (NN euro))\r\n        (PP (IN as)\r\n          (NP (PRP$ its) (JJ official) (NN currency)))))))'

# %% [markdown]
# # Printing noun phrases

# %%
import math
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'NP':
        print (i)
        
#         ptempty_list.append(i)
#A shooting kills one and injures six people in Killarney'
# Out:
# (NP (NNP Lithuania))
# (NP
#   (NP (DT the) (NN euro))
#   (PP (IN as) (NP (PRP$ its) (JJ official) (NN currency))))
# (NP (DT the) (NN euro))
# (NP (PRP$ its) (JJ official) (NN currency))

# %% [markdown]
# # Printing noun phrases leaves

# %%
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'VP':
        print (i.leaves())
# Out:
# ['adopts', 'the', 'euro', 'as', 'its', 'official', 'currency']

# %% [markdown]
# # Creating a new file to convert tree into string

# %%
#!/usr/bin/python
fo = open('NP', 'w')
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'NP':
#         print (i)
#         print (i.leaves())
        fo.write(str(i )+ ';'+ str(i.leaves())+ ';')
#         fo.write(str(i.leaves())+ ';')
#         fo.write("\n")
                 
#         print ("\n\n\n________________________________________________________________________\n\n\n")
fo.flush()
fo.close()

# %% [markdown]
# # Reading text file and converting it into one string

# %%
with open('NP', 'r') as file:
    data = file.read().replace('\n', '')
# print(data)

# %%
df['event_summary'][2]
# Out:
# 'Lithuania adopts the euro as its official currency'

# %% [markdown]
# # Full code for all dataset. Extracting all NP, VP, PP for all dataset

# %%
df['event_summary'][2]
parsestr
# Out:
# '(ROOT\r\n  (S\r\n    (NP (NNP Lithuania))\r\n    (VP (VBZ adopts)\r\n      (NP\r\n        (NP (DT the) (NN euro))\r\n        (PP (IN as)\r\n          (NP (PRP$ its) (JJ official) (NN currency)))))))'

# %%
df['event_summary'].count()
# Out:
# 9487

# %%
for i in range(0,30):
    df['Nounphrases'+ str(i)]="NULL VALUE"

# %%
for j in range(0,100):
    fo = open('verbphrase', 'w', encoding="utf-8")
    text = df['event_summary'][j]
    print(text+"\n")
    parsestr=sNLP.parse(text)
    for i in Tree.fromstring(parsestr).subtrees():
        if i.label() == 'NP':
#             fo.write(str(i)+ ';')
            fo.write(str( i.leaves())+ ';')
           
    fo.close()        
    with open('verbphrase', 'r',encoding="utf8") as file:
        data = file.read().replace('\n', '')
#         data = file.read().replace('[', '')
        
#         data = file.read()
        split_data=data.split(';')
        print (split_data[0])
        print(len(split_data))
        
        for k in range(0,len(split_data)):
#             df['Nounphrases'+ str(k) ]="random"
            df['Nounphrases'+ str(k)][j]=split_data[k]
#             print(df['Nounphrases'+ str(k)][j])

#         df['Verb_Phrases'][j]=data
#         print( df['Verb_Phrases'][j])
        file.seek(0)
    fo = open('verbphrase', 'w').close()
#     fo.write("")
# Out:
# The death toll of the suicide bombing in Ibb
#
# ['The', 'death', 'toll', 'of', 'the', 'suicide', 'bombing', 'in', 'Ibb']
# 8
# c:\users\gulja\python 3.7.3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A shooting kills one and injures six people in Killarney
#
# ['A', 'shooting']
# 6
# Lithuania adopts the euro as its official currency
#
# ['Lithuania']
# 5
# U.S. fast-food restaurant chain Chick-fil-A warns that a security breach may have leaked credit card details of 9
#
# ['U.S.', 'fast-food', 'restaurant', 'chain', 'Chick-fil-A']
# 8
# The Palestine Authority signs a treaty to join and participate in the International Criminal Court. (Wall Street Journal)
#
# ['The', 'Palestine', 'Authority', 'signs', 'a', 'treaty', 'to', 'join', 'and', 'participate', 'in', 'the', 'International', 'Criminal', 'Court', '.']
# 6
# The Eurasian Economic Union between Russia
#
# ['The', 'Eurasian', 'Economic', 'Union']
# 3
# Vietnam’s new marriage law goes into effect
#
# ['Vietnam', "'s", 'new', 'marriage', 'law']
# 4
# Somali al-Shabaab militants attack an army base on the outskirts of Baidoa
#
# ['Somali', 'al-Shabaab', 'militants']
# 6
# Boko Haram militants attack a bus in Waza
#
# ['Boko', 'Haram', 'militants']
# 5
# The MS Norman Atlantic ferry fire death toll rises to at least eleven with as many as 19 people still unaccounted for. (The Independent)
#
# ['The', 'MS', 'Norman', 'Atlantic', 'ferry', 'fire', 'death', 'toll']
# 8
# The United States enacts more sanctions on North Korea in response to their alleged involvement in the hacking attack on Sony. The sanctions target the North Korean Special Operation Force and 10 government officials. (Reuters)
#
# ['The', 'United', 'States']
# 12
# Fleeing villagers from a remote part of the Borno State report that Boko Haram had three days prior kidnapped around 40 boys and young men. (BBC)
#
# ['Fleeing', 'villagers', 'from', 'a', 'remote', 'part', 'of', 'the', 'Borno', 'State', 'report', 'that', 'Boko', 'Haram', 'had', 'three', 'days', 'prior', 'kidnapped', 'around', '40', 'boys', 'and', 'young', 'men', '.']
# 11
# Turkey permits the building of a Syriac church in Istanbul
#
# ['Turkey']
# 7
# The Singapore-registered cargo ship MV Höegh Osaka runs aground on Bramble Bank off the coast of the Isle of Wight
#
# ['The', 'Singapore-registered', 'cargo', 'ship', 'MV', 'Höegh', 'Osaka']
# 9
# The Cypriot-registered cargo ship Cemfjord sinks off the northern coast of Scotland leaving eight onboard missing. (BBC News)
#
# ['The', 'Cypriot-registered', 'cargo', 'ship', 'Cemfjord']
# 8
# A U.S. drone strike kills eight Uzbek people claimed to be linked with al-Qaeda in Pakistan. (Channel 9 News)
#
# ['A', 'U.S.', 'drone', 'strike']
# 5
# A vehicle carrying United Nations peacekeepers hits a roadside bomb in northern Mali
#
# ['A', 'vehicle', 'carrying', 'United', 'Nations', 'peacekeepers']
# 7
# A bombing at a local Houthi movement headquarters in Dhamar Governorate
#
# ['A', 'bombing', 'at', 'a', 'local', 'Houthi', 'movement', 'headquarters', 'in', 'Dhamar', 'Governorate']
# 6
# A suicide car bomber detonates near a military convoy in Mogadishu
#
# ['A', 'suicide', 'car', 'bomber']
# 5
# A six-story building collapse in Nairobi
#
# ['A', 'six-story', 'building', 'collapse', 'in', 'Nairobi']
# 6
# Pope Francis announces the appointment of 20 new Cardinals
#
# ['Pope', 'Francis']
# 5
# A Libyan warplane bombs a Greek-operated oil tanker anchored offshore the city of Derna
#
# ['A', 'Libyan', 'warplane', 'bombs', 'a', 'Greek-operated', 'oil', 'tanker']
# 7
# News emerges that two days prior hundreds of Boko Haram militants had overrun several towns in northeast Nigeria and captured the military base in Baga. (Wall Street Journal)
#
# ['News']
# 11
# Bangladeshi police report that two opposition Bangladesh Nationalist Party activists are shot dead in clashes with members of the ruling Awami League in the town of Natore on the first anniversary of disputed general election. (BBC)
#
# ['Bangladeshi', 'police']
# 18
# A suicide car bomber hits the headquarters of EUPOL Afghanistan in Kabul
#
# ['A', 'suicide', 'car', 'bomber']
# 7
# A Czech archaeological team discovers the tomb of formerly unknown Ancient Egyptian queen Khentakawess III who lived during the Fifth Dynasty. (CNN)
#
# ['A', 'Czech', 'archaeological', 'team']
# 8
# The site where Jesus may have been tried
#
# ['The', 'site']
# 3
# China relaxes controls over the export of rare earth elements after losing a case brought by the United States at the World Trade Organization. (AP)
#
# ['China']
# 11
# Ireland becomes the first European nation to be allowed to export beef to the United States since the mad cow disease scare 15 years ago. (AP via Star Tribune)
#
# ['Ireland']
# 8
# For the second day in a row a multi-story residential building in Nairobi
#
# ['the', 'second', 'day', 'in', 'a', 'row']
# 7
# An avalanche near the Rettenbach glacier in the Austrian Alps
#
# ['An', 'avalanche', 'near', 'the', 'Rettenbach', 'glacier', 'in', 'the', 'Austrian', 'Alps']
# 6
# After being grounded in Abu Dhabi for over 12 hours with all passengers on board
#
# ['Abu', 'Dhabi', 'for', 'over', '12', 'hours']
# 7
# South Korea announces that it will repatriate the remains of Chinese Peoples Liberation Army soldiers killed in the Korean War. (Yonhap)
#
# ['South', 'Korea']
# 9
# Lebanon implements stricter immigration rules on its Syrian border in response to the refugee crisis caused by the Syrian Civil War. (Reuters)
#
# ['Lebanon']
# 10
# Taiwan's justice ministry releases former President Chen Shui-bian from jail on a one-month medical parole. (BBC)
#
# ['Taiwan', "'s", 'justice', 'ministry']
# 7
# The anti-graft body of the Communist Party of China detains Yang Weize
#
# ['The', 'anti-graft', 'body', 'of', 'the', 'Communist', 'Party', 'of', 'China']
# 6
# The Justice Department charges two American citizens of Gambian descent with violating the Neutrality Act by helping to finance and lead the 2014 Gambian coup d'état attempt. (New York Times)
#
# ['The', 'Justice', 'Department']
# 7
# Clashes with ISIL in Anbar province kill twenty-three Iraqi Army soldiers and allied Sunni fighters. (AP via The Hindu)
#
# ['Clashes', 'with', 'ISIL', 'in', 'Anbar', 'province']
# 8
# A suicide bomber kills herself and a policeman in an attack on a police station in a popular tourist district in the Turkish city of Istanbul. (New York Times)
#
# ['A', 'suicide', 'bomber']
# 13
# Officials in the American state of Massachusetts open a time capsule left behind by founding fathers Paul Revere and Samuel Adams. (Reuters via Yahoo! News)
#
# ['Officials', 'in', 'the', 'American', 'state', 'of', 'Massachusetts']
# 11
# American luxury fashion company Coach
#
# ['American', 'luxury', 'fashion', 'company']
# 2
# The price of crude oil drops to $48 per barrel
#
# ['The', 'price', 'of', 'crude', 'oil']
# 7
# A military truck collides with a bus carrying members of the National Guard of Ukraine in Ukraine
#
# ['A', 'military', 'truck']
# 10
# Two commuter trains collide at Mesquita
#
# ['Two', 'commuter', 'trains']
# 3
# Scientists at Oxford University begin a new Ebola vaccine trial on 72 healthy volunteers. (BBC)
#
# ['Scientists', 'at', 'Oxford', 'University']
# 6
# 43 US states report an epidemic of influenza
#
# ['43', 'US', 'states']
# 5
# Cuba starts releasing political prisoners as part of an historic agreement with the United States announced last month. (The Guardian)
#
# ['Cuba']
# 8
# Thai police arrest Gurmeet Singh convicted of involvement in a bombing in Chandigarh that killed 18 people in 1996
#
# ['Thai', 'police', 'arrest', 'Gurmeet', 'Singh']
# 8
# Various California state district attorneys fine Safeway a total of $10 million for the illegal dumping of electronics and pharmaceuticals into landfills. (KPIX)
#
# ['Various', 'California', 'state', 'district', 'attorneys']
# 11
# A man claiming to be the Lord's Resistance Army top commander Ugandan Dominic Ongwen turns himself in to United States forces in the Central African Republic. (AP)
#
# ['A', 'man', 'claiming', 'to', 'be', 'the', 'Lord', "'s", 'Resistance', 'Army', 'top', 'commander', 'Ugandan', 'Dominic', 'Ongwen']
# 10
# A U.S. District Judge sentences former Virginia Governor Bob McDonnell to two years in prison for corruption. (AP via FOX News)
#
# ['A', 'U.S.', 'District', 'Judge', 'sentences', 'former', 'Virginia', 'Governor', 'Bob', 'McDonnell', 'to', 'two', 'years', 'in', 'prison', 'for', 'corruption', '.']
# 10
# A gunman shoots a doctor at the William Beaumont Army Medical Center in El Paso
#
# ['A', 'gunman']
# 6
# An improvised device explodes outside of the Colorado Springs chapter of the NAACP with no injuries. (ABC News)
#
# ['An', 'improvised', 'device']
# 6
# The 114th United States Congress begins. (ABC News)
#
# ['The', '114th', 'United', 'States', 'Congress']
# 2
# The US Congress re-elects John Boehner to his third term as Speaker. (USA Today)
#
# ['The', 'US', 'Congress']
# 6
# NASA's Kepler space observatory announces the discovery of three new planets in the Goldilocks zone capable of supporting life. (News Limited)
#
# ['NASA', "'s", 'Kepler', 'space', 'observatory']
# 9
# A proposal to change the demolition of Candlestick Park in San Francisco
#
# ['A', 'proposal', 'to', 'change', 'the', 'demolition', 'of', 'Candlestick', 'Park', 'in', 'San', 'Francisco']
# 7
# Gunmen attack the Paris office of the French satirical magazine Charlie Hebdo
#
# ['Gunmen']
# 5
# A car bomb explodes outside a police college in the Yemeni capital Sana'a with at least 38 people reported dead and more than 50 wounded. (Reuters)
#
# ['A', 'car', 'bomb']
# 11
# An Andhra Pradesh State Road Transport Corporation bus falls into a ravine near the town of Penukonda in the Indian state of Andhra Pradesh killing at least 20 people. (DNA)
#
# ['An', 'Andhra', 'Pradesh', 'State', 'Road', 'Transport', 'Corporation', 'bus']
# 12
# Nature publishes the findings of Northeastern University scientists that a new class of drug can kill antibiotic-resistant bacteria. (Reuters)
#
# ['Nature']
# 9
# The California Department of Public Health investigates at least nine measles cases linked to Disneyland attendance. (The LA Times)
#
# ['The', 'California', 'Department', 'of', 'Public', 'Health']
# 7
# Philippines President Benigno Aquino III demands an investigation after a drone purportedly belonging to the United States Navy is found in the Philippine province of Quezon
#
# ['Philippines', 'President', 'Benigno', 'Aquino', 'III']
# 9
# The United States denounces a flag-raising ceremony at Taiwan's de facto embassy in Washington DC
#
# ['The', 'United', 'States']
# 7
# One of the suspects in the killings
#
# ['One', 'of', 'the', 'suspects', 'in', 'the', 'killings']
# 6
# [https://www.nytimes.com/2015/01/08/world/europe/charlie-hebdo-paris-shooting.html?smid=tw-nytimes&_r=0"
#
# ['-LSB-', 'https://www.nytimes.com/2015/01/08/world/europe/charlie-hebdo-paris-shooting.html?smid=tw-nytimes&_r=0"']
# 2
# Boko Haram militants raze the entire town of Baga in north-east Nigeria. Bodies lay strewn on Baga's streets with as many as 2
#
# ['Boko', 'Haram', 'militants']
# 7
# A suicide bomber targets a police checkpoint in the town of Youssifiyah
#
# ['A', 'suicide', 'bomber']
# 6
# Dunkin' Donuts signs a franchise agreement for 1
#
# ["Dunkin'", 'Donuts', 'signs', 'a', 'franchise', 'agreement', 'for', '1']
# 6
# Coca-Cola announces that it plans to cut 1
#
# ['Coca-Cola']
# 4
# Schools in the Midwestern and Northeast United States close for a second successive day due to bitterly cold temperatures. (Reuters via Yahoo! News)
#
# ['Schools', 'in', 'the', 'Midwestern', 'and', 'Northeast', 'United', 'States']
# 9
# An unknown gunman shoots dead Nerlita Ledesma
#
# ['An', 'unknown', 'gunman']
# 3
# The Obama administration fines Honda $70 million for failing to report deaths and injury complaints from 2003 to 2014. (KNTV)
#
# ['The', 'Obama', 'administration', 'fines', 'Honda', '$', '70', 'million', 'for', 'failing', 'to', 'report', 'deaths', 'and', 'injury', 'complaints', 'from', '2003', 'to', '2014', '.']
# 8
# Brunei officially bans all future public celebrations of Christmas
#
# ['Brunei']
# 5
# The US Olympic Committee chooses the city of Boston as the American bid city to host the 2024 Summer Olympics. (The New York Times)
#
# ['The', 'US', 'Olympic', 'Committee']
# 8
# Refugees flee Nigeria's Borno State following the Boko Haram massacre in the town of Baga. 7
#
# ['Refugees']
# 10
# The People's Republic of China plans to soon permit the online sale of prescription drugs. (Reuters)
#
# ['The', 'People', "'s", 'Republic', 'of', 'China']
# 8
# A 193-vehicle pileup along a snowy Interstate 94 highway in Kalamazoo County
#
# ['A', '193-vehicle', 'pileup', 'along', 'a', 'snowy', 'Interstate', '94', 'highway', 'in', 'Kalamazoo', 'County']
# 6
# Former Prime Minister of Thailand Yingluck Shinawatra appears to face impeachment charges over a failed rice subsidy scheme. (BBC)
#
# ['Former', 'Prime', 'Minister', 'of', 'Thailand', 'Yingluck', 'Shinawatra']
# 6
# Russia lists transsexual and transgender individuals among those with "personality and behavioural disorders" who will be banned from obtaining driving licenses. (BBC) (The Moscow Times)
#
# ['Russia']
# 11
# A shooting into a car in San Francisco
#
# ['A', 'shooting']
# 4
# Barack Obama proposes a new program to waive tuition at community colleges in the United States for the first two years. (The New York Times)
#
# ['Barack', 'Obama']
# 8
# Stockholm University cuts its ties with the Confucius Institute citing concerns about foreign interference in academic freedom. (South China Morning Post)
#
# ['Stockholm', 'University']
# 8
# The Lovejoy Comet enters its brightest phase to roughly magnitude 4 or 5. (Sydney Morning Herald)
#
# ['The', 'Lovejoy', 'Comet']
# 5
# The AFC Asian Cup holds the opening ceremony
#
# ['The', 'AFC', 'Asian', 'Cup']
# 3
# A suicide bomb attack on a Shiite mosque in Rawalpindi
#
# ['A', 'suicide', 'bomb', 'attack', 'on', 'a', 'Shiite', 'mosque', 'in', 'Rawalpindi']
# 8
# A suicide attack by al-Nusra Front (al-Qaeda's official affiliate in Syria) at a café in Tripoli
#
# ['A', 'suicide', 'attack', 'by', 'al-Nusra', 'Front', '-LRB-', 'al-Qaeda', "'s", 'official', 'affiliate', 'in', 'Syria', '-RRB-', 'at', 'a', 'café', 'in', 'Tripoli']
# 15
# A traffic accident between an oil tanker truck and passenger coach en route to Shikarpur from Karachi on the Pakistan National Highway Link Road near Gulshan-e-Hadeed
#
# ['A', 'traffic', 'accident', 'between', 'an', 'oil', 'tanker', 'truck', 'and', 'passenger', 'coach', 'en', 'route', 'to', 'Shikarpur']
# 11
# A bomb threat on Tigerair Flight 539 at Melbourne Airport
#
# ['A', 'bomb', 'threat', 'on', 'Tigerair', 'Flight', '539', 'at', 'Melbourne', 'Airport']
# 8
# A mass poisoning at a funeral in Mozambique involves beer that was deliberately contaminated with crocodile bile leaving at least 56 dead and 146 hospitailized. (FOX8LIVE)
#
# ['A', 'mass', 'poisoning', 'at', 'a', 'funeral', 'in', 'Mozambique']
# 13
# SpaceX successfully launches a Falcon 9 rocket from Cape Canaveral
#
# ['SpaceX']
# 5
# The Golden Gate Bridge Highway and Transportation District temporarily closes the Golden Gate Bridge until Monday to install a $30 million moveable barrier between opposite traffic flows. (SF Gate)
#
# ['The', 'Golden', 'Gate', 'Bridge', 'Highway', 'and', 'Transportation', 'District']
# 7
# Thousands of police and military personnel prepare to secure a Paris unity rally with up to a million people expected to attend. (Daily Mail)
#
# ['Thousands', 'of', 'police', 'and', 'military', 'personnel']
# 8
# Divers retrieve the flight data recorder from the crashed jet. (AP)
#
# ['Divers']
# 5
# The death toll from the Karachi traffic accident rises to 62. (Indian Express)
#
# ['The', 'death', 'toll', 'from', 'the', 'Karachi', 'traffic', 'accident']
# 5
# Public photographs become available of SpaceX's Falcon 9 rocket after the experimental recovery attempt of the first stage fails and crash-lands on a floating platform in the SpaceX CRS-5 resupply mission. (Space Flight Now)
#
# ['Public', 'photographs']
# 12
# Apparent ISIL computer hackers attack the feeds for the United States Central Command for Twitter and YouTube. (Reuters)
#
# ['Apparent', 'ISIL', 'computer', 'hackers']
# 6
# Cameroon kills 143 Boko Haram fighters in clashes. (Reuters)
#
# ['Cameroon']
# 5
# The eruption of the Hunga Tonga volcano disrupts flights to and from Tonga. (Radio New Zealand)
#
# ['The', 'eruption', 'of', 'the', 'Hunga', 'Tonga', 'volcano']
# 6
# A school bus plunges off of a cliff on the Caribbean island of St. Vincent leaving at least five people dead and two missing. (AP)
#
# ['A', 'school', 'bus']
# 12

# %%
df
# Out:
#       index                                                _id  \
# 0         0               ObjectId("5d056c5bb5f3a01b25e85fd2")
# 1         1               ObjectId("5d056c5bb5f3a01b25e85fd3")
# 2         2               ObjectId("5d056c5bb5f3a01b25e85fd4")
# 3         3               ObjectId("5d056c5bb5f3a01b25e85fd5")
# 4         4               ObjectId("5d056c5bb5f3a01b25e85fd6")
# 5         5               ObjectId("5d056c5bb5f3a01b25e85fd7")
# 6         6               ObjectId("5d056c5bb5f3a01b25e85fd8")
# 7         8               ObjectId("5d056c5bb5f3a01b25e85fda")
# 8         9               ObjectId("5d056c5bb5f3a01b25e85fdb")
# 9        11               ObjectId("5d056c5bb5f3a01b25e85fdd")
# 10       12               ObjectId("5d056c5bb5f3a01b25e85fde")
# 11       13               ObjectId("5d056c5bb5f3a01b25e85fdf")
# 12       14               ObjectId("5d056c5bb5f3a01b25e85fe0")
# 13       15               ObjectId("5d056c5bb5f3a01b25e85fe1")
# 14       17               ObjectId("5d056c5bb5f3a01b25e85fe3")
# 15       20               ObjectId("5d056c5bb5f3a01b25e85fe6")
# 16       23               ObjectId("5d056c5bb5f3a01b25e85fe7")
# 17       24               ObjectId("5d056c5bb5f3a01b25e85fe8")
# 18       25               ObjectId("5d056c5bb5f3a01b25e85fe9")
# 19       26               ObjectId("5d056c5bb5f3a01b25e85fea")
# 20       27               ObjectId("5d056c5bb5f3a01b25e85feb")
# 21       29               ObjectId("5d056c5bb5f3a01b25e85fed")
# 22       30               ObjectId("5d056c5bb5f3a01b25e85fee")
# 23       32               ObjectId("5d056c5bb5f3a01b25e85ff0")
# 24       33               ObjectId("5d056c5bb5f3a01b25e85ff1")
# 25       34               ObjectId("5d056c5bb5f3a01b25e85ff2")
# 26       35               ObjectId("5d056c5bb5f3a01b25e85ff3")
# 27       36               ObjectId("5d056c5bb5f3a01b25e85ff4")
# 28       37               ObjectId("5d056c5bb5f3a01b25e85ff5")
# 29       38               ObjectId("5d056c5bb5f3a01b25e85ff6")
# ...     ...                                                ...
# 9457  12771               ObjectId("5d056c7ab5f3a01b25e88dac")
# 9458  12772               ObjectId("5d056c7ab5f3a01b25e88dad")
# 9459  12773               ObjectId("5d056c7ab5f3a01b25e88dae")
# 9460  12774               ObjectId("5d056c7ab5f3a01b25e88daf")
# 9461  12775  Five Russian warplanes bombard the city of al-...
# 9462  12776               ObjectId("5d056c7ab5f3a01b25e88db0")
# 9463  12777               ObjectId("5d056c7ab5f3a01b25e88db1")
# 9464  12779  The United States Department of Homeland Secur...
# 9465  12781               ObjectId("5d056c7ab5f3a01b25e88db4")
# 9466  12782               ObjectId("5d056c7ab5f3a01b25e88db5")
# 9467  12784               ObjectId("5d056c7ab5f3a01b25e88db7")
# 9468  12786  Iraq's prime minister has demanded the Kurdist...
# 9469  12788               ObjectId("5d056c7ab5f3a01b25e88dba")
# 9470  12791               ObjectId("5d056c7ab5f3a01b25e88dbd")
# 9471  12798               ObjectId("5d056c7ab5f3a01b25e88dc4")
# 9472  12799               ObjectId("5d056c7ab5f3a01b25e88dc5")
# 9473  12800               ObjectId("5d056c7ab5f3a01b25e88dc6")
# 9474  12801               ObjectId("5d056c7ab5f3a01b25e88dc7")
# 9475  12803               ObjectId("5d056c7ab5f3a01b25e88dc9")
# 9476  12805               ObjectId("5d056c7ab5f3a01b25e88dcb")
# 9477  12806               ObjectId("5d056c7ab5f3a01b25e88dcc")
# 9478  12807  Reverberations from the Sun Zhengcai case are ...
# 9479  12808               ObjectId("5d056c7ab5f3a01b25e88dcd")
# 9480  12810               ObjectId("5d056c7ab5f3a01b25e88dcf")
# 9481  12811               ObjectId("5d056c7ab5f3a01b25e88dd0")
# 9482  12812               ObjectId("5d056c7ab5f3a01b25e88dd1")
# 9483  12813               ObjectId("5d056c7ab5f3a01b25e88dd2")
# 9484  12814               ObjectId("5d056c7ab5f3a01b25e88dd3")
# 9485  12815               ObjectId("5d056c7ab5f3a01b25e88dd4")
# 9486  12816               ObjectId("5d056c7ab5f3a01b25e88dd5")
#
#                                                    date  \
# 0                            2015-01-01T00:00:00.000Z""
# 1                            2015-01-01T00:00:00.000Z""
# 2                            2015-01-01T00:00:00.000Z""
# 3                            2015-01-01T00:00:00.000Z""
# 4                            2015-01-01T00:00:00.000Z""
# 5                            2015-01-01T00:00:00.000Z""
# 6                            2015-01-01T00:00:00.000Z""
# 7                            2015-01-02T00:00:00.000Z""
# 8                            2015-01-02T00:00:00.000Z""
# 9                            2015-01-02T00:00:00.000Z""
# 10                           2015-01-02T00:00:00.000Z""
# 11                           2015-01-03T00:00:00.000Z""
# 12                           2015-01-03T00:00:00.000Z""
# 13                           2015-01-03T00:00:00.000Z""
# 14                           2015-01-03T00:00:00.000Z""
# 15                           2015-01-04T00:00:00.000Z""
# 16                           2015-01-04T00:00:00.000Z""
# 17                           2015-01-04T00:00:00.000Z""
# 18                           2015-01-04T00:00:00.000Z""
# 19                           2015-01-04T00:00:00.000Z""
# 20                           2015-01-04T00:00:00.000Z""
# 21                           2015-01-05T00:00:00.000Z""
# 22                           2015-01-05T00:00:00.000Z""
# 23                           2015-01-05T00:00:00.000Z""
# 24                           2015-01-05T00:00:00.000Z""
# 25                           2015-01-05T00:00:00.000Z""
# 26                           2015-01-05T00:00:00.000Z""
# 27                           2015-01-05T00:00:00.000Z""
# 28                           2015-01-05T00:00:00.000Z""
# 29                           2015-01-05T00:00:00.000Z""
# ...                                                 ...
# 9457                         2017-09-26T00:00:00.000Z""
# 9458                         2017-09-26T00:00:00.000Z""
# 9459                         2017-09-26T00:00:00.000Z""
# 9460                         2017-09-27T00:00:00.000Z""
# 9461                                              bombs
# 9462                         2017-09-27T00:00:00.000Z""
# 9463                         2017-09-27T00:00:00.000Z""
# 9464                            [/wiki/Hurricane_Maria"
# 9465                         2017-09-27T00:00:00.000Z""
# 9466                         2017-09-27T00:00:00.000Z""
# 9467                         2017-09-27T00:00:00.000Z""
# 9468                          [/wiki/Iraqi_Kurdistan"]"
# 9469                         2017-09-27T00:00:00.000Z""
# 9470                         2017-09-28T00:00:00.000Z""
# 9471                         2017-09-28T00:00:00.000Z""
# 9472                         2017-09-29T00:00:00.000Z""
# 9473                         2017-09-29T00:00:00.000Z""
# 9474                         2017-09-29T00:00:00.000Z""
# 9475                         2017-09-29T00:00:00.000Z""
# 9476                         2017-09-29T00:00:00.000Z""
# 9477                         2017-09-29T00:00:00.000Z""
# 9478   including former Organization Department head...
# 9479                         2017-09-29T00:00:00.000Z""
# 9480                         2017-09-30T00:00:00.000Z""
# 9481                         2017-09-30T00:00:00.000Z""
# 9482                         2017-09-30T00:00:00.000Z""
# 9483                         2017-09-30T00:00:00.000Z""
# 9484                         2017-09-30T00:00:00.000Z""
# 9485                         2017-09-30T00:00:00.000Z""
# 9486                         2017-09-30T00:00:00.000Z""
#
#                          category  \
# 0     Armed conflicts and attacks
# 1     Armed conflicts and attacks
# 2            Business and economy
# 3            Business and economy
# 4         International relations
# 5         International relations
# 6                   Law and crime
# 7     Armed conflicts and attacks
# 8     Armed conflicts and attacks
# 9         Disasters and accidents
# 10        International relations
# 11    Armed conflicts and attacks
# 12               Arts and culture
# 13        Disasters and accidents
# 14        Disasters and accidents
# 15    Armed conflicts and attacks
# 16    Armed conflicts and attacks
# 17    Armed conflicts and attacks
# 18    Armed conflicts and attacks
# 19        Disasters and accidents
# 20                       Religion
# 21    Armed conflicts and attacks
# 22    Armed conflicts and attacks
# 23    Armed conflicts and attacks
# 24    Armed conflicts and attacks
# 25               Arts and culture
# 26               Arts and culture
# 27         Business and economics
# 28         Business and economics
# 29        Disasters and accidents
# ...                           ...
# 9457       Politics and elections
# 9458       Politics and elections
# 9459       Science and technology
# 9460  Armed conflicts and attacks
# 9461   and Bunker-Buster missiles
# 9462  Armed conflicts and attacks
# 9463  Armed conflicts and attacks
# 9464            /wiki/Outer_Banks
# 9465                Law and crime
# 9466                Law and crime
# 9467       Politics and elections
# 9468                        FALSE
# 9469       Politics and elections
# 9470  Armed conflicts and attacks
# 9471       Science and technology
# 9472  Armed conflicts and attacks
# 9473      Disasters and accidents
# 9474      Disasters and accidents
# 9475      International relations
# 9476       Politics and elections
# 9477       Politics and elections
# 9478         [/wiki/Sun_Zhengcai"
# 9479       Science and technology
# 9480      Disasters and accidents
# 9481      Disasters and accidents
# 9482      Disasters and accidents
# 9483      International relations
# 9484       Politics and elections
# 9485       Politics and elections
# 9486                       Sports
#
#                                             event_title  \
# 0                          [/wiki/Terrorism_in_Yemen"]"
# 1                                                 FALSE
# 2                                                 FALSE
# 3                                                 FALSE
# 4                                                 FALSE
# 5                                                 FALSE
# 6                                                 FALSE
# 7     [/wiki/Somali_Civil_War_(2009%E2%80%93present)"]"
# 8              [/wiki/Islamist_insurgency_in_Nigeria"]"
# 9                                                 FALSE
# 10    [/wiki/North_Korea%E2%80%93United_States_relat...
# 11                                 [/wiki/Boko_Haram"]"
# 12                                                FALSE
# 13                                                FALSE
# 14                                                FALSE
# 15                 [/wiki/War_in_North-West_Pakistan"]"
# 16                     [/wiki/Northern_Mali_conflict"]"
# 17                   [/wiki/Shia_insurgency_in_Yemen"]"
# 18                           [/wiki/Somali_Civil_War"]"
# 19                                                FALSE
# 20                                                FALSE
# 21    [/wiki/Libyan_Civil_War_(2014%E2%80%93present)"]"
# 22                                 [/wiki/Boko_Haram"]"
# 23                                                FALSE
# 24                                                FALSE
# 25                                                FALSE
# 26                                                FALSE
# 27                                                FALSE
# 28                                                FALSE
# 29                                                FALSE
# ...                                                 ...
# 9457                       [/wiki/Politics_of_Russia"]"
# 9458               [/wiki/Presidency_of_Donald_Trump"]"
# 9459                               [/wiki/Green_wall"]"
# 9460                         [/wiki/Syrian_Civil_War"]"
# 9461   wounding several civilians and causing a sign...
# 9462   [/wiki/Russia_and_weapons_of_mass_destruction"]"
# 9463  [/wiki/2017_Kalynivka_ammunition_depot_explosi...
# 9464                               /wiki/North_Carolina
# 9465                   [/wiki/Politics_of_Uzbekistan"]"
# 9466                     [/wiki/Politics_of_Thailand"]"
# 9467      [/wiki/Abortion_in_the_Republic_of_Ireland"]"
# 9468  [https://www.independent.co.uk/news/world/midd...
# 9469       [/wiki/United_States_presidential_primary"]"
# 9470                         [/wiki/Syrian_Civil_War"]"
# 9471  [/wiki/Aftermath_of_the_2011_T%C5%8Dhoku_earth...
# 9472  [/wiki/Somali_Civil_War_(2009%E2%80%93present)"]"
# 9473                     [/wiki/2017_Mumbai_stampede"]"
# 9474           [/wiki/2017_Central_Mexico_earthquake"]"
# 9475     [/wiki/Cuba%E2%80%93United_States_relations"]"
# 9476               [/wiki/Presidency_of_Donald_Trump"]"
# 9477  [/wiki/Anti-corruption_campaign_under_Xi_Jinpi...
# 9478                     /wiki/Communist_Party_of_China
# 9479                             [/wiki/Gene_therapy"]"
# 9480                          [/wiki/2017_in_Romania"]"
# 9481  [/wiki/2017_in_the_Democratic_Republic_of_the_...
# 9482                           [/wiki/Human_stampede"]"
# 9483              [/wiki/Foreign_relations_of_Thailand"
# 9484      [/wiki/Abortion_in_the_Republic_of_Ireland"]"
# 9485                         [/wiki/Nazism_in_Sweden"]"
# 9486                     [/wiki/2017_AFL_Grand_Final"]"
#
#                                           event_summary  \
# 0          The death toll of the suicide bombing in Ibb
# 1     A shooting kills one and injures six people in...
# 2     Lithuania adopts the euro as its official curr...
# 3     U.S. fast-food restaurant chain Chick-fil-A wa...
# 4     The Palestine Authority signs a treaty to join...
# 5            The Eurasian Economic Union between Russia
# 6           Vietnam’s new marriage law goes into effect
# 7     Somali al-Shabaab militants attack an army bas...
# 8             Boko Haram militants attack a bus in Waza
# 9     The MS Norman Atlantic ferry fire death toll r...
# 10    The United States enacts more sanctions on Nor...
# 11    Fleeing villagers from a remote part of the Bo...
# 12    Turkey permits the building of a Syriac church...
# 13    The Singapore-registered cargo ship MV Höegh O...
# 14    The Cypriot-registered cargo ship Cemfjord sin...
# 15    A U.S. drone strike kills eight Uzbek people c...
# 16    A vehicle carrying United Nations peacekeepers...
# 17    A bombing at a local Houthi movement headquart...
# 18    A suicide car bomber detonates near a military...
# 19             A six-story building collapse in Nairobi
# 20    Pope Francis announces the appointment of 20 n...
# 21    A Libyan warplane bombs a Greek-operated oil t...
# 22    News emerges that two days prior hundreds of B...
# 23    Bangladeshi police report that two opposition ...
# 24    A suicide car bomber hits the headquarters of ...
# 25    A Czech archaeological team discovers the tomb...
# 26             The site where Jesus may have been tried
# 27    China relaxes controls over the export of rare...
# 28    Ireland becomes the first European nation to b...
# 29    For the second day in a row a multi-story resi...
# ...                                                 ...
# 9457  Russian President Vladimir Putin dismisses Niz...
# 9458  Acting U.S. Drug Enforcement Administration ch...
# 9459  Africa's Great Green Wall is successfully reve...
# 9460  Russian aircraft carry out air strikes on the ...
# 9461   and causing large number of civilians to flee...
# 9462  Russia announces it has completed the destruct...
# 9463  Thirty thousand people are evacuated from Kaly...
# 9464  /wiki/United_States_Department_of_Homeland_Sec...
# 9465  Uzbekistan dissident writer Nurulloh Muhammad ...
# 9466  Former Thai Prime Minister Yingluck Shinawatra...
# 9467  The Republic of Ireland announces a referendum...
# 9468  https://www.bbc.com/news/world-middle-east-414...
# 9469  California moves its 2020 presidential primary...
# 9470  The Islamic State of Iraq and the Levant relea...
# 9471  Aquatic species from Japan hitched a ride on d...
# 9472  Al-Shabaab militants attack a military base ou...
# 9473  At least 22 people are killed and over 30 are ...
# 9474  A Mexico City borough president says previous ...
# 9475  The U.S. State Department removes all families...
# 9476  Tom Price resigns as the Secretary of Health a...
# 9477  Sun Zhengcai is expelled from the Communist Pa...
# 9478  /wiki/Central_Commission_for_Discipline_Inspec...
# 9479  The journal Protein & Cell publishes Sun Yat-s...
# 9480           A fire at a retirement home in Bucharest
# 9481  A military transport plane crashes after take-...
# 9482  A crowd surge collapses a barrier during a soc...
# 9483  /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 9484  Tens of thousands of protesters march through ...
# 9485  About 600 members of the Swedish neo-Nazi grou...
# 9486  The Australian rules football club Richmond Fo...
#
#                                                entities  \
# 0                                                 Yemen
# 1                                               Calgary
# 2       becoming the 19th member of the Eurozone. (CNN)
# 3            000 customers in five states. (Daily Mail)
# 4                                 [Palestine Authority"
# 5                                            Kazakhstan
# 6      abolishing regulations that “prohibit marriag...
# 7      killing seven soldiers. (Reuters via Daily Ti...
# 8                                              Cameroon
# 9                                [MS Norman Atlantic"]"
# 10                                  [/wiki/North_Korea"
# 11                                [/wiki/Borno_State"]"
# 12     the first construction of a Christian house o...
# 13     in the entrance to Southampton Water. (BBC News)
# 14                                             [Cyprus"
# 15                                                  NaN
# 16                     injuring six soldiers. (Reuters)
# 17                                                Yemen
# 18                                              Somalia
# 19                                                Kenya
# 20     many of them coming from outside of Europe. (...
# 21                                  killing two sailors
# 22                                      [/wiki/Nigeria"
# 23                                  [Bangladesh Police"
# 24                                          Afghanistan
# 25                                       [Czech people"
# 26                             prior to his crucifixion
# 27                                              [China"
# 28                                [Republic of Ireland"
# 29                                                Kenya
# ...                                                 ...
# 9457   the second governor to lose his job in a week...
# 9458                                   effective Oct. 1
# 9459                           [/wiki/Great_Green_Wall"
# 9460                in the western countryside of Idlib
# 9461                                     [/wiki/Russia"
# 9462                                     [/wiki/Russia"
# 9463                                            Ukraine
# 9464                  /wiki/Merchant_Marine_Act_of_1920
# 9465                                 [/wiki/Uzbekistan"
# 9466                                   [/wiki/Thailand"
# 9467                        [/wiki/Republic_of_Ireland"
# 9468                                                NaN
# 9469   making it  fifth in the nominating process af...
# 9470       [/wiki/Islamic_State_of_Iraq_and_the_Levant"
# 9471                                      [/wiki/Japan"
# 9472          with 15 soldiers reported dead. (Reuters)
# 9473                                             (NDTV)
# 9474                              [/wiki/Mexico_City"]"
# 9475          [/wiki/United_States_Department_of_State"
# 9476            [/wiki/Tom_Price_(American_politician)"
# 9477                                                NaN
# 9478                                              FALSE
# 9479   this study demonstrated the feasibility of cu...
# 9480                                            Romania
# 9481                   Democratic Republic of the Congo
# 9482                                             France
# 9483  Thailand's Ministry of Foreign Affairs says it...
# 9484   and anti-abortion activists stage counter-dem...
# 9485                                             and 10
# 9486                                    (ABC Australia)
#
#                                                  person  \
# 0      that occurred on December 31 rises to 49 with...
# 1                                                Canada
# 2                              [Lithuania and the euro"
# 3                                       [Chick-fil-A"]"
# 4                        International Criminal Court]"
# 5                                               Belarus
# 6                                             [Vietnam"
# 7                                       [/wiki/Somalia"
# 8      killing eleven people and injuring six. (CNN ...
# 9                                                 FALSE
# 10               /wiki/Sony_Pictures_Entertainment_hack
# 11                                                FALSE
# 12                                             [Turkey"
# 13                                          [Singapore"
# 14                                          MV Cemfjord
# 15                                                  NaN
# 16                               [/wiki/United_Nations"
# 17     kills five people and wounds 25. (AP via The ...
# 18                           killing four people. (BBC)
# 19     kills one person and leaves several others in...
# 20                                       [Pope Francis"
# 21     one Greek and one Romanian. The Greek governm...
# 22                                /wiki/Baga,_Nigeria]"
# 23                         Bangladesh Nationalist Party
# 24     killing one person and injuring five others. ...
# 25                                        Ancient Egypt
# 26     opens to the public for the first time locate...
# 27                                   Rare earth element
# 28                                               Europe
# 29                                            collapses
# ...                                                 ...
# 9457                        [/wiki/President_of_Russia"
# 9458   after more than two years in the position. (U...
# 9459                            /wiki/Desertification]"
# 9460   killing a child and injuring 5 others. (Iraqi...
# 9461                        /wiki/Christianity_in_Syria
# 9462                             /wiki/Chemical_weapons
# 9463   following an explosion in an ammunition dump ...
# 9464                                /wiki/Puerto_Rico]"
# 9465                               /wiki/Central_Asia]"
# 9466                          /wiki/Yingluck_Shinawatra
# 9467                                   /wiki/Abortion]"
# 9468                                                NaN
# 9469                                      New Hampshire
# 9470                       /wiki/Abu_Bakr_al-Baghdadi]"
# 9471      /wiki/2011_T%C5%8Dhoku_earthquake_and_tsunami
# 9472                [/wiki/Al-Shabaab_(militant_group)"
# 9473                      [/wiki/Parel_railway_station"
# 9474                                              FALSE
# 9475                                 /wiki/Sonic_weapon
# 9476     /wiki/Secretary_of_Health_and_Human_Services]"
# 9477                                                NaN
# 9478  [https://www.washingtonpost.com/world/asia_pac...
# 9479                                   (Protein & Cell)
# 9480   leaves one person dead and 19 others injured....
# 9481   killing all 12 Russian crew members. (Deutsch...
# 9482                        injuring twenty-nine people
# 9483                                   [/wiki/Thailand"
# 9484                                     [/wiki/Dublin"
# 9485  000 people hold a counter-demonstration. More ...
# 9486                  [/wiki/Australian_rules_football"
#
#                                           external_link  \
# 0                              [/wiki/2014_Ibb_bombing"
# 1        with police making no arrests. (National Post)
# 2                                            Eurozone]"
# 3                                                 FALSE
# 4                                                 FALSE
# 5      Kyrgyzstan and Armenia comes into effect (Nov...
# 6                        Same-sex marriage in Vietnam]"
# 7                     /wiki/Al-Shabaab_(militant_group)
# 8                                    [/wiki/Boko_Haram"
# 9     [http://www.independent.ie/world-news/europe/i...
# 10                                           /wiki/Sony
# 11    [https://www.bbc.com/news/world-africa-3066601...
# 12                                  Assyrians in Turkey
# 13                                       MV Höegh Osaka
# 14                                           Scotland]"
# 15                                                  NaN
# 16                                         /wiki/Mali]"
# 17                                      [/wiki/Houthis"
# 18                                    [/wiki/Mogadishu"
# 19                                            [Nairobi"
# 20                         Cardinals created by Francis
# 21                                        [/wiki/Libya"
# 22                                                FALSE
# 23                                         Awami League
# 24                                  [EUPOL Afghanistan"
# 25                                     Khentakawess III
# 26                                        called Kishle
# 27                                        United States
# 28                                        United States
# 29                        this time an 8-story building
# ...                                                 ...
# 9457                               /wiki/Vladimir_Putin
# 9458            [/wiki/Drug_Enforcement_Administration"
# 9459                                              FALSE
# 9460                                                NaN
# 9461                                      /wiki/Idlib]"
# 9462                /wiki/Chemical_Weapons_Convention]"
# 9463                                   [/wiki/Kalynivka
# 9464                                              FALSE
# 9465                                              FALSE
# 9466                                /wiki/In_absentia]"
# 9467                                              FALSE
# 9468                                                NaN
# 9469                                             Nevada
# 9470                                              FALSE
# 9471            /wiki/West_Coast_of_the_United_States]"
# 9472                                      /wiki/Somalia
# 9473             /wiki/Elphinstone_Road_railway_station
# 9474  [https://www.apnews.com/4d56fc67f60d47c3874a43...
# 9475         /wiki/Embassy_of_the_United_States,_Havana
# 9476                                              FALSE
# 9477                                                NaN
# 9478  http://www.scmp.com/news/china/policies-politi...
# 9479                           [/wiki/Protein_%26_Cell"
# 9480                                  [/wiki/Bucharest"
# 9481                          [/wiki/N%27djili_Airport"
# 9482    five of them seriously. (AFP via Yahoo! Sports)
# 9483       /wiki/Ministry_of_Foreign_Affairs_(Thailand)
# 9484                                   /wiki/Pro-choice
# 9485                                     [/wiki/Sweden"
# 9486                       /wiki/Richmond_Football_Club
#
#                                              Unnamed: 8  ... Nounphrases20  \
# 0                                             /wiki/Ibb  ...    NULL VALUE
# 1                                            [Killarney  ...    NULL VALUE
# 2                                                 FALSE  ...    NULL VALUE
# 3     [http://www.dailymail.co.uk/news/article-28936...  ...    NULL VALUE
# 4     [https://www.wsj.com/articles/abbas-oks-palest...  ...    NULL VALUE
# 5                             [Eurasian Economic Union"  ...    NULL VALUE
# 6                                                 FALSE  ...    NULL VALUE
# 7                                        /wiki/Baidoa]"  ...    NULL VALUE
# 8                              /wiki/Waza_National_Park  ...    NULL VALUE
# 9                                                   NaN  ...    NULL VALUE
# 10         /wiki/North_Korean_Special_Operation_Force]"  ...    NULL VALUE
# 11                                                  NaN  ...    NULL VALUE
# 12                                    Church (building)  ...    NULL VALUE
# 13                                        Isle of Wight  ...    NULL VALUE
# 14                                                FALSE  ...    NULL VALUE
# 15                                                  NaN  ...    NULL VALUE
# 16                                                FALSE  ...    NULL VALUE
# 17                             /wiki/Dhamar_Governorate  ...    NULL VALUE
# 18                                      /wiki/Somalia]"  ...    NULL VALUE
# 19                                              Kenya]"  ...    NULL VALUE
# 20                               Cardinal (Catholicism)  ...    NULL VALUE
# 21                                   /wiki/Derna,_Libya  ...    NULL VALUE
# 22    [https://www.wsj.com/articles/boko-haram-overr...  ...    NULL VALUE
# 23                                               Natore  ...    NULL VALUE
# 24                                                Kabul  ...    NULL VALUE
# 25                             Fifth Dynasty of Egypt]"  ...    NULL VALUE
# 26     that is part of the Tower of David Museum gro...  ...    NULL VALUE
# 27                           World Trade Organization]"  ...    NULL VALUE
# 28                   Bovine spongiform encephalopathy]"  ...    NULL VALUE
# 29     killing one person with eight people still mi...  ...    NULL VALUE
# ...                                                 ...  ...           ...
# 9457                       /wiki/Nizhny_Novgorod_Oblast  ...    NULL VALUE
# 9458                            /wiki/Chuck_Rosenberg]"  ...    NULL VALUE
# 9459  [https://www.bbc.com/news/av/magazine-41391844...  ...    NULL VALUE
# 9460                                                NaN  ...    NULL VALUE
# 9461                                              FALSE  ...    NULL VALUE
# 9462                                              FALSE  ...    NULL VALUE
# 9463                                 _Vinnytsia_Oblast"  ...    NULL VALUE
# 9464  [http://abcnews.go.com/US/wireStory/north-caro...  ...    NULL VALUE
# 9465  [https://www.reuters.com/article/us-uzbekistan...  ...    NULL VALUE
# 9466                                              FALSE  ...    NULL VALUE
# 9467  [https://www.independent.co.uk/news/world/euro...  ...    NULL VALUE
# 9468                                                NaN  ...    NULL VALUE
# 9469   and South Carolina. The 2016 primary was held...  ...    NULL VALUE
# 9470  [http://www.latimes.com/world/la-fg-islamic-st...  ...    NULL VALUE
# 9471                                              FALSE  ...    NULL VALUE
# 9472                                    /wiki/Mogadishu  ...    NULL VALUE
# 9473                                        /wiki/India  ...    NULL VALUE
# 9474                                                NaN  ...    NULL VALUE
# 9475            /wiki/Federal_Bureau_of_Investigation]"  ...    NULL VALUE
# 9476  [http://www.cnn.com/2017/09/29/politics/tom-pr...  ...    NULL VALUE
# 9477                                                NaN  ...    NULL VALUE
# 9478                                                NaN  ...    NULL VALUE
# 9479                       /wiki/Sun_Yat-sen_University  ...    NULL VALUE
# 9480                                    /wiki/Romania]"  ...    NULL VALUE
# 9481                                     /wiki/Kinshasa  ...    NULL VALUE
# 9482                                     [/wiki/Soccer"  ...    NULL VALUE
# 9483                                /wiki/Rakhine_State  ...    NULL VALUE
# 9484                    /wiki/Irish_embassy_in_London]"  ...    NULL VALUE
# 9485                                     /wiki/Neo-Nazi  ...    NULL VALUE
# 9486                       /wiki/Adelaide_Football_Club  ...    NULL VALUE
#
#      Nounphrases21 Nounphrases22 Nounphrases23 Nounphrases24 Nounphrases25  \
# 0       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 1       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 2       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 3       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 4       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 5       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 6       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 7       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 8       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 10      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 11      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 12      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 13      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 14      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 15      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 16      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 17      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 18      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 19      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 20      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 21      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 22      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 23      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 24      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 25      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 26      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 27      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 28      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 29      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# ...            ...           ...           ...           ...           ...
# 9457    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9458    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9459    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9460    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9461    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9462    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9463    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9464    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9465    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9466    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9467    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9468    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9469    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9470    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9471    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9472    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9473    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9474    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9475    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9476    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9477    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9478    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9479    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9480    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9481    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9482    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9483    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9484    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9485    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9486    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
#
#      Nounphrases26 Nounphrases27 Nounphrases28 Nounphrases29
# 0       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 1       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 2       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 3       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 4       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 5       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 6       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 7       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 8       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9       NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 10      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 11      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 12      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 13      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 14      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 15      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 16      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 17      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 18      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 19      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 20      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 21      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 22      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 23      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 24      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 25      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 26      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 27      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 28      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 29      NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# ...            ...           ...           ...           ...
# 9457    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9458    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9459    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9460    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9461    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9462    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9463    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9464    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9465    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9466    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9467    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9468    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9469    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9470    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9471    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9472    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9473    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9474    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9475    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9476    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9477    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9478    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9479    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9480    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9481    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9482    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9483    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9484    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9485    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9486    NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
#
# [9487 rows x 90 columns]

# %%
df1=df[['event_summary','Nounphrases0','Nounphrases1','Nounphrases2','Nounphrases3','Nounphrases4','Nounphrases5','Nounphrases6','Nounphrases7','Nounphrases8','Nounphrases9','Nounphrases10','Nounphrases11','Nounphrases12','Nounphrases13','Nounphrases14','Nounphrases15','Nounphrases16','Nounphrases17','Nounphrases18','Nounphrases19']]

# %%
df1=df1.drop(df.index[range(100,9487)])

# %%
df1
# Out:
#                                         event_summary  \
# 0        The death toll of the suicide bombing in Ibb
# 1   A shooting kills one and injures six people in...
# 2   Lithuania adopts the euro as its official curr...
# 3   U.S. fast-food restaurant chain Chick-fil-A wa...
# 4   The Palestine Authority signs a treaty to join...
# 5          The Eurasian Economic Union between Russia
# 6         Vietnam’s new marriage law goes into effect
# 7   Somali al-Shabaab militants attack an army bas...
# 8           Boko Haram militants attack a bus in Waza
# 9   The MS Norman Atlantic ferry fire death toll r...
# 10  The United States enacts more sanctions on Nor...
# 11  Fleeing villagers from a remote part of the Bo...
# 12  Turkey permits the building of a Syriac church...
# 13  The Singapore-registered cargo ship MV Höegh O...
# 14  The Cypriot-registered cargo ship Cemfjord sin...
# 15  A U.S. drone strike kills eight Uzbek people c...
# 16  A vehicle carrying United Nations peacekeepers...
# 17  A bombing at a local Houthi movement headquart...
# 18  A suicide car bomber detonates near a military...
# 19           A six-story building collapse in Nairobi
# 20  Pope Francis announces the appointment of 20 n...
# 21  A Libyan warplane bombs a Greek-operated oil t...
# 22  News emerges that two days prior hundreds of B...
# 23  Bangladeshi police report that two opposition ...
# 24  A suicide car bomber hits the headquarters of ...
# 25  A Czech archaeological team discovers the tomb...
# 26           The site where Jesus may have been tried
# 27  China relaxes controls over the export of rare...
# 28  Ireland becomes the first European nation to b...
# 29  For the second day in a row a multi-story resi...
# ..                                                ...
# 70  Schools in the Midwestern and Northeast United...
# 71      An unknown gunman shoots dead Nerlita Ledesma
# 72  The Obama administration fines Honda $70 milli...
# 73  Brunei officially bans all future public celeb...
# 74  The US Olympic Committee chooses the city of B...
# 75  Refugees flee Nigeria's Borno State following ...
# 76  The People's Republic of China plans to soon p...
# 77  A 193-vehicle pileup along a snowy Interstate ...
# 78  Former Prime Minister of Thailand Yingluck Shi...
# 79  Russia lists transsexual and transgender indiv...
# 80             A shooting into a car in San Francisco
# 81  Barack Obama proposes a new program to waive t...
# 82  Stockholm University cuts its ties with the Co...
# 83  The Lovejoy Comet enters its brightest phase t...
# 84       The AFC Asian Cup holds the opening ceremony
# 85  A suicide bomb attack on a Shiite mosque in Ra...
# 86  A suicide attack by al-Nusra Front (al-Qaeda's...
# 87  A traffic accident between an oil tanker truck...
# 88  A bomb threat on Tigerair Flight 539 at Melbou...
# 89  A mass poisoning at a funeral in Mozambique in...
# 90  SpaceX successfully launches a Falcon 9 rocket...
# 91  The Golden Gate Bridge Highway and Transportat...
# 92  Thousands of police and military personnel pre...
# 93  Divers retrieve the flight data recorder from ...
# 94  The death toll from the Karachi traffic accide...
# 95  Public photographs become available of SpaceX'...
# 96  Apparent ISIL computer hackers attack the feed...
# 97  Cameroon kills 143 Boko Haram fighters in clas...
# 98  The eruption of the Hunga Tonga volcano disrup...
# 99  A school bus plunges off of a cliff on the Car...
#
#                                          Nounphrases0  \
# 0   ['The', 'death', 'toll', 'of', 'the', 'suicide...
# 1                                   ['A', 'shooting']
# 2                                       ['Lithuania']
# 3   ['U.S.', 'fast-food', 'restaurant', 'chain', '...
# 4   ['The', 'Palestine', 'Authority', 'signs', 'a'...
# 5            ['The', 'Eurasian', 'Economic', 'Union']
# 6         ['Vietnam', "'s", 'new', 'marriage', 'law']
# 7               ['Somali', 'al-Shabaab', 'militants']
# 8                      ['Boko', 'Haram', 'militants']
# 9   ['The', 'MS', 'Norman', 'Atlantic', 'ferry', '...
# 10                        ['The', 'United', 'States']
# 11  ['Fleeing', 'villagers', 'from', 'a', 'remote'...
# 12                                         ['Turkey']
# 13  ['The', 'Singapore-registered', 'cargo', 'ship...
# 14  ['The', 'Cypriot-registered', 'cargo', 'ship',...
# 15                   ['A', 'U.S.', 'drone', 'strike']
# 16  ['A', 'vehicle', 'carrying', 'United', 'Nation...
# 17  ['A', 'bombing', 'at', 'a', 'local', 'Houthi',...
# 18                  ['A', 'suicide', 'car', 'bomber']
# 19  ['A', 'six-story', 'building', 'collapse', 'in...
# 20                                ['Pope', 'Francis']
# 21  ['A', 'Libyan', 'warplane', 'bombs', 'a', 'Gre...
# 22                                           ['News']
# 23                          ['Bangladeshi', 'police']
# 24                  ['A', 'suicide', 'car', 'bomber']
# 25           ['A', 'Czech', 'archaeological', 'team']
# 26                                    ['The', 'site']
# 27                                          ['China']
# 28                                        ['Ireland']
# 29         ['the', 'second', 'day', 'in', 'a', 'row']
# ..                                                ...
# 70  ['Schools', 'in', 'the', 'Midwestern', 'and', ...
# 71                        ['An', 'unknown', 'gunman']
# 72  ['The', 'Obama', 'administration', 'fines', 'H...
# 73                                         ['Brunei']
# 74              ['The', 'US', 'Olympic', 'Committee']
# 75                                       ['Refugees']
# 76  ['The', 'People', "'s", 'Republic', 'of', 'Chi...
# 77  ['A', '193-vehicle', 'pileup', 'along', 'a', '...
# 78  ['Former', 'Prime', 'Minister', 'of', 'Thailan...
# 79                                         ['Russia']
# 80                                  ['A', 'shooting']
# 81                                ['Barack', 'Obama']
# 82                        ['Stockholm', 'University']
# 83                        ['The', 'Lovejoy', 'Comet']
# 84                     ['The', 'AFC', 'Asian', 'Cup']
# 85  ['A', 'suicide', 'bomb', 'attack', 'on', 'a', ...
# 86  ['A', 'suicide', 'attack', 'by', 'al-Nusra', '...
# 87  ['A', 'traffic', 'accident', 'between', 'an', ...
# 88  ['A', 'bomb', 'threat', 'on', 'Tigerair', 'Fli...
# 89  ['A', 'mass', 'poisoning', 'at', 'a', 'funeral...
# 90                                         ['SpaceX']
# 91  ['The', 'Golden', 'Gate', 'Bridge', 'Highway',...
# 92  ['Thousands', 'of', 'police', 'and', 'military...
# 93                                         ['Divers']
# 94  ['The', 'death', 'toll', 'from', 'the', 'Karac...
# 95                          ['Public', 'photographs']
# 96        ['Apparent', 'ISIL', 'computer', 'hackers']
# 97                                       ['Cameroon']
# 98  ['The', 'eruption', 'of', 'the', 'Hunga', 'Ton...
# 99                             ['A', 'school', 'bus']
#
#                                          Nounphrases1  \
# 0                                    ['The', 'death']
# 1                                             ['one']
# 2   ['the', 'euro', 'as', 'its', 'official', 'curr...
# 3        ['U.S.', 'fast-food', 'restaurant', 'chain']
# 4   ['The', 'Palestine', 'Authority', 'signs', 'a'...
# 5                                          ['Russia']
# 6                                   ['Vietnam', "'s"]
# 7                              ['an', 'army', 'base']
# 8                          ['a', 'bus', 'in', 'Waza']
# 9        ['The', 'MS', 'Norman', 'Atlantic', 'ferry']
# 10  ['more', 'sanctions', 'on', 'North', 'Korea', ...
# 11                           ['Fleeing', 'villagers']
# 12  ['the', 'building', 'of', 'a', 'Syriac', 'chur...
# 13  ['Bramble', 'Bank', 'off', 'the', 'coast', 'of...
# 14  ['the', 'northern', 'coast', 'of', 'Scotland',...
# 15                       ['eight', 'Uzbek', 'people']
# 16                                   ['A', 'vehicle']
# 17  ['A', 'bombing', 'at', 'a', 'local', 'Houthi',...
# 18     ['a', 'military', 'convoy', 'in', 'Mogadishu']
# 19                     ['A', 'six-story', 'building']
# 20  ['the', 'appointment', 'of', '20', 'new', 'Car...
# 21               ['A', 'Libyan', 'warplane', 'bombs']
# 22                                    ['two', 'days']
# 23  ['two', 'opposition', 'Bangladesh', 'Nationali...
# 24  ['the', 'headquarters', 'of', 'EUPOL', 'Afghan...
# 25  ['the', 'tomb', 'of', 'formerly', 'unknown', '...
# 26                                          ['Jesus']
# 27  ['controls', 'over', 'the', 'export', 'of', 'r...
# 28             ['the', 'first', 'European', 'nation']
# 29                           ['the', 'second', 'day']
# ..                                                ...
# 70                                        ['Schools']
# 71                             ['Nerlita', 'Ledesma']
# 72  ['The', 'Obama', 'administration', 'fines', 'H...
# 73  ['all', 'future', 'public', 'celebrations', 'o...
# 74                    ['the', 'city', 'of', 'Boston']
# 75  ['Nigeria', "'s", 'Borno', 'State', 'following...
# 76                ['The', 'People', "'s", 'Republic']
# 77                     ['A', '193-vehicle', 'pileup']
# 78                    ['Former', 'Prime', 'Minister']
# 79  ['transsexual', 'and', 'transgender', 'individ...
# 80                                       ['a', 'car']
# 81  ['a', 'new', 'program', 'to', 'waive', 'tuitio...
# 82                                    ['its', 'ties']
# 83                      ['its', 'brightest', 'phase']
# 84                     ['the', 'opening', 'ceremony']
# 85                                   ['A', 'suicide']
# 86       ['A', 'suicide', 'attack', 'by', 'al-Nusra']
# 87                       ['A', 'traffic', 'accident']
# 88  ['A', 'bomb', 'threat', 'on', 'Tigerair', 'Fli...
# 89                         ['A', 'mass', 'poisoning']
# 90  ['a', 'Falcon', '9', 'rocket', 'from', 'Cape',...
# 91                ['the', 'Golden', 'Gate', 'Bridge']
# 92                                      ['Thousands']
# 93  ['the', 'flight', 'data', 'recorder', 'from', ...
# 94                           ['The', 'death', 'toll']
# 95  ['available', 'of', 'SpaceX', "'s", 'Falcon', ...
# 96                                            ['the']
# 97  ['143', 'Boko', 'Haram', 'fighters', 'in', 'cl...
# 98                                ['The', 'eruption']
# 99  ['a', 'cliff', 'on', 'the', 'Caribbean', 'isla...
#
#                                          Nounphrases2  \
# 0   ['toll', 'of', 'the', 'suicide', 'bombing', 'i...
# 1                ['six', 'people', 'in', 'Killarney']
# 2                                     ['the', 'euro']
# 3                                     ['Chick-fil-A']
# 4          ['The', 'Palestine', 'Authority', 'signs']
# 5
# 6                                          ['effect']
# 7                ['the', 'outskirts', 'of', 'Baidoa']
# 8                                        ['a', 'bus']
# 9                           ['fire', 'death', 'toll']
# 10                              ['more', 'sanctions']
# 11                            ['a', 'remote', 'part']
# 12                                ['the', 'building']
# 13                                ['Bramble', 'Bank']
# 14                       ['the', 'northern', 'coast']
# 15                                       ['al-Qaeda']
# 16              ['United', 'Nations', 'peacekeepers']
# 17                                   ['A', 'bombing']
# 18                        ['a', 'military', 'convoy']
# 19                      ['collapse', 'in', 'Nairobi']
# 20                             ['the', 'appointment']
# 21           ['a', 'Greek-operated', 'oil', 'tanker']
# 22   ['hundreds', 'of', 'Boko', 'Haram', 'militants']
# 23                ['two', 'opposition', 'Bangladesh']
# 24                            ['the', 'headquarters']
# 25                                    ['the', 'tomb']
# 26
# 27                                       ['controls']
# 28                                           ['beef']
# 29                                       ['a', 'row']
# ..                                                ...
# 70  ['the', 'Midwestern', 'and', 'Northeast', 'Uni...
# 71
# 72        ['The', 'Obama', 'administration', 'fines']
# 73        ['all', 'future', 'public', 'celebrations']
# 74                                    ['the', 'city']
# 75                ['Nigeria', "'s", 'Borno', 'State']
# 76                            ['The', 'People', "'s"]
# 77  ['a', 'snowy', 'Interstate', '94', 'highway', ...
# 78             ['Thailand', 'Yingluck', 'Shinawatra']
# 79  ['transsexual', 'and', 'transgender', 'individ...
# 80                               ['San', 'Francisco']
# 81                                        ['tuition']
# 82                  ['the', 'Confucius', 'Institute']
# 83           ['roughly', 'magnitude', '4', 'or', '5']
# 84
# 85  ['bomb', 'attack', 'on', 'a', 'Shiite', 'mosqu...
# 86                         ['A', 'suicide', 'attack']
# 87  ['an', 'oil', 'tanker', 'truck', 'and', 'passe...
# 88                            ['A', 'bomb', 'threat']
# 89               ['a', 'funeral', 'in', 'Mozambique']
# 90                     ['a', 'Falcon', '9', 'rocket']
# 91                                         ['Monday']
# 92         ['police', 'and', 'military', 'personnel']
# 93              ['the', 'flight', 'data', 'recorder']
# 94          ['the', 'Karachi', 'traffic', 'accident']
# 95  ['SpaceX', "'s", 'Falcon', '9', 'rocket', 'aft...
# 96  ['the', 'United', 'States', 'Central', 'Comman...
# 97               ['143', 'Boko', 'Haram', 'fighters']
# 98               ['the', 'Hunga', 'Tonga', 'volcano']
# 99                                     ['a', 'cliff']
#
#                                          Nounphrases3  \
# 0                                            ['toll']
# 1                                   ['six', 'people']
# 2                     ['its', 'official', 'currency']
# 3                         ['a', 'security', 'breach']
# 4                                     ['a', 'treaty']
# 5                                          NULL VALUE
# 6
# 7                                ['the', 'outskirts']
# 8                                            ['Waza']
# 9   ['at', 'least', 'eleven', 'with', 'as', 'many'...
# 10               ['North', 'Korea', 'in', 'response']
# 11  ['the', 'Borno', 'State', 'report', 'that', 'B...
# 12        ['a', 'Syriac', 'church', 'in', 'Istanbul']
# 13  ['the', 'coast', 'of', 'the', 'Isle', 'of', 'W...
# 14  ['Scotland', 'leaving', 'eight', 'onboard', 'm...
# 15                                       ['Pakistan']
# 16  ['a', 'roadside', 'bomb', 'in', 'northern', 'M...
# 17  ['a', 'local', 'Houthi', 'movement', 'headquar...
# 18                                      ['Mogadishu']
# 19                                       ['collapse']
# 20                         ['20', 'new', 'Cardinals']
# 21                     ['the', 'city', 'of', 'Derna']
# 22                                       ['hundreds']
# 23              ['Nationalist', 'Party', 'activists']
# 24            ['EUPOL', 'Afghanistan', 'in', 'Kabul']
# 25  ['formerly', 'unknown', 'Ancient', 'Egyptian',...
# 26                                         NULL VALUE
# 27  ['the', 'export', 'of', 'rare', 'earth', 'elem...
# 28                        ['the', 'United', 'States']
# 29  ['a', 'multi-story', 'residential', 'building'...
# ..                                                ...
# 70                              ['the', 'Midwestern']
# 71                                         NULL VALUE
# 72  ['$', '70', 'million', 'for', 'failing', 'to',...
# 73                                      ['Christmas']
# 74                                         ['Boston']
# 75                                  ['Nigeria', "'s"]
# 76                                          ['China']
# 77      ['a', 'snowy', 'Interstate', '94', 'highway']
# 78                         ['impeachment', 'charges']
# 79  ['those', 'with', '``', 'personality', 'and', ...
# 80
# 81  ['community', 'colleges', 'in', 'the', 'United...
# 82                                       ['concerns']
# 83                           ['roughly', 'magnitude']
# 84                                         NULL VALUE
# 85                                 ['bomb', 'attack']
# 86                                       ['al-Nusra']
# 87  ['an', 'oil', 'tanker', 'truck', 'and', 'passe...
# 88                             ['Tigerair', 'Flight']
# 89                                   ['a', 'funeral']
# 90                              ['Cape', 'Canaveral']
# 91  ['a', '$', '30', 'million', 'moveable', 'barri...
# 92                   ['a', 'Paris', 'unity', 'rally']
# 93                          ['the', 'crashed', 'jet']
# 94                                             ['62']
# 95          ['SpaceX', "'s", 'Falcon', '9', 'rocket']
# 96  ['the', 'United', 'States', 'Central', 'Command']
# 97                                        ['clashes']
# 98                                        ['flights']
# 99  ['the', 'Caribbean', 'island', 'of', 'St.', 'V...
#
#                                          Nounphrases4  \
# 0          ['the', 'suicide', 'bombing', 'in', 'Ibb']
# 1                                       ['Killarney']
# 2
# 3            ['credit', 'card', 'details', 'of', '9']
# 4       ['the', 'International', 'Criminal', 'Court']
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          ['Baidoa']
# 8
# 9                           ['at', 'least', 'eleven']
# 10                                 ['North', 'Korea']
# 11                ['the', 'Borno', 'State', 'report']
# 12                          ['a', 'Syriac', 'church']
# 13                                   ['the', 'coast']
# 14                                       ['Scotland']
# 15
# 16                          ['a', 'roadside', 'bomb']
# 17                          ['Dhamar', 'Governorate']
# 18
# 19                                        ['Nairobi']
# 20
# 21                                    ['the', 'city']
# 22                     ['Boko', 'Haram', 'militants']
# 23  ['clashes', 'with', 'members', 'of', 'the', 'r...
# 24                           ['EUPOL', 'Afghanistan']
# 25                            ['formerly', 'unknown']
# 26                                         NULL VALUE
# 27                                  ['the', 'export']
# 28  ['the', 'mad', 'cow', 'disease', 'scare', '15'...
# 29    ['a', 'multi-story', 'residential', 'building']
# ..                                                ...
# 70                  ['Northeast', 'United', 'States']
# 71                                         NULL VALUE
# 72                             ['$', '70', 'million']
# 73
# 74                 ['the', 'American', 'bid', 'city']
# 75  ['the', 'Boko', 'Haram', 'massacre', 'in', 'th...
# 76  ['the', 'online', 'sale', 'of', 'prescription'...
# 77                            ['Kalamazoo', 'County']
# 78       ['a', 'failed', 'rice', 'subsidy', 'scheme']
# 79                                          ['those']
# 80                                         NULL VALUE
# 81                          ['community', 'colleges']
# 82  ['foreign', 'interference', 'in', 'academic', ...
# 83
# 84                                         NULL VALUE
# 85      ['a', 'Shiite', 'mosque', 'in', 'Rawalpindi']
# 86  ['Front', '-LRB-', 'al-Qaeda', "'s", 'official...
# 87                                          ['route']
# 88              ['539', 'at', 'Melbourne', 'Airport']
# 89                                     ['Mozambique']
# 90
# 91  ['a', '$', '30', 'million', 'moveable', 'barri...
# 92  ['up', 'to', 'a', 'million', 'people', 'expect...
# 93
# 94
# 95                                   ['SpaceX', "'s"]
# 96                      ['Twitter', 'and', 'YouTube']
# 97
# 98                                          ['Tonga']
# 99  ['the', 'Caribbean', 'island', 'of', 'St.', 'V...
#
#                                          Nounphrases5  \
# 0                       ['the', 'suicide', 'bombing']
# 1
# 2                                          NULL VALUE
# 3                       ['credit', 'card', 'details']
# 4
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7
# 8                                          NULL VALUE
# 9   ['as', 'many', 'as', '19', 'people', 'still', ...
# 10                                       ['response']
# 11                                  ['Boko', 'Haram']
# 12                                       ['Istanbul']
# 13                     ['the', 'Isle', 'of', 'Wight']
# 14                    ['eight', 'onboard', 'missing']
# 15                                         NULL VALUE
# 16                               ['northern', 'Mali']
# 17
# 18                                         NULL VALUE
# 19
# 20                                         NULL VALUE
# 21                                          ['Derna']
# 22                               ['several', 'towns']
# 23                                        ['clashes']
# 24                                          ['Kabul']
# 25  ['Ancient', 'Egyptian', 'queen', 'Khentakawess...
# 26                                         NULL VALUE
# 27                      ['rare', 'earth', 'elements']
# 28          ['the', 'mad', 'cow', 'disease', 'scare']
# 29                                        ['Nairobi']
# ..                                                ...
# 70  ['a', 'second', 'successive', 'day', 'due', 't...
# 71                                         NULL VALUE
# 72          ['deaths', 'and', 'injury', 'complaints']
# 73                                         NULL VALUE
# 74                          ['the', '2024', 'Summer']
# 75               ['the', 'Boko', 'Haram', 'massacre']
# 76                          ['the', 'online', 'sale']
# 77
# 78
# 79  ['``', 'personality', 'and', 'behavioural', 'd...
# 80                                         NULL VALUE
# 81                        ['the', 'United', 'States']
# 82                        ['foreign', 'interference']
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85                          ['a', 'Shiite', 'mosque']
# 86  ['Front', '-LRB-', 'al-Qaeda', "'s", 'official...
# 87                                      ['Shikarpur']
# 88                                            ['539']
# 89  ['beer', 'that', 'was', 'deliberately', 'conta...
# 90                                         NULL VALUE
# 91                   ['opposite', 'traffic', 'flows']
# 92             ['up', 'to', 'a', 'million', 'people']
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95  ['the', 'experimental', 'recovery', 'attempt',...
# 96
# 97                                         NULL VALUE
# 98
# 99                     ['the', 'Caribbean', 'island']
#
#                                          Nounphrases6  \
# 0                                             ['Ibb']
# 1                                          NULL VALUE
# 2                                          NULL VALUE
# 3                                               ['9']
# 4                                          NULL VALUE
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          NULL VALUE
# 8                                          NULL VALUE
# 9                ['as', 'many', 'as', '19', 'people']
# 10  ['their', 'alleged', 'involvement', 'in', 'the...
# 11                                  ['three', 'days']
# 12
# 13                                    ['the', 'Isle']
# 14                                          ['eight']
# 15                                         NULL VALUE
# 16
# 17                                         NULL VALUE
# 18                                         NULL VALUE
# 19                                         NULL VALUE
# 20                                         NULL VALUE
# 21
# 22                           ['northeast', 'Nigeria']
# 23                 ['members', 'of', 'the', 'ruling']
# 24
# 25                        ['the', 'Fifth', 'Dynasty']
# 26                                         NULL VALUE
# 27  ['a', 'case', 'brought', 'by', 'the', 'United'...
# 28                                    ['15', 'years']
# 29
# ..                                                ...
# 70               ['a', 'second', 'successive', 'day']
# 71                                         NULL VALUE
# 72                             ['2003', 'to', '2014']
# 73                                         NULL VALUE
# 74                                       ['Olympics']
# 75                      ['the', 'town', 'of', 'Baga']
# 76                          ['prescription', 'drugs']
# 77                                         NULL VALUE
# 78                                         NULL VALUE
# 79  ['personality', 'and', 'behavioural', 'disorde...
# 80                                         NULL VALUE
# 81                   ['the', 'first', 'two', 'years']
# 82                            ['academic', 'freedom']
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85                                     ['Rawalpindi']
# 86                                          ['Front']
# 87                                        ['Karachi']
# 88                           ['Melbourne', 'Airport']
# 89                                           ['beer']
# 90                                         NULL VALUE
# 91
# 92                                   ['a', 'million']
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95     ['the', 'experimental', 'recovery', 'attempt']
# 96                                         NULL VALUE
# 97                                         NULL VALUE
# 98                                         NULL VALUE
# 99  ['St.', 'Vincent', 'leaving', 'at', 'least', '...
#
#                                          Nounphrases7  \
# 0
# 1                                          NULL VALUE
# 2                                          NULL VALUE
# 3
# 4                                          NULL VALUE
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          NULL VALUE
# 8                                          NULL VALUE
# 9
# 10                ['their', 'alleged', 'involvement']
# 11              ['40', 'boys', 'and', 'young', 'men']
# 12                                         NULL VALUE
# 13                                          ['Wight']
# 14
# 15                                         NULL VALUE
# 16                                         NULL VALUE
# 17                                         NULL VALUE
# 18                                         NULL VALUE
# 19                                         NULL VALUE
# 20                                         NULL VALUE
# 21                                         NULL VALUE
# 22          ['the', 'military', 'base', 'in', 'Baga']
# 23                                        ['members']
# 24                                         NULL VALUE
# 25
# 26                                         NULL VALUE
# 27                                      ['a', 'case']
# 28
# 29                                         NULL VALUE
# ..                                                ...
# 70               ['bitterly', 'cold', 'temperatures']
# 71                                         NULL VALUE
# 72
# 73                                         NULL VALUE
# 74
# 75                                    ['the', 'town']
# 76
# 77                                         NULL VALUE
# 78                                         NULL VALUE
# 79                                    ['personality']
# 80                                         NULL VALUE
# 81
# 82
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85
# 86  ['al-Qaeda', "'s", 'official', 'affiliate', 'i...
# 87  ['the', 'Pakistan', 'National', 'Highway', 'Li...
# 88
# 89                              ['crocodile', 'bile']
# 90                                         NULL VALUE
# 91                                         NULL VALUE
# 92
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95                          ['the', 'first', 'stage']
# 96                                         NULL VALUE
# 97                                         NULL VALUE
# 98                                         NULL VALUE
# 99                                 ['St.', 'Vincent']
#
#                                          Nounphrases8  ...  \
# 0                                          NULL VALUE  ...
# 1                                          NULL VALUE  ...
# 2                                          NULL VALUE  ...
# 3                                          NULL VALUE  ...
# 4                                          NULL VALUE  ...
# 5                                          NULL VALUE  ...
# 6                                          NULL VALUE  ...
# 7                                          NULL VALUE  ...
# 8                                          NULL VALUE  ...
# 9                                          NULL VALUE  ...
# 10         ['the', 'hacking', 'attack', 'on', 'Sony']  ...
# 11                                     ['40', 'boys']  ...
# 12                                         NULL VALUE  ...
# 13                                                     ...
# 14                                         NULL VALUE  ...
# 15                                         NULL VALUE  ...
# 16                                         NULL VALUE  ...
# 17                                         NULL VALUE  ...
# 18                                         NULL VALUE  ...
# 19                                         NULL VALUE  ...
# 20                                         NULL VALUE  ...
# 21                                         NULL VALUE  ...
# 22                        ['the', 'military', 'base']  ...
# 23                                  ['the', 'ruling']  ...
# 24                                         NULL VALUE  ...
# 25                                         NULL VALUE  ...
# 26                                         NULL VALUE  ...
# 27                        ['the', 'United', 'States']  ...
# 28                                         NULL VALUE  ...
# 29                                         NULL VALUE  ...
# ..                                                ...  ...
# 70                                                     ...
# 71                                         NULL VALUE  ...
# 72                                         NULL VALUE  ...
# 73                                         NULL VALUE  ...
# 74                                         NULL VALUE  ...
# 75                                           ['Baga']  ...
# 76                                         NULL VALUE  ...
# 77                                         NULL VALUE  ...
# 78                                         NULL VALUE  ...
# 79                       ['behavioural', 'disorders']  ...
# 80                                         NULL VALUE  ...
# 81                                         NULL VALUE  ...
# 82                                         NULL VALUE  ...
# 83                                         NULL VALUE  ...
# 84                                         NULL VALUE  ...
# 85                                         NULL VALUE  ...
# 86        ['al-Qaeda', "'s", 'official', 'affiliate']  ...
# 87  ['the', 'Pakistan', 'National', 'Highway', 'Li...  ...
# 88                                         NULL VALUE  ...
# 89  ['at', 'least', '56', 'dead', 'and', '146', 'h...  ...
# 90                                         NULL VALUE  ...
# 91                                         NULL VALUE  ...
# 92                                         NULL VALUE  ...
# 93                                         NULL VALUE  ...
# 94                                         NULL VALUE  ...
# 95  ['a', 'floating', 'platform', 'in', 'the', 'Sp...  ...
# 96                                         NULL VALUE  ...
# 97                                         NULL VALUE  ...
# 98                                         NULL VALUE  ...
# 99                  ['at', 'least', 'five', 'people']  ...
#
#                  Nounphrases10                    Nounphrases11  \
# 0                   NULL VALUE                       NULL VALUE
# 1                   NULL VALUE                       NULL VALUE
# 2                   NULL VALUE                       NULL VALUE
# 3                   NULL VALUE                       NULL VALUE
# 4                   NULL VALUE                       NULL VALUE
# 5                   NULL VALUE                       NULL VALUE
# 6                   NULL VALUE                       NULL VALUE
# 7                   NULL VALUE                       NULL VALUE
# 8                   NULL VALUE                       NULL VALUE
# 9                   NULL VALUE                       NULL VALUE
# 10                    ['Sony']
# 11                                                   NULL VALUE
# 12                  NULL VALUE                       NULL VALUE
# 13                  NULL VALUE                       NULL VALUE
# 14                  NULL VALUE                       NULL VALUE
# 15                  NULL VALUE                       NULL VALUE
# 16                  NULL VALUE                       NULL VALUE
# 17                  NULL VALUE                       NULL VALUE
# 18                  NULL VALUE                       NULL VALUE
# 19                  NULL VALUE                       NULL VALUE
# 20                  NULL VALUE                       NULL VALUE
# 21                  NULL VALUE                       NULL VALUE
# 22                                                   NULL VALUE
# 23         ['Awami', 'League']  ['the', 'town', 'of', 'Natore']
# 24                  NULL VALUE                       NULL VALUE
# 25                  NULL VALUE                       NULL VALUE
# 26                  NULL VALUE                       NULL VALUE
# 27                                                   NULL VALUE
# 28                  NULL VALUE                       NULL VALUE
# 29                  NULL VALUE                       NULL VALUE
# ..                         ...                              ...
# 70                  NULL VALUE                       NULL VALUE
# 71                  NULL VALUE                       NULL VALUE
# 72                  NULL VALUE                       NULL VALUE
# 73                  NULL VALUE                       NULL VALUE
# 74                  NULL VALUE                       NULL VALUE
# 75                  NULL VALUE                       NULL VALUE
# 76                  NULL VALUE                       NULL VALUE
# 77                  NULL VALUE                       NULL VALUE
# 78                  NULL VALUE                       NULL VALUE
# 79                                                   NULL VALUE
# 80                  NULL VALUE                       NULL VALUE
# 81                  NULL VALUE                       NULL VALUE
# 82                  NULL VALUE                       NULL VALUE
# 83                  NULL VALUE                       NULL VALUE
# 84                  NULL VALUE                       NULL VALUE
# 85                  NULL VALUE                       NULL VALUE
# 86                   ['Syria']   ['a', 'café', 'in', 'Tripoli']
# 87                                                   NULL VALUE
# 88                  NULL VALUE                       NULL VALUE
# 89    ['146', 'hospitailized']                          ['146']
# 90                  NULL VALUE                       NULL VALUE
# 91                  NULL VALUE                       NULL VALUE
# 92                  NULL VALUE                       NULL VALUE
# 93                  NULL VALUE                       NULL VALUE
# 94                  NULL VALUE                       NULL VALUE
# 95  ['the', 'SpaceX', 'CRS-5']
# 96                  NULL VALUE                       NULL VALUE
# 97                  NULL VALUE                       NULL VALUE
# 98                  NULL VALUE                       NULL VALUE
# 99                     ['two']
#
#       Nounphrases12 Nounphrases13  \
# 0        NULL VALUE    NULL VALUE
# 1        NULL VALUE    NULL VALUE
# 2        NULL VALUE    NULL VALUE
# 3        NULL VALUE    NULL VALUE
# 4        NULL VALUE    NULL VALUE
# 5        NULL VALUE    NULL VALUE
# 6        NULL VALUE    NULL VALUE
# 7        NULL VALUE    NULL VALUE
# 8        NULL VALUE    NULL VALUE
# 9        NULL VALUE    NULL VALUE
# 10       NULL VALUE    NULL VALUE
# 11       NULL VALUE    NULL VALUE
# 12       NULL VALUE    NULL VALUE
# 13       NULL VALUE    NULL VALUE
# 14       NULL VALUE    NULL VALUE
# 15       NULL VALUE    NULL VALUE
# 16       NULL VALUE    NULL VALUE
# 17       NULL VALUE    NULL VALUE
# 18       NULL VALUE    NULL VALUE
# 19       NULL VALUE    NULL VALUE
# 20       NULL VALUE    NULL VALUE
# 21       NULL VALUE    NULL VALUE
# 22       NULL VALUE    NULL VALUE
# 23  ['the', 'town']    ['Natore']
# 24       NULL VALUE    NULL VALUE
# 25       NULL VALUE    NULL VALUE
# 26       NULL VALUE    NULL VALUE
# 27       NULL VALUE    NULL VALUE
# 28       NULL VALUE    NULL VALUE
# 29       NULL VALUE    NULL VALUE
# ..              ...           ...
# 70       NULL VALUE    NULL VALUE
# 71       NULL VALUE    NULL VALUE
# 72       NULL VALUE    NULL VALUE
# 73       NULL VALUE    NULL VALUE
# 74       NULL VALUE    NULL VALUE
# 75       NULL VALUE    NULL VALUE
# 76       NULL VALUE    NULL VALUE
# 77       NULL VALUE    NULL VALUE
# 78       NULL VALUE    NULL VALUE
# 79       NULL VALUE    NULL VALUE
# 80       NULL VALUE    NULL VALUE
# 81       NULL VALUE    NULL VALUE
# 82       NULL VALUE    NULL VALUE
# 83       NULL VALUE    NULL VALUE
# 84       NULL VALUE    NULL VALUE
# 85       NULL VALUE    NULL VALUE
# 86    ['a', 'café']   ['Tripoli']
# 87       NULL VALUE    NULL VALUE
# 88       NULL VALUE    NULL VALUE
# 89                     NULL VALUE
# 90       NULL VALUE    NULL VALUE
# 91       NULL VALUE    NULL VALUE
# 92       NULL VALUE    NULL VALUE
# 93       NULL VALUE    NULL VALUE
# 94       NULL VALUE    NULL VALUE
# 95       NULL VALUE    NULL VALUE
# 96       NULL VALUE    NULL VALUE
# 97       NULL VALUE    NULL VALUE
# 98       NULL VALUE    NULL VALUE
# 99       NULL VALUE    NULL VALUE
#
#                                         Nounphrases14  \
# 0                                          NULL VALUE
# 1                                          NULL VALUE
# 2                                          NULL VALUE
# 3                                          NULL VALUE
# 4                                          NULL VALUE
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          NULL VALUE
# 8                                          NULL VALUE
# 9                                          NULL VALUE
# 10                                         NULL VALUE
# 11                                         NULL VALUE
# 12                                         NULL VALUE
# 13                                         NULL VALUE
# 14                                         NULL VALUE
# 15                                         NULL VALUE
# 16                                         NULL VALUE
# 17                                         NULL VALUE
# 18                                         NULL VALUE
# 19                                         NULL VALUE
# 20                                         NULL VALUE
# 21                                         NULL VALUE
# 22                                         NULL VALUE
# 23  ['the', 'first', 'anniversary', 'of', 'dispute...
# 24                                         NULL VALUE
# 25                                         NULL VALUE
# 26                                         NULL VALUE
# 27                                         NULL VALUE
# 28                                         NULL VALUE
# 29                                         NULL VALUE
# ..                                                ...
# 70                                         NULL VALUE
# 71                                         NULL VALUE
# 72                                         NULL VALUE
# 73                                         NULL VALUE
# 74                                         NULL VALUE
# 75                                         NULL VALUE
# 76                                         NULL VALUE
# 77                                         NULL VALUE
# 78                                         NULL VALUE
# 79                                         NULL VALUE
# 80                                         NULL VALUE
# 81                                         NULL VALUE
# 82                                         NULL VALUE
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85                                         NULL VALUE
# 86
# 87                                         NULL VALUE
# 88                                         NULL VALUE
# 89                                         NULL VALUE
# 90                                         NULL VALUE
# 91                                         NULL VALUE
# 92                                         NULL VALUE
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95                                         NULL VALUE
# 96                                         NULL VALUE
# 97                                         NULL VALUE
# 98                                         NULL VALUE
# 99                                         NULL VALUE
#
#                       Nounphrases15                        Nounphrases16  \
# 0                        NULL VALUE                           NULL VALUE
# 1                        NULL VALUE                           NULL VALUE
# 2                        NULL VALUE                           NULL VALUE
# 3                        NULL VALUE                           NULL VALUE
# 4                        NULL VALUE                           NULL VALUE
# 5                        NULL VALUE                           NULL VALUE
# 6                        NULL VALUE                           NULL VALUE
# 7                        NULL VALUE                           NULL VALUE
# 8                        NULL VALUE                           NULL VALUE
# 9                        NULL VALUE                           NULL VALUE
# 10                       NULL VALUE                           NULL VALUE
# 11                       NULL VALUE                           NULL VALUE
# 12                       NULL VALUE                           NULL VALUE
# 13                       NULL VALUE                           NULL VALUE
# 14                       NULL VALUE                           NULL VALUE
# 15                       NULL VALUE                           NULL VALUE
# 16                       NULL VALUE                           NULL VALUE
# 17                       NULL VALUE                           NULL VALUE
# 18                       NULL VALUE                           NULL VALUE
# 19                       NULL VALUE                           NULL VALUE
# 20                       NULL VALUE                           NULL VALUE
# 21                       NULL VALUE                           NULL VALUE
# 22                       NULL VALUE                           NULL VALUE
# 23  ['the', 'first', 'anniversary']  ['disputed', 'general', 'election']
# 24                       NULL VALUE                           NULL VALUE
# 25                       NULL VALUE                           NULL VALUE
# 26                       NULL VALUE                           NULL VALUE
# 27                       NULL VALUE                           NULL VALUE
# 28                       NULL VALUE                           NULL VALUE
# 29                       NULL VALUE                           NULL VALUE
# ..                              ...                                  ...
# 70                       NULL VALUE                           NULL VALUE
# 71                       NULL VALUE                           NULL VALUE
# 72                       NULL VALUE                           NULL VALUE
# 73                       NULL VALUE                           NULL VALUE
# 74                       NULL VALUE                           NULL VALUE
# 75                       NULL VALUE                           NULL VALUE
# 76                       NULL VALUE                           NULL VALUE
# 77                       NULL VALUE                           NULL VALUE
# 78                       NULL VALUE                           NULL VALUE
# 79                       NULL VALUE                           NULL VALUE
# 80                       NULL VALUE                           NULL VALUE
# 81                       NULL VALUE                           NULL VALUE
# 82                       NULL VALUE                           NULL VALUE
# 83                       NULL VALUE                           NULL VALUE
# 84                       NULL VALUE                           NULL VALUE
# 85                       NULL VALUE                           NULL VALUE
# 86                       NULL VALUE                           NULL VALUE
# 87                       NULL VALUE                           NULL VALUE
# 88                       NULL VALUE                           NULL VALUE
# 89                       NULL VALUE                           NULL VALUE
# 90                       NULL VALUE                           NULL VALUE
# 91                       NULL VALUE                           NULL VALUE
# 92                       NULL VALUE                           NULL VALUE
# 93                       NULL VALUE                           NULL VALUE
# 94                       NULL VALUE                           NULL VALUE
# 95                       NULL VALUE                           NULL VALUE
# 96                       NULL VALUE                           NULL VALUE
# 97                       NULL VALUE                           NULL VALUE
# 98                       NULL VALUE                           NULL VALUE
# 99                       NULL VALUE                           NULL VALUE
#
#    Nounphrases17 Nounphrases18 Nounphrases19
# 0     NULL VALUE    NULL VALUE    NULL VALUE
# 1     NULL VALUE    NULL VALUE    NULL VALUE
# 2     NULL VALUE    NULL VALUE    NULL VALUE
# 3     NULL VALUE    NULL VALUE    NULL VALUE
# 4     NULL VALUE    NULL VALUE    NULL VALUE
# 5     NULL VALUE    NULL VALUE    NULL VALUE
# 6     NULL VALUE    NULL VALUE    NULL VALUE
# 7     NULL VALUE    NULL VALUE    NULL VALUE
# 8     NULL VALUE    NULL VALUE    NULL VALUE
# 9     NULL VALUE    NULL VALUE    NULL VALUE
# 10    NULL VALUE    NULL VALUE    NULL VALUE
# 11    NULL VALUE    NULL VALUE    NULL VALUE
# 12    NULL VALUE    NULL VALUE    NULL VALUE
# 13    NULL VALUE    NULL VALUE    NULL VALUE
# 14    NULL VALUE    NULL VALUE    NULL VALUE
# 15    NULL VALUE    NULL VALUE    NULL VALUE
# 16    NULL VALUE    NULL VALUE    NULL VALUE
# 17    NULL VALUE    NULL VALUE    NULL VALUE
# 18    NULL VALUE    NULL VALUE    NULL VALUE
# 19    NULL VALUE    NULL VALUE    NULL VALUE
# 20    NULL VALUE    NULL VALUE    NULL VALUE
# 21    NULL VALUE    NULL VALUE    NULL VALUE
# 22    NULL VALUE    NULL VALUE    NULL VALUE
# 23                  NULL VALUE    NULL VALUE
# 24    NULL VALUE    NULL VALUE    NULL VALUE
# 25    NULL VALUE    NULL VALUE    NULL VALUE
# 26    NULL VALUE    NULL VALUE    NULL VALUE
# 27    NULL VALUE    NULL VALUE    NULL VALUE
# 28    NULL VALUE    NULL VALUE    NULL VALUE
# 29    NULL VALUE    NULL VALUE    NULL VALUE
# ..           ...           ...           ...
# 70    NULL VALUE    NULL VALUE    NULL VALUE
# 71    NULL VALUE    NULL VALUE    NULL VALUE
# 72    NULL VALUE    NULL VALUE    NULL VALUE
# 73    NULL VALUE    NULL VALUE    NULL VALUE
# 74    NULL VALUE    NULL VALUE    NULL VALUE
# 75    NULL VALUE    NULL VALUE    NULL VALUE
# 76    NULL VALUE    NULL VALUE    NULL VALUE
# 77    NULL VALUE    NULL VALUE    NULL VALUE
# 78    NULL VALUE    NULL VALUE    NULL VALUE
# 79    NULL VALUE    NULL VALUE    NULL VALUE
# 80    NULL VALUE    NULL VALUE    NULL VALUE
# 81    NULL VALUE    NULL VALUE    NULL VALUE
# 82    NULL VALUE    NULL VALUE    NULL VALUE
# 83    NULL VALUE    NULL VALUE    NULL VALUE
# 84    NULL VALUE    NULL VALUE    NULL VALUE
# 85    NULL VALUE    NULL VALUE    NULL VALUE
# 86    NULL VALUE    NULL VALUE    NULL VALUE
# 87    NULL VALUE    NULL VALUE    NULL VALUE
# 88    NULL VALUE    NULL VALUE    NULL VALUE
# 89    NULL VALUE    NULL VALUE    NULL VALUE
# 90    NULL VALUE    NULL VALUE    NULL VALUE
# 91    NULL VALUE    NULL VALUE    NULL VALUE
# 92    NULL VALUE    NULL VALUE    NULL VALUE
# 93    NULL VALUE    NULL VALUE    NULL VALUE
# 94    NULL VALUE    NULL VALUE    NULL VALUE
# 95    NULL VALUE    NULL VALUE    NULL VALUE
# 96    NULL VALUE    NULL VALUE    NULL VALUE
# 97    NULL VALUE    NULL VALUE    NULL VALUE
# 98    NULL VALUE    NULL VALUE    NULL VALUE
# 99    NULL VALUE    NULL VALUE    NULL VALUE
#
# [100 rows x 21 columns]

# %%
for i in range(0,20):
    df1['Nounphrases'+ str(i)] = df1['Nounphrases'+ str(i)].str.strip('[]').astype(str)
    df1['Nounphrases'+ str(i)] = df1['Nounphrases'+ str(i)].str.replace(',','').astype(str)
    df1['Nounphrases'+ str(i)] = df1['Nounphrases'+ str(i)].str.replace('\'','').astype(str)
    df1['Nounphrases'+ str(i)] = df1['Nounphrases'+ str(i)].str.replace('\"','').astype(str)
    df1['Nounphrases'+ str(i)] = df1['Nounphrases'+ str(i)].str.replace('.','').astype(str)

# %%
for i in range(0,20):
    print("'"+'Nounphrases'+ str(i)+"'"+" "+'=>'+'$row['+ str(i+1)+"]"+","+"\n")
# Out:
# 'Nounphrases0' =>$row[1],
#
# 'Nounphrases1' =>$row[2],
#
# 'Nounphrases2' =>$row[3],
#
# 'Nounphrases3' =>$row[4],
#
# 'Nounphrases4' =>$row[5],
#
# 'Nounphrases5' =>$row[6],
#
# 'Nounphrases6' =>$row[7],
#
# 'Nounphrases7' =>$row[8],
#
# 'Nounphrases8' =>$row[9],
#
# 'Nounphrases9' =>$row[10],
#
# 'Nounphrases10' =>$row[11],
#
# 'Nounphrases11' =>$row[12],
#
# 'Nounphrases12' =>$row[13],
#
# 'Nounphrases13' =>$row[14],
#
# 'Nounphrases14' =>$row[15],
#
# 'Nounphrases15' =>$row[16],
#
# 'Nounphrases16' =>$row[17],
#
# 'Nounphrases17' =>$row[18],
#
# 'Nounphrases18' =>$row[19],
#
# 'Nounphrases19' =>$row[20],

# %%
df1
# Out:
#                                         event_summary  \
# 0        The death toll of the suicide bombing in Ibb
# 1   A shooting kills one and injures six people in...
# 2   Lithuania adopts the euro as its official curr...
# 3   U.S. fast-food restaurant chain Chick-fil-A wa...
# 4   The Palestine Authority signs a treaty to join...
# 5          The Eurasian Economic Union between Russia
# 6         Vietnam’s new marriage law goes into effect
# 7   Somali al-Shabaab militants attack an army bas...
# 8           Boko Haram militants attack a bus in Waza
# 9   The MS Norman Atlantic ferry fire death toll r...
# 10  The United States enacts more sanctions on Nor...
# 11  Fleeing villagers from a remote part of the Bo...
# 12  Turkey permits the building of a Syriac church...
# 13  The Singapore-registered cargo ship MV Höegh O...
# 14  The Cypriot-registered cargo ship Cemfjord sin...
# 15  A U.S. drone strike kills eight Uzbek people c...
# 16  A vehicle carrying United Nations peacekeepers...
# 17  A bombing at a local Houthi movement headquart...
# 18  A suicide car bomber detonates near a military...
# 19           A six-story building collapse in Nairobi
# 20  Pope Francis announces the appointment of 20 n...
# 21  A Libyan warplane bombs a Greek-operated oil t...
# 22  News emerges that two days prior hundreds of B...
# 23  Bangladeshi police report that two opposition ...
# 24  A suicide car bomber hits the headquarters of ...
# 25  A Czech archaeological team discovers the tomb...
# 26           The site where Jesus may have been tried
# 27  China relaxes controls over the export of rare...
# 28  Ireland becomes the first European nation to b...
# 29  For the second day in a row a multi-story resi...
# ..                                                ...
# 70  Schools in the Midwestern and Northeast United...
# 71      An unknown gunman shoots dead Nerlita Ledesma
# 72  The Obama administration fines Honda $70 milli...
# 73  Brunei officially bans all future public celeb...
# 74  The US Olympic Committee chooses the city of B...
# 75  Refugees flee Nigeria's Borno State following ...
# 76  The People's Republic of China plans to soon p...
# 77  A 193-vehicle pileup along a snowy Interstate ...
# 78  Former Prime Minister of Thailand Yingluck Shi...
# 79  Russia lists transsexual and transgender indiv...
# 80             A shooting into a car in San Francisco
# 81  Barack Obama proposes a new program to waive t...
# 82  Stockholm University cuts its ties with the Co...
# 83  The Lovejoy Comet enters its brightest phase t...
# 84       The AFC Asian Cup holds the opening ceremony
# 85  A suicide bomb attack on a Shiite mosque in Ra...
# 86  A suicide attack by al-Nusra Front (al-Qaeda's...
# 87  A traffic accident between an oil tanker truck...
# 88  A bomb threat on Tigerair Flight 539 at Melbou...
# 89  A mass poisoning at a funeral in Mozambique in...
# 90  SpaceX successfully launches a Falcon 9 rocket...
# 91  The Golden Gate Bridge Highway and Transportat...
# 92  Thousands of police and military personnel pre...
# 93  Divers retrieve the flight data recorder from ...
# 94  The death toll from the Karachi traffic accide...
# 95  Public photographs become available of SpaceX'...
# 96  Apparent ISIL computer hackers attack the feed...
# 97  Cameroon kills 143 Boko Haram fighters in clas...
# 98  The eruption of the Hunga Tonga volcano disrup...
# 99  A school bus plunges off of a cliff on the Car...
#
#                                          Nounphrases0  \
# 0        The death toll of the suicide bombing in Ibb
# 1                                          A shooting
# 2                                           Lithuania
# 3           US fast-food restaurant chain Chick-fil-A
# 4   The Palestine Authority signs a treaty to join...
# 5                         The Eurasian Economic Union
# 6                          Vietnam s new marriage law
# 7                         Somali al-Shabaab militants
# 8                                Boko Haram militants
# 9        The MS Norman Atlantic ferry fire death toll
# 10                                  The United States
# 11  Fleeing villagers from a remote part of the Bo...
# 12                                             Turkey
# 13  The Singapore-registered cargo ship MV Höegh O...
# 14         The Cypriot-registered cargo ship Cemfjord
# 15                                  A US drone strike
# 16     A vehicle carrying United Nations peacekeepers
# 17  A bombing at a local Houthi movement headquart...
# 18                               A suicide car bomber
# 19           A six-story building collapse in Nairobi
# 20                                       Pope Francis
# 21  A Libyan warplane bombs a Greek-operated oil t...
# 22                                               News
# 23                                 Bangladeshi police
# 24                               A suicide car bomber
# 25                        A Czech archaeological team
# 26                                           The site
# 27                                              China
# 28                                            Ireland
# 29                            the second day in a row
# ..                                                ...
# 70  Schools in the Midwestern and Northeast United...
# 71                                  An unknown gunman
# 72  The Obama administration fines Honda $ 70 mill...
# 73                                             Brunei
# 74                           The US Olympic Committee
# 75                                           Refugees
# 76                     The People s Republic of China
# 77  A 193-vehicle pileup along a snowy Interstate ...
# 78  Former Prime Minister of Thailand Yingluck Shi...
# 79                                             Russia
# 80                                         A shooting
# 81                                       Barack Obama
# 82                               Stockholm University
# 83                                  The Lovejoy Comet
# 84                                  The AFC Asian Cup
# 85  A suicide bomb attack on a Shiite mosque in Ra...
# 86  A suicide attack by al-Nusra Front -LRB- al-Qa...
# 87  A traffic accident between an oil tanker truck...
# 88  A bomb threat on Tigerair Flight 539 at Melbou...
# 89        A mass poisoning at a funeral in Mozambique
# 90                                             SpaceX
# 91  The Golden Gate Bridge Highway and Transportat...
# 92         Thousands of police and military personnel
# 93                                             Divers
# 94   The death toll from the Karachi traffic accident
# 95                                 Public photographs
# 96                     Apparent ISIL computer hackers
# 97                                           Cameroon
# 98            The eruption of the Hunga Tonga volcano
# 99                                       A school bus
#
#                                          Nounphrases1  \
# 0                                           The death
# 1                                                 one
# 2                   the euro as its official currency
# 3                       US fast-food restaurant chain
# 4              The Palestine Authority signs a treaty
# 5                                              Russia
# 6                                           Vietnam s
# 7                                        an army base
# 8                                       a bus in Waza
# 9                        The MS Norman Atlantic ferry
# 10          more sanctions on North Korea in response
# 11                                  Fleeing villagers
# 12        the building of a Syriac church in Istanbul
# 13    Bramble Bank off the coast of the Isle of Wight
# 14  the northern coast of Scotland leaving eight o...
# 15                                 eight Uzbek people
# 16                                          A vehicle
# 17  A bombing at a local Houthi movement headquarters
# 18                     a military convoy in Mogadishu
# 19                               A six-story building
# 20                the appointment of 20 new Cardinals
# 21                            A Libyan warplane bombs
# 22                                           two days
# 23  two opposition Bangladesh Nationalist Party ac...
# 24     the headquarters of EUPOL Afghanistan in Kabul
# 25  the tomb of formerly unknown Ancient Egyptian ...
# 26                                              Jesus
# 27    controls over the export of rare earth elements
# 28                          the first European nation
# 29                                     the second day
# ..                                                ...
# 70                                            Schools
# 71                                    Nerlita Ledesma
# 72               The Obama administration fines Honda
# 73        all future public celebrations of Christmas
# 74                                 the city of Boston
# 75  Nigeria s Borno State following the Boko Haram...
# 76                              The People s Republic
# 77                               A 193-vehicle pileup
# 78                              Former Prime Minister
# 79  transsexual and transgender individuals among ...
# 80                                              a car
# 81  a new program to waive tuition at community co...
# 82                                           its ties
# 83                                its brightest phase
# 84                               the opening ceremony
# 85                                          A suicide
# 86                       A suicide attack by al-Nusra
# 87                                 A traffic accident
# 88                   A bomb threat on Tigerair Flight
# 89                                   A mass poisoning
# 90              a Falcon 9 rocket from Cape Canaveral
# 91                             the Golden Gate Bridge
# 92                                          Thousands
# 93      the flight data recorder from the crashed jet
# 94                                     The death toll
# 95  available of SpaceX s Falcon 9 rocket after th...
# 96                                                the
# 97                 143 Boko Haram fighters in clashes
# 98                                       The eruption
# 99  a cliff on the Caribbean island of St Vincent ...
#
#                                          Nounphrases2  \
# 0                  toll of the suicide bombing in Ibb
# 1                             six people in Killarney
# 2                                            the euro
# 3                                         Chick-fil-A
# 4                       The Palestine Authority signs
# 5
# 6                                              effect
# 7                             the outskirts of Baidoa
# 8                                               a bus
# 9                                     fire death toll
# 10                                     more sanctions
# 11                                      a remote part
# 12                                       the building
# 13                                       Bramble Bank
# 14                                 the northern coast
# 15                                           al-Qaeda
# 16                        United Nations peacekeepers
# 17                                          A bombing
# 18                                  a military convoy
# 19                                collapse in Nairobi
# 20                                    the appointment
# 21                        a Greek-operated oil tanker
# 22                   hundreds of Boko Haram militants
# 23                          two opposition Bangladesh
# 24                                   the headquarters
# 25                                           the tomb
# 26
# 27                                           controls
# 28                                               beef
# 29                                              a row
# ..                                                ...
# 70         the Midwestern and Northeast United States
# 71
# 72                     The Obama administration fines
# 73                     all future public celebrations
# 74                                           the city
# 75                              Nigeria s Borno State
# 76                                       The People s
# 77  a snowy Interstate 94 highway in Kalamazoo County
# 78                       Thailand Yingluck Shinawatra
# 79            transsexual and transgender individuals
# 80                                      San Francisco
# 81                                            tuition
# 82                            the Confucius Institute
# 83                           roughly magnitude 4 or 5
# 84
# 85       bomb attack on a Shiite mosque in Rawalpindi
# 86                                   A suicide attack
# 87   an oil tanker truck and passenger coach en route
# 88                                      A bomb threat
# 89                            a funeral in Mozambique
# 90                                  a Falcon 9 rocket
# 91                                             Monday
# 92                      police and military personnel
# 93                           the flight data recorder
# 94                       the Karachi traffic accident
# 95  SpaceX s Falcon 9 rocket after the experimenta...
# 96  the United States Central Command for Twitter ...
# 97                            143 Boko Haram fighters
# 98                            the Hunga Tonga volcano
# 99                                            a cliff
#
#                                          Nounphrases3  \
# 0                                                toll
# 1                                          six people
# 2                               its official currency
# 3                                   a security breach
# 4                                            a treaty
# 5                                          NULL VALUE
# 6
# 7                                       the outskirts
# 8                                                Waza
# 9   at least eleven with as many as 19 people stil...
# 10                            North Korea in response
# 11  the Borno State report that Boko Haram had thr...
# 12                        a Syriac church in Istanbul
# 13                     the coast of the Isle of Wight
# 14             Scotland leaving eight onboard missing
# 15                                           Pakistan
# 16                   a roadside bomb in northern Mali
# 17               a local Houthi movement headquarters
# 18                                          Mogadishu
# 19                                           collapse
# 20                                   20 new Cardinals
# 21                                  the city of Derna
# 22                                           hundreds
# 23                        Nationalist Party activists
# 24                         EUPOL Afghanistan in Kabul
# 25  formerly unknown Ancient Egyptian queen Khenta...
# 26                                         NULL VALUE
# 27                  the export of rare earth elements
# 28                                  the United States
# 29      a multi-story residential building in Nairobi
# ..                                                ...
# 70                                     the Midwestern
# 71                                         NULL VALUE
# 72  $ 70 million for failing to report deaths and ...
# 73                                          Christmas
# 74                                             Boston
# 75                                          Nigeria s
# 76                                              China
# 77                      a snowy Interstate 94 highway
# 78                                impeachment charges
# 79  those with `` personality and behavioural diso...
# 80
# 81            community colleges in the United States
# 82                                           concerns
# 83                                  roughly magnitude
# 84                                         NULL VALUE
# 85                                        bomb attack
# 86                                           al-Nusra
# 87            an oil tanker truck and passenger coach
# 88                                    Tigerair Flight
# 89                                          a funeral
# 90                                     Cape Canaveral
# 91  a $ 30 million moveable barrier between opposi...
# 92                                a Paris unity rally
# 93                                    the crashed jet
# 94                                                 62
# 95                           SpaceX s Falcon 9 rocket
# 96                  the United States Central Command
# 97                                            clashes
# 98                                            flights
# 99  the Caribbean island of St Vincent leaving at ...
#
#                                          Nounphrases4  \
# 0                          the suicide bombing in Ibb
# 1                                           Killarney
# 2
# 3                            credit card details of 9
# 4                    the International Criminal Court
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                              Baidoa
# 8
# 9                                     at least eleven
# 10                                        North Korea
# 11                             the Borno State report
# 12                                    a Syriac church
# 13                                          the coast
# 14                                           Scotland
# 15
# 16                                    a roadside bomb
# 17                                 Dhamar Governorate
# 18
# 19                                            Nairobi
# 20
# 21                                           the city
# 22                               Boko Haram militants
# 23                 clashes with members of the ruling
# 24                                  EUPOL Afghanistan
# 25                                   formerly unknown
# 26                                         NULL VALUE
# 27                                         the export
# 28             the mad cow disease scare 15 years ago
# 29                 a multi-story residential building
# ..                                                ...
# 70                            Northeast United States
# 71                                         NULL VALUE
# 72                                       $ 70 million
# 73
# 74                              the American bid city
# 75        the Boko Haram massacre in the town of Baga
# 76              the online sale of prescription drugs
# 77                                   Kalamazoo County
# 78                       a failed rice subsidy scheme
# 79                                              those
# 80                                         NULL VALUE
# 81                                 community colleges
# 82           foreign interference in academic freedom
# 83
# 84                                         NULL VALUE
# 85                      a Shiite mosque in Rawalpindi
# 86  Front -LRB- al-Qaeda s official affiliate in S...
# 87                                              route
# 88                           539 at Melbourne Airport
# 89                                         Mozambique
# 90
# 91                    a $ 30 million moveable barrier
# 92          up to a million people expected to attend
# 93
# 94
# 95                                           SpaceX s
# 96                                Twitter and YouTube
# 97
# 98                                              Tonga
# 99  the Caribbean island of St Vincent leaving at ...
#
#                                          Nounphrases5  \
# 0                                 the suicide bombing
# 1
# 2                                          NULL VALUE
# 3                                 credit card details
# 4
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7
# 8                                          NULL VALUE
# 9              as many as 19 people still unaccounted
# 10                                           response
# 11                                         Boko Haram
# 12                                           Istanbul
# 13                                  the Isle of Wight
# 14                              eight onboard missing
# 15                                         NULL VALUE
# 16                                      northern Mali
# 17
# 18                                         NULL VALUE
# 19
# 20                                         NULL VALUE
# 21                                              Derna
# 22                                      several towns
# 23                                            clashes
# 24                                              Kabul
# 25            Ancient Egyptian queen Khentakawess III
# 26                                         NULL VALUE
# 27                                rare earth elements
# 28                          the mad cow disease scare
# 29                                            Nairobi
# ..                                                ...
# 70  a second successive day due to bitterly cold t...
# 71                                         NULL VALUE
# 72                       deaths and injury complaints
# 73                                         NULL VALUE
# 74                                    the 2024 Summer
# 75                            the Boko Haram massacre
# 76                                    the online sale
# 77
# 78
# 79  `` personality and behavioural disorders  who ...
# 80                                         NULL VALUE
# 81                                  the United States
# 82                               foreign interference
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85                                    a Shiite mosque
# 86  Front -LRB- al-Qaeda s official affiliate in S...
# 87                                          Shikarpur
# 88                                                539
# 89  beer that was deliberately contaminated with c...
# 90                                         NULL VALUE
# 91                             opposite traffic flows
# 92                             up to a million people
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95  the experimental recovery attempt of the first...
# 96
# 97                                         NULL VALUE
# 98
# 99                               the Caribbean island
#
#                                          Nounphrases6  \
# 0                                                 Ibb
# 1                                          NULL VALUE
# 2                                          NULL VALUE
# 3                                                   9
# 4                                          NULL VALUE
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          NULL VALUE
# 8                                          NULL VALUE
# 9                                as many as 19 people
# 10  their alleged involvement in the hacking attac...
# 11                                         three days
# 12
# 13                                           the Isle
# 14                                              eight
# 15                                         NULL VALUE
# 16
# 17                                         NULL VALUE
# 18                                         NULL VALUE
# 19                                         NULL VALUE
# 20                                         NULL VALUE
# 21
# 22                                  northeast Nigeria
# 23                              members of the ruling
# 24
# 25                                  the Fifth Dynasty
# 26                                         NULL VALUE
# 27  a case brought by the United States at the Wor...
# 28                                           15 years
# 29
# ..                                                ...
# 70                            a second successive day
# 71                                         NULL VALUE
# 72                                       2003 to 2014
# 73                                         NULL VALUE
# 74                                           Olympics
# 75                                   the town of Baga
# 76                                 prescription drugs
# 77                                         NULL VALUE
# 78                                         NULL VALUE
# 79              personality and behavioural disorders
# 80                                         NULL VALUE
# 81                                the first two years
# 82                                   academic freedom
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85                                         Rawalpindi
# 86                                              Front
# 87                                            Karachi
# 88                                  Melbourne Airport
# 89                                               beer
# 90                                         NULL VALUE
# 91
# 92                                          a million
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95                  the experimental recovery attempt
# 96                                         NULL VALUE
# 97                                         NULL VALUE
# 98                                         NULL VALUE
# 99       St Vincent leaving at least five people dead
#
#                                          Nounphrases7  \
# 0
# 1                                          NULL VALUE
# 2                                          NULL VALUE
# 3
# 4                                          NULL VALUE
# 5                                          NULL VALUE
# 6                                          NULL VALUE
# 7                                          NULL VALUE
# 8                                          NULL VALUE
# 9
# 10                          their alleged involvement
# 11                              40 boys and young men
# 12                                         NULL VALUE
# 13                                              Wight
# 14
# 15                                         NULL VALUE
# 16                                         NULL VALUE
# 17                                         NULL VALUE
# 18                                         NULL VALUE
# 19                                         NULL VALUE
# 20                                         NULL VALUE
# 21                                         NULL VALUE
# 22                          the military base in Baga
# 23                                            members
# 24                                         NULL VALUE
# 25
# 26                                         NULL VALUE
# 27                                             a case
# 28
# 29                                         NULL VALUE
# ..                                                ...
# 70                         bitterly cold temperatures
# 71                                         NULL VALUE
# 72
# 73                                         NULL VALUE
# 74
# 75                                           the town
# 76
# 77                                         NULL VALUE
# 78                                         NULL VALUE
# 79                                        personality
# 80                                         NULL VALUE
# 81
# 82
# 83                                         NULL VALUE
# 84                                         NULL VALUE
# 85
# 86             al-Qaeda s official affiliate in Syria
# 87  the Pakistan National Highway Link Road near G...
# 88
# 89                                     crocodile bile
# 90                                         NULL VALUE
# 91                                         NULL VALUE
# 92
# 93                                         NULL VALUE
# 94                                         NULL VALUE
# 95                                    the first stage
# 96                                         NULL VALUE
# 97                                         NULL VALUE
# 98                                         NULL VALUE
# 99                                         St Vincent
#
#                                         Nounphrases8  ...      Nounphrases10  \
# 0                                         NULL VALUE  ...         NULL VALUE
# 1                                         NULL VALUE  ...         NULL VALUE
# 2                                         NULL VALUE  ...         NULL VALUE
# 3                                         NULL VALUE  ...         NULL VALUE
# 4                                         NULL VALUE  ...         NULL VALUE
# 5                                         NULL VALUE  ...         NULL VALUE
# 6                                         NULL VALUE  ...         NULL VALUE
# 7                                         NULL VALUE  ...         NULL VALUE
# 8                                         NULL VALUE  ...         NULL VALUE
# 9                                         NULL VALUE  ...         NULL VALUE
# 10                        the hacking attack on Sony  ...               Sony
# 11                                           40 boys  ...
# 12                                        NULL VALUE  ...         NULL VALUE
# 13                                                    ...         NULL VALUE
# 14                                        NULL VALUE  ...         NULL VALUE
# 15                                        NULL VALUE  ...         NULL VALUE
# 16                                        NULL VALUE  ...         NULL VALUE
# 17                                        NULL VALUE  ...         NULL VALUE
# 18                                        NULL VALUE  ...         NULL VALUE
# 19                                        NULL VALUE  ...         NULL VALUE
# 20                                        NULL VALUE  ...         NULL VALUE
# 21                                        NULL VALUE  ...         NULL VALUE
# 22                                 the military base  ...
# 23                                        the ruling  ...       Awami League
# 24                                        NULL VALUE  ...         NULL VALUE
# 25                                        NULL VALUE  ...         NULL VALUE
# 26                                        NULL VALUE  ...         NULL VALUE
# 27                                 the United States  ...
# 28                                        NULL VALUE  ...         NULL VALUE
# 29                                        NULL VALUE  ...         NULL VALUE
# ..                                               ...  ...                ...
# 70                                                    ...         NULL VALUE
# 71                                        NULL VALUE  ...         NULL VALUE
# 72                                        NULL VALUE  ...         NULL VALUE
# 73                                        NULL VALUE  ...         NULL VALUE
# 74                                        NULL VALUE  ...         NULL VALUE
# 75                                              Baga  ...         NULL VALUE
# 76                                        NULL VALUE  ...         NULL VALUE
# 77                                        NULL VALUE  ...         NULL VALUE
# 78                                        NULL VALUE  ...         NULL VALUE
# 79                             behavioural disorders  ...
# 80                                        NULL VALUE  ...         NULL VALUE
# 81                                        NULL VALUE  ...         NULL VALUE
# 82                                        NULL VALUE  ...         NULL VALUE
# 83                                        NULL VALUE  ...         NULL VALUE
# 84                                        NULL VALUE  ...         NULL VALUE
# 85                                        NULL VALUE  ...         NULL VALUE
# 86                     al-Qaeda s official affiliate  ...              Syria
# 87           the Pakistan National Highway Link Road  ...
# 88                                        NULL VALUE  ...         NULL VALUE
# 89            at least 56 dead and 146 hospitailized  ...  146 hospitailized
# 90                                        NULL VALUE  ...         NULL VALUE
# 91                                        NULL VALUE  ...         NULL VALUE
# 92                                        NULL VALUE  ...         NULL VALUE
# 93                                        NULL VALUE  ...         NULL VALUE
# 94                                        NULL VALUE  ...         NULL VALUE
# 95  a floating platform in the SpaceX CRS-5 resupply  ...   the SpaceX CRS-5
# 96                                        NULL VALUE  ...         NULL VALUE
# 97                                        NULL VALUE  ...         NULL VALUE
# 98                                        NULL VALUE  ...         NULL VALUE
# 99                              at least five people  ...                two
#
#          Nounphrases11 Nounphrases12 Nounphrases13  \
# 0           NULL VALUE    NULL VALUE    NULL VALUE
# 1           NULL VALUE    NULL VALUE    NULL VALUE
# 2           NULL VALUE    NULL VALUE    NULL VALUE
# 3           NULL VALUE    NULL VALUE    NULL VALUE
# 4           NULL VALUE    NULL VALUE    NULL VALUE
# 5           NULL VALUE    NULL VALUE    NULL VALUE
# 6           NULL VALUE    NULL VALUE    NULL VALUE
# 7           NULL VALUE    NULL VALUE    NULL VALUE
# 8           NULL VALUE    NULL VALUE    NULL VALUE
# 9           NULL VALUE    NULL VALUE    NULL VALUE
# 10                        NULL VALUE    NULL VALUE
# 11          NULL VALUE    NULL VALUE    NULL VALUE
# 12          NULL VALUE    NULL VALUE    NULL VALUE
# 13          NULL VALUE    NULL VALUE    NULL VALUE
# 14          NULL VALUE    NULL VALUE    NULL VALUE
# 15          NULL VALUE    NULL VALUE    NULL VALUE
# 16          NULL VALUE    NULL VALUE    NULL VALUE
# 17          NULL VALUE    NULL VALUE    NULL VALUE
# 18          NULL VALUE    NULL VALUE    NULL VALUE
# 19          NULL VALUE    NULL VALUE    NULL VALUE
# 20          NULL VALUE    NULL VALUE    NULL VALUE
# 21          NULL VALUE    NULL VALUE    NULL VALUE
# 22          NULL VALUE    NULL VALUE    NULL VALUE
# 23  the town of Natore      the town        Natore
# 24          NULL VALUE    NULL VALUE    NULL VALUE
# 25          NULL VALUE    NULL VALUE    NULL VALUE
# 26          NULL VALUE    NULL VALUE    NULL VALUE
# 27          NULL VALUE    NULL VALUE    NULL VALUE
# 28          NULL VALUE    NULL VALUE    NULL VALUE
# 29          NULL VALUE    NULL VALUE    NULL VALUE
# ..                 ...           ...           ...
# 70          NULL VALUE    NULL VALUE    NULL VALUE
# 71          NULL VALUE    NULL VALUE    NULL VALUE
# 72          NULL VALUE    NULL VALUE    NULL VALUE
# 73          NULL VALUE    NULL VALUE    NULL VALUE
# 74          NULL VALUE    NULL VALUE    NULL VALUE
# 75          NULL VALUE    NULL VALUE    NULL VALUE
# 76          NULL VALUE    NULL VALUE    NULL VALUE
# 77          NULL VALUE    NULL VALUE    NULL VALUE
# 78          NULL VALUE    NULL VALUE    NULL VALUE
# 79          NULL VALUE    NULL VALUE    NULL VALUE
# 80          NULL VALUE    NULL VALUE    NULL VALUE
# 81          NULL VALUE    NULL VALUE    NULL VALUE
# 82          NULL VALUE    NULL VALUE    NULL VALUE
# 83          NULL VALUE    NULL VALUE    NULL VALUE
# 84          NULL VALUE    NULL VALUE    NULL VALUE
# 85          NULL VALUE    NULL VALUE    NULL VALUE
# 86   a café in Tripoli        a café       Tripoli
# 87          NULL VALUE    NULL VALUE    NULL VALUE
# 88          NULL VALUE    NULL VALUE    NULL VALUE
# 89                 146                  NULL VALUE
# 90          NULL VALUE    NULL VALUE    NULL VALUE
# 91          NULL VALUE    NULL VALUE    NULL VALUE
# 92          NULL VALUE    NULL VALUE    NULL VALUE
# 93          NULL VALUE    NULL VALUE    NULL VALUE
# 94          NULL VALUE    NULL VALUE    NULL VALUE
# 95                        NULL VALUE    NULL VALUE
# 96          NULL VALUE    NULL VALUE    NULL VALUE
# 97          NULL VALUE    NULL VALUE    NULL VALUE
# 98          NULL VALUE    NULL VALUE    NULL VALUE
# 99                        NULL VALUE    NULL VALUE
#
#                                         Nounphrases14          Nounphrases15  \
# 0                                          NULL VALUE             NULL VALUE
# 1                                          NULL VALUE             NULL VALUE
# 2                                          NULL VALUE             NULL VALUE
# 3                                          NULL VALUE             NULL VALUE
# 4                                          NULL VALUE             NULL VALUE
# 5                                          NULL VALUE             NULL VALUE
# 6                                          NULL VALUE             NULL VALUE
# 7                                          NULL VALUE             NULL VALUE
# 8                                          NULL VALUE             NULL VALUE
# 9                                          NULL VALUE             NULL VALUE
# 10                                         NULL VALUE             NULL VALUE
# 11                                         NULL VALUE             NULL VALUE
# 12                                         NULL VALUE             NULL VALUE
# 13                                         NULL VALUE             NULL VALUE
# 14                                         NULL VALUE             NULL VALUE
# 15                                         NULL VALUE             NULL VALUE
# 16                                         NULL VALUE             NULL VALUE
# 17                                         NULL VALUE             NULL VALUE
# 18                                         NULL VALUE             NULL VALUE
# 19                                         NULL VALUE             NULL VALUE
# 20                                         NULL VALUE             NULL VALUE
# 21                                         NULL VALUE             NULL VALUE
# 22                                         NULL VALUE             NULL VALUE
# 23  the first anniversary of disputed general elec...  the first anniversary
# 24                                         NULL VALUE             NULL VALUE
# 25                                         NULL VALUE             NULL VALUE
# 26                                         NULL VALUE             NULL VALUE
# 27                                         NULL VALUE             NULL VALUE
# 28                                         NULL VALUE             NULL VALUE
# 29                                         NULL VALUE             NULL VALUE
# ..                                                ...                    ...
# 70                                         NULL VALUE             NULL VALUE
# 71                                         NULL VALUE             NULL VALUE
# 72                                         NULL VALUE             NULL VALUE
# 73                                         NULL VALUE             NULL VALUE
# 74                                         NULL VALUE             NULL VALUE
# 75                                         NULL VALUE             NULL VALUE
# 76                                         NULL VALUE             NULL VALUE
# 77                                         NULL VALUE             NULL VALUE
# 78                                         NULL VALUE             NULL VALUE
# 79                                         NULL VALUE             NULL VALUE
# 80                                         NULL VALUE             NULL VALUE
# 81                                         NULL VALUE             NULL VALUE
# 82                                         NULL VALUE             NULL VALUE
# 83                                         NULL VALUE             NULL VALUE
# 84                                         NULL VALUE             NULL VALUE
# 85                                         NULL VALUE             NULL VALUE
# 86                                                                NULL VALUE
# 87                                         NULL VALUE             NULL VALUE
# 88                                         NULL VALUE             NULL VALUE
# 89                                         NULL VALUE             NULL VALUE
# 90                                         NULL VALUE             NULL VALUE
# 91                                         NULL VALUE             NULL VALUE
# 92                                         NULL VALUE             NULL VALUE
# 93                                         NULL VALUE             NULL VALUE
# 94                                         NULL VALUE             NULL VALUE
# 95                                         NULL VALUE             NULL VALUE
# 96                                         NULL VALUE             NULL VALUE
# 97                                         NULL VALUE             NULL VALUE
# 98                                         NULL VALUE             NULL VALUE
# 99                                         NULL VALUE             NULL VALUE
#
#                 Nounphrases16 Nounphrases17 Nounphrases18 Nounphrases19
# 0                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 1                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 2                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 3                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 4                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 5                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 6                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 7                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 8                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 9                  NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 10                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 11                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 12                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 13                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 14                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 15                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 16                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 17                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 18                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 19                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 20                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 21                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 22                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 23  disputed general election                  NULL VALUE    NULL VALUE
# 24                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 25                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 26                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 27                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 28                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 29                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# ..                        ...           ...           ...           ...
# 70                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 71                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 72                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 73                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 74                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 75                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 76                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 77                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 78                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 79                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 80                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 81                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 82                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 83                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 84                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 85                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 86                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 87                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 88                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 89                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 90                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 91                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 92                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 93                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 94                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 95                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 96                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 97                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 98                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
# 99                 NULL VALUE    NULL VALUE    NULL VALUE    NULL VALUE
#
# [100 rows x 21 columns]

# %%
# export_csv = df1.to_csv (r'C:\Users\gulja\Python 3.7.3\Scripts\df_small.csv', index = None, header=True, sep=';') #Don't forget to add '.csv' at the end of the path

# %%
for i in range(0, 10):
        text = df['event_summary'][i]
        print(text)
        print ("Dep Parse:", sNLP.dependency_parse(text))
        sentence=sNLP.parse(text)
#         print(text.print_dependencies())
#         parser = CoreNLPParser()
#         next(parser.raw_parse(text)).pretty_print()
        
#         sdp =  StanfordDependencyParser()
#         next(sdp.raw_parse(text)).pretty_print()
#         result = list(sdp.raw_parse(text))

#         dep_tree_dot_repr = [parse for parse in result][0].to_dot()
#         source = Source(dep_tree_dot_repr, filename="dep_tree", format="png")
#         source.view()

        
        print('\n\n .......................................................................... \n\n')
        
#         https://nlp.stanford.edu/software/dependencies_manual.pdf

# det: determiner
# A determiner is the relation between the head of an NP and its determiner.
# “The man is here” det(man, the)
# Out:
# The death toll of the suicide bombing in Ibb
# Dep Parse: [('ROOT', 0, 3), ('det', 3, 1), ('compound', 3, 2), ('case', 7, 4), ('det', 7, 5), ('compound', 7, 6), ('nmod', 3, 7), ('case', 9, 8), ('nmod', 7, 9)]
#
#
#  ..........................................................................
#
#
# A shooting kills one and injures six people in Killarney
# Dep Parse: [('ROOT', 0, 3), ('det', 2, 1), ('nsubj', 3, 2), ('dobj', 3, 4), ('cc', 3, 5), ('conj', 3, 6), ('nummod', 8, 7), ('dobj', 6, 8), ('case', 10, 9), ('nmod', 6, 10)]
#
#
#  ..........................................................................
#
#
# Lithuania adopts the euro as its official currency
# Dep Parse: [('ROOT', 0, 2), ('nsubj', 2, 1), ('det', 4, 3), ('dobj', 2, 4), ('case', 8, 5), ('nmod:poss', 8, 6), ('amod', 8, 7), ('nmod', 2, 8)]
#
#
#  ..........................................................................
#
#
# U.S. fast-food restaurant chain Chick-fil-A warns that a security breach may have leaked credit card details of 9
# Dep Parse: [('ROOT', 0, 6), ('compound', 5, 1), ('compound', 5, 2), ('compound', 5, 3), ('compound', 5, 4), ('nsubj', 6, 5), ('mark', 13, 7), ('det', 10, 8), ('compound', 10, 9), ('nsubj', 13, 10), ('aux', 13, 11), ('aux', 13, 12), ('ccomp', 6, 13), ('compound', 16, 14), ('compound', 16, 15), ('dobj', 13, 16), ('case', 18, 17), ('nmod', 16, 18)]
#
#
#  ..........................................................................
#
#
# The Palestine Authority signs a treaty to join and participate in the International Criminal Court. (Wall Street Journal)
# Dep Parse: [('ROOT', 0, 4), ('det', 4, 1), ('compound', 4, 2), ('compound', 4, 3), ('det', 6, 5), ('dep', 4, 6), ('mark', 8, 7), ('acl', 6, 8), ('cc', 8, 9), ('conj', 8, 10), ('case', 15, 11), ('det', 15, 12), ('compound', 15, 13), ('compound', 15, 14), ('nmod', 8, 15), ('punct', 4, 16), ('ROOT', 0, 4), ('punct', 4, 1), ('compound', 4, 2), ('compound', 4, 3), ('punct', 4, 5)]
#
#
#  ..........................................................................
#
#
# The Eurasian Economic Union between Russia
# Dep Parse: [('ROOT', 0, 4), ('det', 4, 1), ('amod', 4, 2), ('compound', 4, 3), ('case', 6, 5), ('nmod', 4, 6)]
#
#
#  ..........................................................................
#
#
# Vietnam’s new marriage law goes into effect
# Dep Parse: [('ROOT', 0, 6), ('nmod:poss', 5, 1), ('case', 1, 2), ('amod', 5, 3), ('compound', 5, 4), ('nsubj', 6, 5), ('case', 8, 7), ('nmod', 6, 8)]
#
#
#  ..........................................................................
#
#
# Somali al-Shabaab militants attack an army base on the outskirts of Baidoa
# Dep Parse: [('ROOT', 0, 4), ('amod', 3, 1), ('amod', 3, 2), ('nsubj', 4, 3), ('det', 7, 5), ('compound', 7, 6), ('dobj', 4, 7), ('case', 10, 8), ('det', 10, 9), ('nmod', 7, 10), ('case', 12, 11), ('nmod', 10, 12)]
#
#
#  ..........................................................................
#
#
# Boko Haram militants attack a bus in Waza
# Dep Parse: [('ROOT', 0, 4), ('compound', 3, 1), ('compound', 3, 2), ('nsubj', 4, 3), ('det', 6, 5), ('dobj', 4, 6), ('case', 8, 7), ('nmod', 4, 8)]
#
#
#  ..........................................................................
#
#
# The MS Norman Atlantic ferry fire death toll rises to at least eleven with as many as 19 people still unaccounted for. (The Independent)
# Dep Parse: [('ROOT', 0, 9), ('det', 8, 1), ('compound', 8, 2), ('compound', 8, 3), ('compound', 8, 4), ('compound', 8, 5), ('compound', 8, 6), ('compound', 8, 7), ('nsubj', 9, 8), ('case', 13, 10), ('case', 12, 11), ('advmod', 13, 12), ('nmod', 9, 13), ('case', 19, 14), ('advmod', 18, 15), ('advmod', 18, 16), ('advmod', 18, 17), ('nummod', 19, 18), ('nmod', 13, 19), ('advmod', 21, 20), ('amod', 19, 21), ('nmod', 21, 22), ('punct', 9, 23), ('ROOT', 0, 3), ('punct', 3, 1), ('det', 3, 2), ('punct', 3, 4)]
#
#
#  ..........................................................................

# %%
sentence="Boko Haram militants attack a bus in Waza"

# %%
nlp = StanfordNLP()
print (nlp.annotate(sentence))
# Out:
# {'sentences': [{'index': 0, 'parse': '(ROOT\r\n  (S\r\n    (NP (NNP Boko) (NNP Haram) (NNS militants))\r\n    (VP (VBP attack)\r\n      (NP\r\n        (NP (DT a) (NN bus))\r\n        (PP (IN in)\r\n          (NP (NNP Waza)))))))', 'basicDependencies': [{'dep': 'ROOT', 'governor': 0, 'governorGloss': 'ROOT', 'dependent': 4, 'dependentGloss': 'attack'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 1, 'dependentGloss': 'Boko'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 2, 'dependentGloss': 'Haram'}, {'dep': 'nsubj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 3, 'dependentGloss': 'militants'}, {'dep': 'det', 'governor': 6, 'governorGloss': 'bus', 'dependent': 5, 'dependentGloss': 'a'}, {'dep': 'dobj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 6, 'dependentGloss': 'bus'}, {'dep': 'case', 'governor': 8, 'governorGloss': 'Waza', 'dependent': 7, 'dependentGloss': 'in'}, {'dep': 'nmod', 'governor': 4, 'governorGloss': 'attack', 'dependent': 8, 'dependentGloss': 'Waza'}], 'enhancedDependencies': [{'dep': 'ROOT', 'governor': 0, 'governorGloss': 'ROOT', 'dependent': 4, 'dependentGloss': 'attack'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 1, 'dependentGloss': 'Boko'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 2, 'dependentGloss': 'Haram'}, {'dep': 'nsubj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 3, 'dependentGloss': 'militants'}, {'dep': 'det', 'governor': 6, 'governorGloss': 'bus', 'dependent': 5, 'dependentGloss': 'a'}, {'dep': 'dobj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 6, 'dependentGloss': 'bus'}, {'dep': 'case', 'governor': 8, 'governorGloss': 'Waza', 'dependent': 7, 'dependentGloss': 'in'}, {'dep': 'nmod:in', 'governor': 4, 'governorGloss': 'attack', 'dependent': 8, 'dependentGloss': 'Waza'}], 'enhancedPlusPlusDependencies': [{'dep': 'ROOT', 'governor': 0, 'governorGloss': 'ROOT', 'dependent': 4, 'dependentGloss': 'attack'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 1, 'dependentGloss': 'Boko'}, {'dep': 'compound', 'governor': 3, 'governorGloss': 'militants', 'dependent': 2, 'dependentGloss': 'Haram'}, {'dep': 'nsubj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 3, 'dependentGloss': 'militants'}, {'dep': 'det', 'governor': 6, 'governorGloss': 'bus', 'dependent': 5, 'dependentGloss': 'a'}, {'dep': 'dobj', 'governor': 4, 'governorGloss': 'attack', 'dependent': 6, 'dependentGloss': 'bus'}, {'dep': 'case', 'governor': 8, 'governorGloss': 'Waza', 'dependent': 7, 'dependentGloss': 'in'}, {'dep': 'nmod:in', 'governor': 4, 'governorGloss': 'attack', 'dependent': 8, 'dependentGloss': 'Waza'}], 'entitymentions': [{'docTokenBegin': 0, 'docTokenEnd': 2, 'tokenBegin': 0, 'tokenEnd': 2, 'text': 'Boko Haram', 'characterOffsetBegin': 0, 'characterOffsetEnd': 10, 'ner': 'PERSON'}, {'docTokenBegin': 7, 'docTokenEnd': 8, 'tokenBegin': 7, 'tokenEnd': 8, 'text': 'Waza', 'characterOffsetBegin': 37, 'characterOffsetEnd': 41, 'ner': 'PERSON'}], 'tokens': [{'index': 1, 'word': 'Boko', 'originalText': 'Boko', 'lemma': 'Boko', 'characterOffsetBegin': 0, 'characterOffsetEnd': 4, 'pos': 'NNP', 'ner': 'PERSON', 'speaker': 'PER0', 'before': '', 'after': ' '}, {'index': 2, 'word': 'Haram', 'originalText': 'Haram', 'lemma': 'Haram', 'characterOffsetBegin': 5, 'characterOffsetEnd': 10, 'pos': 'NNP', 'ner': 'PERSON', 'speaker': 'PER0', 'before': ' ', 'after': ' '}, {'index': 3, 'word': 'militants', 'originalText': 'militants', 'lemma': 'militant', 'characterOffsetBegin': 11, 'characterOffsetEnd': 20, 'pos': 'NNS', 'ner': 'O', 'speaker': 'PER0', 'before': ' ', 'after': ' '}, {'index': 4, 'word': 'attack', 'originalText': 'attack', 'lemma': 'attack', 'characterOffsetBegin': 21, 'characterOffsetEnd': 27, 'pos': 'VBP', 'ner': 'O', 'speaker': 'PER0', 'before': ' ', 'after': ' '}, {'index': 5, 'word': 'a', 'originalText': 'a', 'le ...

# %%
StanfordNLP()

# %%
import nltk
import re
from pycorenlp import *

nlp = StanfordCoreNLP("http://localhost:9000/")

# %%
text = 'Mark Robert is the founder of 3trucks. 3trucks was founded in 2010'

# %%
output = nlp.annotate(text, properties={
'annotators': 'tokenize,ssplit,pos,depparse,parse',
"timeout": "50000",
'outputFormat': 'json'

 })

# %%
print(output['sentences'][0]['parse'])
# Out:
# (ROOT
#   (S
#     (NP (NNP Mark) (NNP Robert))
#     (VP (VBZ is)
#       (NP
#         (NP (DT the) (NN founder))
#         (PP (IN of)
#           (NP (NNS 3trucks)))))
#     (. .)))

# %%
output = nlp.annotate(text, properties={"annotators":"tokenize,ssplit,pos,depparse,natlog,openie",
                            "outputFormat": "json",
                             "openie.triple.strict":"true",
                             "openie.max_entailments_per_clause":"1"})

# %%
result = [output["sentences"][0]["openie"] for item in output]
for i in result:
    for rel in i:
        relationSent=rel['subject'],rel['relation'],rel['object']
        print(relationSent)
# Out:
# ('Mark Robert', 'is founder of', '3trucks')

# %%
import nltk
import re
from pycorenlp import *
nlp = StanfordCoreNLP("http://localhost:9000/")
df['Entity Relation']="NULL VALUE"

# %%
for k in range(0,50):
    text = df['event_summary'][k]
    print('sentence:'+text+ '\n')
    output = nlp.annotate(text, properties={"annotators":"tokenize,ssplit,pos,depparse,natlog,openie",
                            "outputFormat": "json",
                             "openie.triple.strict":"true",
                             "openie.max_entailments_per_clause":"1"})
    result = [output["sentences"][0]["openie"] for item in output]
    for i in result:
        for rel in i:
            relationSent=rel['subject'],rel['relation'],rel['object']
            print(relationSent )
            print('\n')
            df['Entity Relation'][k]= relationSent
# Out:
# sentence:The death toll of the suicide bombing in Ibb
#
# ('suicide bombing', 'is in', 'Ibb')
#
#
# sentence:A shooting kills one and injures six people in Killarney
#
# sentence:Lithuania adopts the euro as its official currency
# c:\users\gulja\python 3.7.3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ('Lithuania', 'adopts euro as', 'its official currency')
#
#
# sentence:U.S. fast-food restaurant chain Chick-fil-A warns that a security breach may have leaked credit card details of 9
#
# ('security breach', 'leaked', 'credit card details of 9')
#
#
# sentence:The Palestine Authority signs a treaty to join and participate in the International Criminal Court. (Wall Street Journal)
#
# sentence:The Eurasian Economic Union between Russia
#
# sentence:Vietnam’s new marriage law goes into effect
#
# ('Vietnam', 'has', 'new marriage law')
#
#
# ("Vietnam 's new marriage law", 'goes into', 'effect')
#
#
# sentence:Somali al-Shabaab militants attack an army base on the outskirts of Baidoa
#
# ('Somali al-Shabaab militants', 'attack', 'army base on outskirts of Baidoa')
#
#
# sentence:Boko Haram militants attack a bus in Waza
#
# ('Boko Haram militants', 'attack bus in', 'Waza')
#
#
# sentence:The MS Norman Atlantic ferry fire death toll rises to at least eleven with as many as 19 people still unaccounted for. (The Independent)
#
# ('MS Norman Atlantic ferry fire death toll', 'rises to', 'at least eleven with as many as 19 people still unaccounted for')
#
#
# ('eleven', 'is with', 'as many as 19 people still unaccounted for')
#
#
# sentence:The United States enacts more sanctions on North Korea in response to their alleged involvement in the hacking attack on Sony. The sanctions target the North Korean Special Operation Force and 10 government officials. (Reuters)
#
# ('their alleged involvement', 'is in', 'hacking attack on Sony')
#
#
# sentence:Fleeing villagers from a remote part of the Borno State report that Boko Haram had three days prior kidnapped around 40 boys and young men. (BBC)
#
# sentence:Turkey permits the building of a Syriac church in Istanbul
#
# ('Turkey', 'permits', 'building of Syriac church in Istanbul')
#
#
# ('Syriac church', 'is in', 'Istanbul')
#
#
# sentence:The Singapore-registered cargo ship MV Höegh Osaka runs aground on Bramble Bank off the coast of the Isle of Wight
#
# sentence:The Cypriot-registered cargo ship Cemfjord sinks off the northern coast of Scotland leaving eight onboard missing. (BBC News)
#
# sentence:A U.S. drone strike kills eight Uzbek people claimed to be linked with al-Qaeda in Pakistan. (Channel 9 News)
#
# ('eight Uzbek people', 'be linked in', 'Pakistan')
#
#
# ('eight Uzbek people', 'be', 'linked with al-Qaeda in Pakistan')
#
#
# sentence:A vehicle carrying United Nations peacekeepers hits a roadside bomb in northern Mali
#
# ('vehicle', 'carrying', 'United Nations peacekeepers')
#
#
# sentence:A bombing at a local Houthi movement headquarters in Dhamar Governorate
#
# ('local Houthi movement headquarters', 'is in', 'Dhamar Governorate')
#
#
# sentence:A suicide car bomber detonates near a military convoy in Mogadishu
#
# ('military convoy', 'is in', 'Mogadishu')
#
#
# ('suicide car bomber', 'detonates near', 'military convoy in Mogadishu')
#
#
# sentence:A six-story building collapse in Nairobi
#
# ('six-story building collapse', 'is in', 'Nairobi')
#
#
# sentence:Pope Francis announces the appointment of 20 new Cardinals
#
# ('Pope Francis', 'announces', 'appointment of 20 new Cardinals')
#
#
# sentence:A Libyan warplane bombs a Greek-operated oil tanker anchored offshore the city of Derna
#
# ('Greek-operated oil tanker', 'anchored offshore', 'city of Derna')
#
#
# ('Greek-operated oil tanker', 'city of', 'Derna')
#
#
# sentence:News emerges that two days prior hundreds of Boko Haram militants had overrun several towns in northeast Nigeria and captured the military base in Baga. (Wall Street Journal)
#
# ('military base', 'is in', 'Baga')
#
#
# ('several towns', 'is in', 'northeast Nigeria')
#
#
# sentence:Bangladeshi police report that two opposition Bangladesh Nationalist Party activists are shot dead in clashes with members of the ruling Awami League in the town of Natore on the first anniversary of disputed general election. (BBC)
#
# sentence:A suicide car bomber hits the headquarters of EUPOL Afghanistan in Kabul
#
# sentence:A Czech archaeological team discovers the tomb of formerly unknown Ancient Egyptian queen Khentakawess III who lived during the Fifth Dynasty. (CNN)
#
# sentence:The site where Jesus may have been tried
#
# ('Jesus', 'may', 'where may have tried')
#
#
# ('Jesus', 'may', 'may have tried')
#
#
# sentence:China relaxes controls over the export of rare earth elements after losing a case brought by the United States at the World Trade Organization. (AP)
#
# ('China', 'losing', 'case brought by United States at World Trade Organization')
#
#
# sentence:Ireland becomes the first European nation to be allowed to export beef to the United States since the mad cow disease scare 15 years ago. (AP via Star Tribune)
#
# sentence:For the second day in a row a multi-story residential building in Nairobi
#
# ('second day', 'is in', 'row')
#
#
# ('multi-story residential building', 'is in', 'Nairobi')
#
#
# sentence:An avalanche near the Rettenbach glacier in the Austrian Alps
#
# ('Rettenbach glacier', 'is in', 'Austrian Alps')
#
#
# sentence:After being grounded in Abu Dhabi for over 12 hours with all passengers on board
#
# ('12 hours', 'is with', 'passengers on board')
#
#
# sentence:South Korea announces that it will repatriate the remains of Chinese Peoples Liberation Army soldiers killed in the Korean War. (Yonhap)
#
# ('it', 'remains of', 'Chinese Peoples Liberation Army soldiers killed in Korean War')
#
#
# ('it', 'repatriate', 'remains of Chinese Peoples Liberation Army soldiers killed in Korean War')
#
#
# sentence:Lebanon implements stricter immigration rules on its Syrian border in response to the refugee crisis caused by the Syrian Civil War. (Reuters)
#
# sentence:Taiwan's justice ministry releases former President Chen Shui-bian from jail on a one-month medical parole. (BBC)
#
# ('Taiwan', 'has', 'justice ministry')
#
#
# sentence:The anti-graft body of the Communist Party of China detains Yang Weize
#
# sentence:The Justice Department charges two American citizens of Gambian descent with violating the Neutrality Act by helping to finance and lead the 2014 Gambian coup d'état attempt. (New York Times)
#
# sentence:Clashes with ISIL in Anbar province kill twenty-three Iraqi Army soldiers and allied Sunni fighters. (AP via The Hindu)
#
# ('Clashes', 'allied', 'Sunni fighters')
#
#
# ('ISIL', 'is in', 'Anbar province')
#
#
# ('Clashes', 'is with', 'ISIL in Anbar province')
#
#
# sentence:A suicide bomber kills herself and a policeman in an attack on a police station in a popular tourist district in the Turkish city of Istanbul. (New York Times)
#
# ('popular tourist district', 'is in', 'Turkish city of Istanbul')
#
#
# ('police station', 'is in', 'popular tourist district')
#
#
# sentence:Officials in the American state of Massachusetts open a time capsule left behind by founding fathers Paul Revere and Samuel Adams. (Reuters via Yahoo! News)
#
# ('Officials', 'is in', 'American state of Massachusetts')
#
#
# sentence:American luxury fashion company Coach
#
# sentence:The price of crude oil drops to $48 per barrel
#
# sentence:A military truck collides with a bus carrying members of the National Guard of Ukraine in Ukraine
#
# sentence:Two commuter trains collide at Mesquita
#
# ('Two commuter trains', 'collide at', 'Mesquita')
#
#
# sentence:Scientists at Oxford University begin a new Ebola vaccine trial on 72 healthy volunteers. (BBC)
#
# sentence:43 US states report an epidemic of influenza
#
# ('43 US states', 'report', 'epidemic of influenza')
#
#
# sentence:Cuba starts releasing political prisoners as part of an historic agreement with the United States announced last month. (The Guardian)
#
# ('historic agreement', 'is with', 'United States')
#
#
# sentence:Thai police arrest Gurmeet Singh convicted of involvement in a bombing in Chandigarh that killed 18 people in 1996
#
# ('bombing', 'is in', 'Chandigarh')
#
#
# ('involvement', 'is in', 'bombing')
#
#
# sentence:Various California state district attorneys fine Safeway a total of $10 million for the illegal dumping of electronics and pharmaceuticals into landfills. (KPIX)
#
# sentence:A man claiming to be the Lord's Resistance Army top commander Ugandan Dominic Ongwen turns himself in to United States forces in the Central African Republic. (AP)
#
# ('Lord', 'has', 'Resistance Army top commander Ugandan Dominic Ongwen')

# %%
df['Entity Relation']
# Out:
# 0                           (suicide bombing, is in, Ibb)
# 1                                              NULL VALUE
# 2       (Lithuania, adopts euro as, its official curre...
# 3       (security breach, leaked, credit card details ...
# 4                                              NULL VALUE
# 5                                              NULL VALUE
# 6        (Vietnam 's new marriage law, goes into, effect)
# 7       (Somali al-Shabaab militants, attack, army bas...
# 8             (Boko Haram militants, attack bus in, Waza)
# 9       (eleven, is with, as many as 19 people still u...
# 10      (their alleged involvement, is in, hacking att...
# 11                                             NULL VALUE
# 12                       (Syriac church, is in, Istanbul)
# 13                                             NULL VALUE
# 14                                             NULL VALUE
# 15      (eight Uzbek people, be, linked with al-Qaeda ...
# 16       (vehicle, carrying, United Nations peacekeepers)
# 17      (local Houthi movement headquarters, is in, Dh...
# 18      (suicide car bomber, detonates near, military ...
# 19          (six-story building collapse, is in, Nairobi)
# 20      (Pope Francis, announces, appointment of 20 ne...
# 21            (Greek-operated oil tanker, city of, Derna)
# 22              (several towns, is in, northeast Nigeria)
# 23                                             NULL VALUE
# 24                                             NULL VALUE
# 25                                             NULL VALUE
# 26                           (Jesus, may, may have tried)
# 27      (China, losing, case brought by United States ...
# 28                                             NULL VALUE
# 29      (multi-story residential building, is in, Nair...
#                               ...
# 9457                                           NULL VALUE
# 9458                                           NULL VALUE
# 9459                                           NULL VALUE
# 9460                                           NULL VALUE
# 9461                                           NULL VALUE
# 9462                                           NULL VALUE
# 9463                                           NULL VALUE
# 9464                                           NULL VALUE
# 9465                                           NULL VALUE
# 9466                                           NULL VALUE
# 9467                                           NULL VALUE
# 9468                                           NULL VALUE
# 9469                                           NULL VALUE
# 9470                                           NULL VALUE
# 9471                                           NULL VALUE
# 9472                                           NULL VALUE
# 9473                                           NULL VALUE
# 9474                                           NULL VALUE
# 9475                                           NULL VALUE
# 9476                                           NULL VALUE
# 9477                                           NULL VALUE
# 9478                                           NULL VALUE
# 9479                                           NULL VALUE
# 9480                                           NULL VALUE
# 9481                                           NULL VALUE
# 9482                                           NULL VALUE
# 9483                                           NULL VALUE
# 9484                                           NULL VALUE
# 9485                                           NULL VALUE
# 9486                                           NULL VALUE
# Name: Entity Relation, Length: 9487, dtype: object
