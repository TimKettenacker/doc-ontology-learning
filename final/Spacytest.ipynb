# %% [markdown]
# ## Features
# Non-destructive tokenization <br>
# Named entity recognition <br>
# Support for 49+ languages <br>
# 16 statistical models for 9 languages <br>
# Pre-trained word vectors <br>
# State-of-the-art speed <br>
# Easy deep learning integration <br>
# Part-of-speech tagging <br>
# Labelled dependency parsing <br>
# Syntax-driven sentence segmentation <br>
# Built in visualizers for syntax and NER <br>
# Convenient string-to-hash mapping <br>
# Export to numpy data arrays <br>
# Efficient binary serialization <br>
# Easy model packaging and deployment <br>
# Robust, rigorously evaluated accuracy <br>

# %%
# %load_ext autoreload
# %autoreload 2
#Reload all modules (except those excluded by %aimport) automatically now.

# %%
import pandas as pd
import spacy
from spacy.displacy.render import EntityRenderer
from IPython.core.display import display, HTML

# %%
def custom_render(doc, df, column, options={}, page=False, minify=False, idx=0):
    """Overload the spaCy built-in rendering to allow custom part-of-speech (POS) tags.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    column -- the name of of a column of interest in the dataframe
    options -- various options to feed into the spaCy renderer, including colors
    page -- rendering markup as full HTML page (default False)
    minify -- for compact HTML (default False)
    idx -- index for specific query or doc in dataframe (default 0)
    
    """
    renderer, converter = EntityRenderer, parse_custom_ents
    renderer = renderer(options=options)
    parsed = [converter(doc, df=df, idx=idx, column=column)]
    html = renderer.render(parsed, page=page, minify=minify).strip()  
    return display(HTML(html))

def parse_custom_ents(doc, df, idx, column):
    """Parse custom entity types that aren't in the original spaCy module.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    idx -- index for specific query or doc in dataframe
    column -- the name of of a column of interest in the dataframe
    
    """
    if column in df.columns:
        entities = df[column][idx]
        ents = [{'start': ent[1], 'end': ent[2], 'label': ent[3]} 
                for ent in entities]
    else:
        ents = [{'start': ent.start_char, 'end': ent.end_char, 'label': ent.label_}
            for ent in doc.ents]
    return {'text': doc.text, 'ents': ents, 'title': None}

def render_entities(idx, df, options={}, column='named_ents'):
    """A wrapper function to get text from a dataframe and render it visually in jupyter notebooks
    
    Keyword arguments:
    idx -- index for specific query or doc in dataframe (default 0)
    df -- a pandas dataframe object
    options -- various options to feed into the spaCy renderer, including colors
    column -- the name of of a column of interest in the dataframe (default 'named_ents')
    
    """
    text = df['event_summary'][idx]
    custom_render(nlp(text), df=df, column=column, options=options, idx=idx)

# %%
options = {
    'colors': {'COMPOUND': '#FE6BFE', 'PROPN': '#18CFE6', 'NOUN': '#18CFE6', 'NP': '#1EECA6', 'ENTITY': '#FF8800'}
}

# %%
pd.set_option('display.max_rows', 10) # edit how jupyter will render our pandas dataframes
pd.options.mode.chained_assignment = None # prevent warning about working on a copy of a dataframe

# %%
import csv
import sys, os, json, re, time
import subprocess

# %%
#file = './nips-2015-papers/Papers.csv'
#file = '/uci-news-aggregator.csv'
df = pd.read_csv('newsdataset1.csv')
df.event_summary=df.event_summary.astype(str)

# %%
df.describe()
# Out:
#                 _id                        date                     category  \
# count         12817                       12701                        12636
# unique        12814                        1869                          853
# top     Jeff Weaver  2016-04-22T00:00:00.000Z""  Armed conflicts and attacks
# freq              2                          32                         2309
#
#        event_title event_summary entities person external_link Unnamed: 8  \
# count        12601         12817    12299  12042         11786      11181
# unique        3259         11220    10017   9611          8658       7958
# top          FALSE      _2016"]"    FALSE  FALSE         FALSE      FALSE
# freq          5216           311      123    572          1452       1879
#
#        Unnamed: 9  ...    Unnamed: 49    Unnamed: 50  \
# count        9783  ...              2              2
# unique       6994  ...              2              2
# top         FALSE  ...  /wiki/Holland  /wiki/Belgium
# freq         1798  ...              1              1
#
#                                               Unnamed: 51  \
# count                                                   2
# unique                                                  2
# top     http://www.msn.com/en-us/news/politics/media-s...
# freq                                                    1
#
#                      Unnamed: 52   Unnamed: 53     Unnamed: 54 Unnamed: 55  \
# count                          1             1               1           1
# unique                         1             1               1           1
# top     /wiki/State_of_Palestine  /wiki/Turkey  /wiki/Greece]"       False
# freq                           1             1               1           1
#
#                                               Unnamed: 56  \
# count                                                   1
# unique                                                  1
# top     [https://www.independent.co.uk/news/world/euro...
# freq                                                    1
#
#                                               Unnamed: 57  \
# count                                                   1
# unique                                                  1
# top     http://www.euronews.com/2016/03/20/at-least-14...
# freq                                                    1
#
#                                               Unnamed: 58
# count                                                   1
# unique                                                  1
# top     https://www.bloomberg.com/news/articles/2016-0...
# freq                                                    1
#
# [4 rows x 59 columns]

# %%
display(df)
# Out:
#                                         _id                        date  \
# 0      ObjectId("5d056c5bb5f3a01b25e85fd2")  2015-01-01T00:00:00.000Z""
# 1      ObjectId("5d056c5bb5f3a01b25e85fd3")  2015-01-01T00:00:00.000Z""
# 2      ObjectId("5d056c5bb5f3a01b25e85fd4")  2015-01-01T00:00:00.000Z""
# 3      ObjectId("5d056c5bb5f3a01b25e85fd5")  2015-01-01T00:00:00.000Z""
# 4      ObjectId("5d056c5bb5f3a01b25e85fd6")  2015-01-01T00:00:00.000Z""
# ...                                     ...                         ...
# 12812  ObjectId("5d056c7ab5f3a01b25e88dd1")  2017-09-30T00:00:00.000Z""
# 12813  ObjectId("5d056c7ab5f3a01b25e88dd2")  2017-09-30T00:00:00.000Z""
# 12814  ObjectId("5d056c7ab5f3a01b25e88dd3")  2017-09-30T00:00:00.000Z""
# 12815  ObjectId("5d056c7ab5f3a01b25e88dd4")  2017-09-30T00:00:00.000Z""
# 12816  ObjectId("5d056c7ab5f3a01b25e88dd5")  2017-09-30T00:00:00.000Z""
#
#                           category  \
# 0      Armed conflicts and attacks
# 1      Armed conflicts and attacks
# 2             Business and economy
# 3             Business and economy
# 4          International relations
# ...                            ...
# 12812      Disasters and accidents
# 12813      International relations
# 12814       Politics and elections
# 12815       Politics and elections
# 12816                       Sports
#
#                                          event_title  \
# 0                       [/wiki/Terrorism_in_Yemen"]"
# 1                                              FALSE
# 2                                              FALSE
# 3                                              FALSE
# 4                                              FALSE
# ...                                              ...
# 12812                       [/wiki/Human_stampede"]"
# 12813          [/wiki/Foreign_relations_of_Thailand"
# 12814  [/wiki/Abortion_in_the_Republic_of_Ireland"]"
# 12815                     [/wiki/Nazism_in_Sweden"]"
# 12816                 [/wiki/2017_AFL_Grand_Final"]"
#
#                                            event_summary  \
# 0           The death toll of the suicide bombing in Ibb
# 1      A shooting kills one and injures six people in...
# 2      Lithuania adopts the euro as its official curr...
# 3      U.S. fast-food restaurant chain Chick-fil-A wa...
# 4      The Palestine Authority signs a treaty to join...
# ...                                                  ...
# 12812  A crowd surge collapses a barrier during a soc...
# 12813  /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814  Tens of thousands of protesters march through ...
# 12815  About 600 members of the Swedish neo-Nazi grou...
# 12816  The Australian rules football club Richmond Fo...
#
#                                                 entities  \
# 0                                                  Yemen
# 1                                                Calgary
# 2        becoming the 19th member of the Eurozone. (CNN)
# 3             000 customers in five states. (Daily Mail)
# 4                                  [Palestine Authority"
# ...                                                  ...
# 12812                                             France
# 12813  Thailand's Ministry of Foreign Affairs says it...
# 12814   and anti-abortion activists stage counter-dem...
# 12815                                             and 10
# 12816                                    (ABC Australia)
#
#                                                   person  \
# 0       that occurred on December 31 rises to 49 with...
# 1                                                 Canada
# 2                               [Lithuania and the euro"
# 3                                        [Chick-fil-A"]"
# 4                         International Criminal Court]"
# ...                                                  ...
# 12812                        injuring twenty-nine people
# 12813                                   [/wiki/Thailand"
# 12814                                     [/wiki/Dublin"
# 12815  000 people hold a counter-demonstration. More ...
# 12816                  [/wiki/Australian_rules_football"
#
#                                           external_link  \
# 0                              [/wiki/2014_Ibb_bombing"
# 1        with police making no arrests. (National Post)
# 2                                            Eurozone]"
# 3                                                 FALSE
# 4                                                 FALSE
# ...                                                 ...
# 12812   five of them seriously. (AFP via Yahoo! Sports)
# 12813      /wiki/Ministry_of_Foreign_Affairs_(Thailand)
# 12814                                  /wiki/Pro-choice
# 12815                                    [/wiki/Sweden"
# 12816                      /wiki/Richmond_Football_Club
#
#                                               Unnamed: 8  \
# 0                                              /wiki/Ibb
# 1                                             [Killarney
# 2                                                  FALSE
# 3      [http://www.dailymail.co.uk/news/article-28936...
# 4      [https://www.wsj.com/articles/abbas-oks-palest...
# ...                                                  ...
# 12812                                     [/wiki/Soccer"
# 12813                                /wiki/Rakhine_State
# 12814                    /wiki/Irish_embassy_in_London]"
# 12815                                     /wiki/Neo-Nazi
# 12816                       /wiki/Adelaide_Football_Club
#
#                                               Unnamed: 9  ... Unnamed: 49  \
# 0                                          /wiki/Yemen]"  ...         NaN
# 1                                             Calgary"]"  ...         NaN
# 2      [http://money.cnn.com/2014/12/31/news/economy/...  ...         NaN
# 3                                                    NaN  ...         NaN
# 4                                                    NaN  ...         NaN
# ...                                                  ...  ...         ...
# 12812                          /wiki/Stade_de_la_Licorne  ...         NaN
# 12813                                      /wiki/Myanmar  ...         NaN
# 12814                                              FALSE  ...         NaN
# 12815                   /wiki/Nordic_Resistance_Movement  ...         NaN
# 12816                              /wiki/AFL_Grand_Final  ...         NaN
#
#       Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 12812         NaN         NaN         NaN         NaN         NaN         NaN
# 12813         NaN         NaN         NaN         NaN         NaN         NaN
# 12814         NaN         NaN         NaN         NaN         NaN         NaN
# 12815         NaN         NaN         NaN         NaN         NaN         NaN
# 12816         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 56 Unnamed: 57 Unnamed: 58
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# ...           ...         ...         ...
# 12812         NaN         NaN         NaN
# 12813         NaN         NaN         NaN
# 12814         NaN         NaN         NaN
# 12815         NaN         NaN         NaN
# 12816         NaN         NaN         NaN
#
# [12817 rows x 59 columns]

# %%
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#                                        _id                        date  \
# 6014  ObjectId("5d056c69b5f3a01b25e87549")  2016-03-20T00:00:00.000Z""
#
#                      category                  event_title  \
# 6014  Disasters and accidents  [/wiki/Erasmus_bus_crash"]"
#
#                                           event_summary  \
# 6014  Thirteen are killed and 34 others injured afte...
#
#                      entities  \
# 6014   crashes near Freginals
#
#                                                  person  \
# 6014   Spain. The regional government of Catalonia s...
#
#                            external_link  \
# 6014   "... according to the latest data
#
#                                         Unnamed: 8 Unnamed: 9  ...  \
# 6014   the ill-fated bus had students from Hungary    Germany  ...
#
#         Unnamed: 49    Unnamed: 50   Unnamed: 51               Unnamed: 52  \
# 6014  /wiki/Holland  /wiki/Belgium  /wiki/France  /wiki/State_of_Palestine
#
#        Unnamed: 53     Unnamed: 54 Unnamed: 55  \
# 6014  /wiki/Turkey  /wiki/Greece]"       False
#
#                                             Unnamed: 56  \
# 6014  [https://www.independent.co.uk/news/world/euro...
#
#                                             Unnamed: 57  \
# 6014  http://www.euronews.com/2016/03/20/at-least-14...
#
#                                             Unnamed: 58
# 6014  https://www.bloomberg.com/news/articles/2016-0...
#
# [1 rows x 59 columns]

# %%
# mini_df = df[:10]
# mini_df.index = pd.RangeIndex(len(mini_df.index))

# # comment this out to run on full dataset
# df = mini_df

# %%
display(df)
# Out:
#                                         _id                        date  \
# 0      ObjectId("5d056c5bb5f3a01b25e85fd2")  2015-01-01T00:00:00.000Z""
# 1      ObjectId("5d056c5bb5f3a01b25e85fd3")  2015-01-01T00:00:00.000Z""
# 2      ObjectId("5d056c5bb5f3a01b25e85fd4")  2015-01-01T00:00:00.000Z""
# 3      ObjectId("5d056c5bb5f3a01b25e85fd5")  2015-01-01T00:00:00.000Z""
# 4      ObjectId("5d056c5bb5f3a01b25e85fd6")  2015-01-01T00:00:00.000Z""
# ...                                     ...                         ...
# 12812  ObjectId("5d056c7ab5f3a01b25e88dd1")  2017-09-30T00:00:00.000Z""
# 12813  ObjectId("5d056c7ab5f3a01b25e88dd2")  2017-09-30T00:00:00.000Z""
# 12814  ObjectId("5d056c7ab5f3a01b25e88dd3")  2017-09-30T00:00:00.000Z""
# 12815  ObjectId("5d056c7ab5f3a01b25e88dd4")  2017-09-30T00:00:00.000Z""
# 12816  ObjectId("5d056c7ab5f3a01b25e88dd5")  2017-09-30T00:00:00.000Z""
#
#                           category  \
# 0      Armed conflicts and attacks
# 1      Armed conflicts and attacks
# 2             Business and economy
# 3             Business and economy
# 4          International relations
# ...                            ...
# 12812      Disasters and accidents
# 12813      International relations
# 12814       Politics and elections
# 12815       Politics and elections
# 12816                       Sports
#
#                                          event_title  \
# 0                       [/wiki/Terrorism_in_Yemen"]"
# 1                                              FALSE
# 2                                              FALSE
# 3                                              FALSE
# 4                                              FALSE
# ...                                              ...
# 12812                       [/wiki/Human_stampede"]"
# 12813          [/wiki/Foreign_relations_of_Thailand"
# 12814  [/wiki/Abortion_in_the_Republic_of_Ireland"]"
# 12815                     [/wiki/Nazism_in_Sweden"]"
# 12816                 [/wiki/2017_AFL_Grand_Final"]"
#
#                                            event_summary  \
# 0           The death toll of the suicide bombing in Ibb
# 1      A shooting kills one and injures six people in...
# 2      Lithuania adopts the euro as its official curr...
# 3      U.S. fast-food restaurant chain Chick-fil-A wa...
# 4      The Palestine Authority signs a treaty to join...
# ...                                                  ...
# 12812  A crowd surge collapses a barrier during a soc...
# 12813  /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814  Tens of thousands of protesters march through ...
# 12815  About 600 members of the Swedish neo-Nazi grou...
# 12816  The Australian rules football club Richmond Fo...
#
#                                                 entities  \
# 0                                                  Yemen
# 1                                                Calgary
# 2        becoming the 19th member of the Eurozone. (CNN)
# 3             000 customers in five states. (Daily Mail)
# 4                                  [Palestine Authority"
# ...                                                  ...
# 12812                                             France
# 12813  Thailand's Ministry of Foreign Affairs says it...
# 12814   and anti-abortion activists stage counter-dem...
# 12815                                             and 10
# 12816                                    (ABC Australia)
#
#                                                   person  \
# 0       that occurred on December 31 rises to 49 with...
# 1                                                 Canada
# 2                               [Lithuania and the euro"
# 3                                        [Chick-fil-A"]"
# 4                         International Criminal Court]"
# ...                                                  ...
# 12812                        injuring twenty-nine people
# 12813                                   [/wiki/Thailand"
# 12814                                     [/wiki/Dublin"
# 12815  000 people hold a counter-demonstration. More ...
# 12816                  [/wiki/Australian_rules_football"
#
#                                           external_link  \
# 0                              [/wiki/2014_Ibb_bombing"
# 1        with police making no arrests. (National Post)
# 2                                            Eurozone]"
# 3                                                 FALSE
# 4                                                 FALSE
# ...                                                 ...
# 12812   five of them seriously. (AFP via Yahoo! Sports)
# 12813      /wiki/Ministry_of_Foreign_Affairs_(Thailand)
# 12814                                  /wiki/Pro-choice
# 12815                                    [/wiki/Sweden"
# 12816                      /wiki/Richmond_Football_Club
#
#                                               Unnamed: 8  \
# 0                                              /wiki/Ibb
# 1                                             [Killarney
# 2                                                  FALSE
# 3      [http://www.dailymail.co.uk/news/article-28936...
# 4      [https://www.wsj.com/articles/abbas-oks-palest...
# ...                                                  ...
# 12812                                     [/wiki/Soccer"
# 12813                                /wiki/Rakhine_State
# 12814                    /wiki/Irish_embassy_in_London]"
# 12815                                     /wiki/Neo-Nazi
# 12816                       /wiki/Adelaide_Football_Club
#
#                                               Unnamed: 9  ... Unnamed: 49  \
# 0                                          /wiki/Yemen]"  ...         NaN
# 1                                             Calgary"]"  ...         NaN
# 2      [http://money.cnn.com/2014/12/31/news/economy/...  ...         NaN
# 3                                                    NaN  ...         NaN
# 4                                                    NaN  ...         NaN
# ...                                                  ...  ...         ...
# 12812                          /wiki/Stade_de_la_Licorne  ...         NaN
# 12813                                      /wiki/Myanmar  ...         NaN
# 12814                                              FALSE  ...         NaN
# 12815                   /wiki/Nordic_Resistance_Movement  ...         NaN
# 12816                              /wiki/AFL_Grand_Final  ...         NaN
#
#       Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 12812         NaN         NaN         NaN         NaN         NaN         NaN
# 12813         NaN         NaN         NaN         NaN         NaN         NaN
# 12814         NaN         NaN         NaN         NaN         NaN         NaN
# 12815         NaN         NaN         NaN         NaN         NaN         NaN
# 12816         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 56 Unnamed: 57 Unnamed: 58
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# ...           ...         ...         ...
# 12812         NaN         NaN         NaN
# 12813         NaN         NaN         NaN
# 12814         NaN         NaN         NaN
# 12815         NaN         NaN         NaN
# 12816         NaN         NaN         NaN
#
# [12817 rows x 59 columns]

# %%
lower = lambda x: x.lower() # make everything lowercase

# %%
df = pd.DataFrame(df['event_summary'].apply(lower))
df.columns = ['event_summary']
display(df)
# Out:
#                                            event_summary
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
# [12817 rows x 1 columns]

# %%
 import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def extract_named_ents(text):
    """Extract named entities, and beginning, middle and end idx using spaCy's out-of-the-box model. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in nlp(text).ents]

def add_named_ents(df):
    """Create new column in data frame with named entity tuple extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_ents'] = df['event_summary'].apply(extract_named_ents)

# %%
add_named_ents(df)

# %%
df['event_summary'].count()
# Out:
# 12817

# %%
df
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
# [12817 rows x 2 columns]

# %%
column = 'named_ents'
render_entities(9, df, options=options, column=column) # take a look at one of the abstracts
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">boko haram militants attack a bus in waza</div>

# %%
def extract_nouns(text):
    """Extract a few types of nouns, and beginning, middle and end idx using spaCy's POS (part of speech) tagger. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    keep_pos = ['PROPN', 'NOUN']
    return [(tok.text, tok.idx, tok.idx+len(tok.text), tok.pos_) for tok in nlp(text) if tok.pos_ in keep_pos]

def add_nouns(df):
    """Create new column in data frame with nouns extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['nouns'] = df['event_summary'].apply(extract_nouns)

# %%
add_nouns(df)
display(df)
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents  \
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
#                                                    nouns
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens, 0, 4, NOUN), (thousands, 8, 17, NOUN),...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
# [12817 rows x 3 columns]

# %%
column = 'nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
def extract_named_nouns(row_series):
    """Combine nouns and non-numerical entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    ents = set()
    idxs = set()
    # remove duplicates and merge two lists together
    for noun_tuple in row_series['nouns']:
        for named_ents_tuple in row_series['named_ents']:
            if noun_tuple[1] == named_ents_tuple[1]: 
                idxs.add(noun_tuple[1])
                ents.add(named_ents_tuple)
        if noun_tuple[1] not in idxs:
            ents.add(noun_tuple)
    
    return sorted(list(ents), key=lambda x: x[1])

def add_named_nouns(df):
    """Create new column in data frame with nouns and named ents.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_nouns'] = df.apply(extract_named_nouns, axis=1)

# %%
add_named_nouns(df)
display(df)
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents  \
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
#                                                    nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens, 0, 4, NOUN), (thousands, 8, 17, NOUN),...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                              named_nouns
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens of thousands, 0, 17, CARDINAL), (thousa...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
# [12817 rows x 4 columns]

# %%
column = 'named_nouns'
render_entities(1, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     shooting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  kills one and injures six
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     killarney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
text = "Dr. Abraham is the primary author of this paper, and a physician in the specialty of internal medicine."

spacy.displacy.render(nlp(text), jupyter=True) # generating raw-markup using spacy's built-in renderer
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="215d20bf7e3a48f3b72150d7074802c6-0" class="displacy" width="3200" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Abraham</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">primary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">author</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">paper,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">physician</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">specialty</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">internal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">medicine.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f3b72150d7074802c6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f3b72150d7074802c6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-2" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f3b72150d7074802c6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-3" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f3b72150d7074802c6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-4" stroke-width="2px" d="M420,439.5 C420,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f3b72150d7074802c6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,441.5 L923.0,429.5 907.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-215d20bf7e3a48f3b72150d7074802c6-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-215d20bf7e3a48f

# %%
def extract_noun_phrases(text):
    """Combine noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(chunk.text, chunk.start_char, chunk.end_char, chunk.label_) for chunk in nlp(text).noun_chunks]

def add_noun_phrases(df):
    """Create new column in data frame with noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['noun_phrases'] = df['event_summary'].apply(extract_noun_phrases)

# %%
def visualize_noun_phrases(text):
    """Create a temporary dataframe to extract and visualize noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    df = pd.DataFrame([text]) 
    df.columns = ['event_summary']
    add_noun_phrases(df)
    column = 'noun_phrases'
    render_entities(0, df, options=options, column=column)

# %%
visualize_noun_phrases(text)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dr. Abraham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the primary author
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this paper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# , and
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     a physician
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the specialty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     internal medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .</div>

# %%
add_noun_phrases(df)
display(df)
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents  \
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
#                                                    nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens, 0, 4, NOUN), (thousands, 8, 17, NOUN),...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                              named_nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens of thousands, 0, 17, CARDINAL), (thousa...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                             noun_phrases
# 0      [(the death toll, 0, 14, NP), (the suicide bom...
# 1      [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2      [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3      [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4      [(the palestine authority, 0, 23, NP), (a trea...
# ...                                                  ...
# 12812  [(a crowd surge, 0, 13, NP), (a barrier, 24, 3...
# 12813                                [(/wiki, 0, 5, NP)]
# 12814  [(tens of thousands, 0, 17, NP), (protesters, ...
# 12815  [(about 600 members, 0, 17, NP), (the swedish ...
# 12816  [(the australian rules, 0, 20, NP), (football ...
#
# [12817 rows x 5 columns]

# %%
column = 'noun_phrases'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# </div>

# %%
def extract_compounds(text):
    """Extract compound noun phrases with beginning and end idxs. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    comp_idx = 0
    compound = []
    compound_nps = []
    tok_idx = 0
    for idx, tok in enumerate(nlp(text)):
        if tok.dep_ == 'compound':

            # capture hyphenated compounds
            children = ''.join([c.text for c in tok.children])
            if '-' in children:
                compound.append(''.join([children, tok.text]))
            else:
                compound.append(tok.text)

            # remember starting index of first child in compound or word
            try:
                tok_idx = [c for c in tok.children][0].idx
            except IndexError:
                if len(compound) == 1:
                    tok_idx = tok.idx
            comp_idx = tok.i

        # append the last word in a compound phrase
        if tok.i - comp_idx == 1:
            compound.append(tok.text)
            if len(compound) > 1: 
                compound = ' '.join(compound)
                compound_nps.append((compound, tok_idx, tok_idx+len(compound), 'COMPOUND'))

            # reset parameters
            tok_idx = 0 
            compound = []

    return compound_nps

def add_compounds(df):
    """Create new column in data frame with compound noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['compounds'] = df['event_summary'].apply(extract_compounds)

# %%
add_compounds(df)
display(df)
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents  \
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
#                                                    nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens, 0, 4, NOUN), (thousands, 8, 17, NOUN),...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                              named_nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens of thousands, 0, 17, CARDINAL), (thousa...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                             noun_phrases  \
# 0      [(the death toll, 0, 14, NP), (the suicide bom...
# 1      [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2      [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3      [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4      [(the palestine authority, 0, 23, NP), (a trea...
# ...                                                  ...
# 12812  [(a crowd surge, 0, 13, NP), (a barrier, 24, 3...
# 12813                                [(/wiki, 0, 5, NP)]
# 12814  [(tens of thousands, 0, 17, NP), (protesters, ...
# 12815  [(about 600 members, 0, 17, NP), (the swedish ...
# 12816  [(the australian rules, 0, 20, NP), (football ...
#
#                                                compounds
# 0      [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                    [(shooting kills, 2, 16, COMPOUND)]
# 2                                                     []
# 3      [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4      [(palestine authority, 4, 23, COMPOUND), (wall...
# ...                                                  ...
# 12812  [(crowd surge, 2, 13, COMPOUND), (soccer match...
# 12813                                                 []
# 12814                [(abortion laws, 85, 98, COMPOUND)]
# 12815          [(resistance movement, 48, 67, COMPOUND)]
# 12816  [(football club richmond football club, 30, 66...
#
# [12817 rows x 6 columns]

# %%
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  of the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  in ibb</div>

# %%
def extract_comp_nouns(row_series, cols=[]):
    """Combine compound noun phrases and entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    return {noun_tuple[0] for col in cols for noun_tuple in row_series[col]}

def add_comp_nouns(df, cols=[]):
    """Create new column in data frame with merged entities.
    
    Keyword arguments:
    df -- a dataframe object
    cols -- a list of column names that need to be merged
    
    """
    df['comp_nouns'] = df.apply(extract_comp_nouns, axis=1, cols=cols)

# %%
cols = ['nouns', 'compounds']
add_comp_nouns(df, cols=cols)
display(df)
# Out:
#                                            event_summary  \
# 0           the death toll of the suicide bombing in ibb
# 1      a shooting kills one and injures six people in...
# 2      lithuania adopts the euro as its official curr...
# 3      u.s. fast-food restaurant chain chick-fil-a wa...
# 4      the palestine authority signs a treaty to join...
# ...                                                  ...
# 12812  a crowd surge collapses a barrier during a soc...
# 12813  /wiki/rohingya_persecution_in_myanmar_(2016%e2...
# 12814  tens of thousands of protesters march through ...
# 12815  about 600 members of the swedish neo-nazi grou...
# 12816  the australian rules football club richmond fo...
#
#                                               named_ents  \
# 0                                                     []
# 1      [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                     []
# 3                              [(9, 112, 113, CARDINAL)]
# 4                                                     []
# ...                                                  ...
# 12812                                                 []
# 12813                                                 []
# 12814             [(tens of thousands, 0, 17, CARDINAL)]
# 12815                      [(about 600, 0, 9, CARDINAL)]
# 12816  [(2017, 100, 104, DATE), (108, 124, 127, CARDI...
#
#                                                    nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens, 0, 4, NOUN), (thousands, 8, 17, NOUN),...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                              named_nouns  \
# 0      [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1      [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2      [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3      [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4      [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ...                                                  ...
# 12812  [(crowd, 2, 7, NOUN), (surge, 8, 13, NOUN), (b...
# 12813                             [(/wiki, 0, 5, PROPN)]
# 12814  [(tens of thousands, 0, 17, CARDINAL), (thousa...
# 12815  [(members, 10, 17, NOUN), (group, 42, 47, NOUN...
# 12816  [(rules, 15, 20, NOUN), (football, 21, 29, NOU...
#
#                                             noun_phrases  \
# 0      [(the death toll, 0, 14, NP), (the suicide bom...
# 1      [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2      [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3      [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4      [(the palestine authority, 0, 23, NP), (a trea...
# ...                                                  ...
# 12812  [(a crowd surge, 0, 13, NP), (a barrier, 24, 3...
# 12813                                [(/wiki, 0, 5, NP)]
# 12814  [(tens of thousands, 0, 17, NP), (protesters, ...
# 12815  [(about 600 members, 0, 17, NP), (the swedish ...
# 12816  [(the australian rules, 0, 20, NP), (football ...
#
#                                                compounds  \
# 0      [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                    [(shooting kills, 2, 16, COMPOUND)]
# 2                                                     []
# 3      [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4      [(palestine authority, 4, 23, COMPOUND), (wall...
# ...                                                  ...
# 12812  [(crowd surge, 2, 13, COMPOUND), (soccer match...
# 12813                                                 []
# 12814                [(abortion laws, 85, 98, COMPOUND)]
# 12815          [(resistance movement, 48, 67, COMPOUND)]
# 12816  [(football club richmond football club, 30, 66...
#
#                                               comp_nouns
# 0      {ibb, bombing, toll, suicide bombing, death to...
# 1          {people, killarney, shooting kills, shooting}
# 2                            {euro, lithuania, currency}
# 3      {-chick -, breach, credit, card, details, secu...
# 4      {authority, palestine, palestine authority, jo...
# ...                                                  ...
# 12812  {surge, barrier, amiens, licorne, match, crowd...
# 12813                                            {/wiki}
# 12814  {thousands, laws, tens, abortion, protesters, ...
# 12815  {resistance movement, group, resistance, membe...
# 12816  {player, smith medal, martin, australia, abc, ...
#
# [12817 rows x 7 columns]

# %%
# take a look at all the nouns again
column = 'named_nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
# take a look at all the compound noun phrases again
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  of the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  in ibb</div>

# %%
# take a look at combined entities
df['comp_nouns'][0]
# Out:
# {'bombing', 'death', 'death toll', 'ibb', 'suicide', 'suicide bombing', 'toll'}

# %%
df.head()
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
#
#                                          named_nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
#
#                                         noun_phrases  \
# 0  [(the death toll, 0, 14, NP), (the suicide bom...
# 1  [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2  [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3  [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4  [(the palestine authority, 0, 23, NP), (a trea...
#
#                                            compounds  \
# 0  [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                [(shooting kills, 2, 16, COMPOUND)]
# 2                                                 []
# 3  [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4  [(palestine authority, 4, 23, COMPOUND), (wall...
#
#                                           comp_nouns
# 0  {ibb, bombing, toll, suicide bombing, death to...
# 1      {people, killarney, shooting kills, shooting}
# 2                        {euro, lithuania, currency}
# 3  {-chick -, breach, credit, card, details, secu...
# 4  {authority, palestine, palestine authority, jo...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12817 entries, 0 to 12816
# Data columns (total 7 columns):
# event_summary    12817 non-null object
# named_ents       12817 non-null object
# nouns            12817 non-null object
# named_nouns      12817 non-null object
# noun_phrases     12817 non-null object
# compounds        12817 non-null object
# comp_nouns       12817 non-null object
# dtypes: object(7)
# memory usage: 701.0+ KB

# %%
df.comp_nouns.value_counts()
# Out:
# {}                                                                                          1027
# {nan}                                                                                        234
# {people}                                                                                      56
# {/wiki}                                                                                       35
# {football}                                                                                    31
#                                                                                             ...
# {car, winds, pileup, people, 50-plus-car pileup, whiteout}                                     1
# {provinces, forces, targets, houthi, houthi targets, coalition forces, yemen, coalition}       1
# {lee jun -, jun, mv, lee, seok, mv sewol, sewol}                                               1
# {others, neighborhoods, baghdad, people, attacks, series}                                      1
# {arianna huffington, huffington, cnbc, huffington post, post}                                  1
# Name: comp_nouns, Length: 10762, dtype: int64

# %%
df.compounds.value_counts()
# Out:
# []                                                                                                                                               4766
# [(death toll, 4, 14, COMPOUND)]                                                                                                                    36
# [(pope francis, 0, 12, COMPOUND)]                                                                                                                  20
# [(association football, 3, 23, COMPOUND)]                                                                                                          17
# [(rugby union, 3, 14, COMPOUND)]                                                                                                                   14
#                                                                                                                                                  ...
# [(border patrol agents, 5, 25, COMPOUND)]                                                                                                           1
# [(service patrol vessel, 12, 33, COMPOUND)]                                                                                                         1
# [(death toll, 4, 14, COMPOUND), (flash flood, 44, 55, COMPOUND), (– arizona border, 72, 88, COMPOUND), (science monitor, 112, 127, COMPOUND)]       1
# [(cargo spacecraft kounotori, 14, 40, COMPOUND)]                                                                                                    1
# [(cement company, 29, 43, COMPOUND)]                                                                                                                1
# Name: compounds, Length: 7699, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
text_counts= cv.fit_transform(df['event_summary'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, df['compounds'], test_size=0.3, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-4de174bd7435> in <module>
#       3 from sklearn import metrics
#       4 # Model Generation Using Multinomial Naive Bayes
# ----> 5 clf = MultinomialNB().fit(X_train, y_train)
#       6 predicted= clf.predict(X_test)
#       7 print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
#
# c:\python 3.7.3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     590
#     591         labelbin = LabelBinarizer()
# --> 592         Y = labelbin.fit_transform(y)
#     593         self.classes_ = labelbin.classes_
#     594         if Y.shape[1] == 1:
#
# c:\python 3.7.3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     437             Shape will be [n_samples, 1] for binary problems.
#     438         """
# --> 439         return self.fit(y).transform(y)
#     440
#     441     def transform(self, y):
#
# c:\python 3.7.3\lib\site-packages\sklearn\preprocessing\label.py in fit(self, y)
#     406         self : returns an instance of self.
#     407         """
# --> 408         self.y_type_ = type_of_target(y)
#     409         if 'multioutput' in self.y_type_:
#     410             raise ValueError("Multioutput target data is not supported with "
#
# c:\python 3.7.3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     258         if (not hasattr(y[0], '__array__') and isinstance(y[0], Sequence)
#     259                 and not isinstance(y[0], str)):
# --> 260             raise ValueError('You appear to be using a legacy multi-label data'
#     261                              ' representation. Sequence of sequences are no'
#     262                              ' longer supported; use a binary array or sparse'
#
# ValueError: You appear to be using a legacy multi-label data representation. Sequence of sequences are no longer supported; use a binary array or sparse matrix instead - the MultiLabelBinarizer transformer can convert to this format.
