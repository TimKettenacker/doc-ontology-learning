# %%
from stanfordcorenlp import StanfordCoreNLP
import logging
import json
import pandas as pd
# from nltk.parse.stanford import StanfordDependencyParser
import os

from graphviz import Source
pd.set_option('display.max_colwidth', -1)

# %%
class StanfordNLP:
    def __init__(self, host='http://localhost', port=9000):
        self.nlp = StanfordCoreNLP(host, port=port,
                                   timeout=30000)  # , quiet=False, logging_level=logging.DEBUG)
        self.props = {
            'annotators': 'tokenize,ssplit,pos,lemma,ner,parse,depparse,dcoref,relation',
            'pipelineLanguage': 'en',
            'outputFormat': 'json'
        }

    def word_tokenize(self, sentence):
        return self.nlp.word_tokenize(sentence)

    def pos(self, sentence):
        return self.nlp.pos_tag(sentence)

    def ner(self, sentence):
        return self.nlp.ner(sentence)

    def parse(self, sentence):
        return self.nlp.parse(sentence)

    def dependency_parse(self, sentence):
        return self.nlp.dependency_parse(sentence)

    def annotate(self, sentence):
        return json.loads(self.nlp.annotate(sentence, properties=self.props))

    @staticmethod
    def tokens_to_dict(_tokens):
        tokens = defaultdict(dict)
        for token in _tokens:
            tokens[int(token['index'])] = {
                'word': token['word'],
                'lemma': token['lemma'],
                'pos': token['pos'],
                'ner': token['ner']
            }
        return tokens

# %%
df = pd.read_csv('newsdataset1.csv')
df.event_summary=df.event_summary.astype(str)

# %%
df['event_summary'].str.replace('(','').astype(str)
df['event_summary'].str.replace(')','').astype(str)
df['event_summary'].str.replace('[','').astype(str)
df['event_summary'].str.replace(']','').astype(str)
df['event_summary'].str.replace('"','').astype(str)
df['event_summary'].str.replace('’','').astype(str)
# Out:
# 0        A shooting takes place at a pub in Tel Aviv
# 1        About one thousand houses in Manila's Tondo district in the Philippines are set ablaze following New Year's Eve firecracker festivities that left one dead and 380 others injured. AP via CTV News
# 2        The EU-Ukraine Free Trade deal officially comes into force
# 3        The two-child policy takes effect in China
# 4        /wiki/List_of_politicians_killed_in_the_Mexican_Drug_War
#                                    ...
# 10419    Indonesian President Joko Widodo has decided to relocate the nation's capital from Jakarta
# 10420    U.S. Deputy Attorney General Rod Rosenstein  announces he will resign
# 10421    Emperor Akihito abdicates the Chrysanthemum Throne in favor of his elder son
# 10422    U.S. Attorney General William Barr has decided to recuse himself from deliberations about whether the Antitrust Division of the U.S. Justice Department ought to challenge the planned merger of T-Mobile and Sprint
# 10423    /wiki/2019_Venezuelan_presidential_crisis
# Name: event_summary, Length: 10424, dtype: object

# %%
indexes=df[df['event_summary'].map(len)  < 35].index
# print(indexes)
df=df.drop(indexes)
index2=df[df['event_summary']=='nan'].index
df=df.drop(index2)

# %%
df=df.reset_index()

# %%
from nltk.parse.corenlp import CoreNLPParser
from nltk.parse.stanford import StanfordDependencyParser
if __name__ == '__main__':
    sNLP = StanfordNLP()
    for i in range(0, 10):
        print(i)
        text = df['event_summary'][i]
#         print ("Annotate:", sNLP.annotate(text))
        print('\n\n')
        print(text)
#         print('\n\n')
#         print ("POS:", sNLP.pos(text))
#         print('\n\n')
#         print ("Tokens:", sNLP.word_tokenize(text))
        print('\n\n')
#         print ("NER:", sNLP.ner(text))
#         df['NER'][i]=sNLP.ner(text)

        print('\n\n')
        print ("Parse:", sNLP.parse(text))
        print ("Dep Parse:", sNLP.dependency_parse(text))
#         sentence=sNLP.parse(text)
#         parser = CoreNLPParser()
#         next(parser.raw_parse(text)).pretty_print()
        
#         sdp =  StanfordDependencyParser()
#         next(sdp.raw_parse(text)).pretty_print()
#         result = list(sdp.raw_parse(text))

#         dep_tree_dot_repr = [parse for parse in result][0].to_dot()
#         source = Source(dep_tree_dot_repr, filename="dep_tree", format="png")
#         source.view()

        
        print('\n\n .......................................................................... \n\n')
# Out:
# 0
#
#
#
# A shooting takes place at a pub in Tel Aviv
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT A) (NN shooting))
#     (VP (VBZ takes)
#       (NP (NN place))
#       (PP (IN at)
#         (NP
#           (NP (DT a) (NN pub))
#           (PP (IN in)
#             (NP (NNP Tel) (NNP Aviv))))))))
# Dep Parse: [('ROOT', 0, 3), ('det', 2, 1), ('nsubj', 3, 2), ('dobj', 3, 4), ('case', 7, 5), ('det', 7, 6), ('nmod', 3, 7), ('case', 10, 8), ('compound', 10, 9), ('nmod', 7, 10)]
#
#
#  ..........................................................................
#
#
# 1
#
#
#
# About one thousand houses in Manila's Tondo district in the Philippines are set ablaze following New Year's Eve firecracker festivities that left one dead and 380 others injured. AP via CTV News
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (PP (IN About)
#       (NP (CD one)))
#     (NP
#       (NP (CD thousand) (NNS houses))
#       (PP (IN in)
#         (NP
#           (NP
#             (NP (NNP Manila) (POS 's))
#             (NNP Tondo) (NN district))
#           (PP (IN in)
#             (NP (DT the) (NNPS Philippines))))))
#     (VP (VBP are)
#       (VP (VBN set)
#         (NP
#           (NP (NN ablaze))
#           (PP (VBG following)
#             (NP
#               (NP
#                 (NP (NNP New) (NNP Year) (POS 's))
#                 (NNP Eve) (NN firecracker) (NNS festivities))
#               (SBAR
#                 (WHNP (WDT that))
#                 (S
#                   (VP (VBD left)
#                     (NP (CD one))
#                     (UCP
#                       (ADJP (JJ dead))
#                       (CC and)
#                       (NP
#                         (NP (CD 380) (NNS others))
#                         (VP (VBN injured))))))))))))
#     (. .)))
# Dep Parse: [('ROOT', 0, 14), ('advmod', 3, 1), ('compound', 3, 2), ('nummod', 4, 3), ('nsubjpass', 14, 4), ('case', 9, 5), ('nmod:poss', 9, 6), ('case', 6, 7), ('compound', 9, 8), ('nmod', 4, 9), ('case', 12, 10), ('det', 12, 11), ('nmod', 9, 12), ('auxpass', 14, 13), ('dobj', 14, 15), ('case', 22, 16), ('compound', 18, 17), ('nmod:poss', 22, 18), ('case', 18, 19), ('compound', 22, 20), ('compound', 22, 21), ('nmod', 15, 22), ('nsubj', 24, 23), ('acl:relcl', 22, 24), ('nummod', 29, 25), ('amod', 29, 26), ('cc', 26, 27), ('conj', 26, 28), ('nsubj', 30, 29), ('ccomp', 24, 30), ('punct', 14, 31), ('ROOT', 0, 1), ('case', 4, 2), ('compound', 4, 3), ('nmod', 1, 4)]
#
#
#  ..........................................................................
#
#
# 2
#
#
#
# The EU-Ukraine Free Trade deal officially comes into force
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN EU-Ukraine))
#       (SBAR
#         (S
#           (NP (NNP Free) (NNP Trade))
#           (VP (VB deal)
#             (ADVP (RB officially))))))
#     (VP (VBZ comes)
#       (PP (IN into)
#         (NP (NN force))))))
# Dep Parse: [('ROOT', 0, 5), ('det', 4, 1), ('compound', 4, 2), ('compound', 4, 3), ('nsubj', 5, 4), ('advmod', 5, 6), ('dobj', 5, 7), ('case', 9, 8), ('nmod', 7, 9)]
#
#
#  ..........................................................................
#
#
# 3
#
#
#
# The two-child policy takes effect in China
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT The) (JJ two-child) (NN policy))
#     (VP (VBZ takes)
#       (NP
#         (NP (NN effect))
#         (PP (IN in)
#           (NP (NNP China)))))))
# Dep Parse: [('ROOT', 0, 4), ('det', 3, 1), ('amod', 3, 2), ('nsubj', 4, 3), ('dobj', 4, 5), ('case', 7, 6), ('nmod', 4, 7)]
#
#
#  ..........................................................................
#
#
# 4
#
#
#
# /wiki/List_of_politicians_killed_in_the_Mexican_Drug_War
#
#
#
#
#
#
# Parse: (ROOT
#   (PRN (: /)
#     (S
#       (NP
#         (NP (NN wiki/List) (NN _))
#         (PP (IN of)
#           (NP (NN _) (NNS politicians))))
#       (VP (VBP _)
#         (S
#           (VP (VBN killed)
#             (S
#               (NP
#                 (NP (NN _))
#                 (PP (IN in)
#                   (NP (NN _))))
#               (NP (DT the) (NNP _) (NNP Mexican) (NNP _) (NNP Drug) (NNP _) (NNP War)))))))))
# Dep Parse: [('ROOT', 0, 1), ('compound', 3, 2), ('root', 1, 3), ('case', 6, 4), ('compound', 6, 5), ('nmod', 3, 6), ('acl', 3, 7), ('amod', 9, 8), ('dobj', 7, 9), ('case', 11, 10), ('nmod', 9, 11), ('det', 18, 12), ('compound', 18, 13), ('compound', 18, 14), ('compound', 18, 15), ('compound', 18, 16), ('compound', 18, 17), ('dep', 9, 18)]
#
#
#  ..........................................................................
#
#
# 5
#
#
#
# /wiki/2011%E2%80%9312_Saudi_Arabian_protests
#
#
#
#
#
#
# Parse: (ROOT
#   (PRN (: /)
#     (NP
#       (NP (NN wiki/2011))
#       (: --)
#       (NP (CD 12) (CD _) (NNP Saudi) (NNP _) (NNP Arabian) (NN _) (NNS protests)))))
# Dep Parse: [('ROOT', 0, 2), ('punct', 2, 1), ('punct', 2, 3), ('compound', 5, 4), ('nummod', 10, 5), ('compound', 10, 6), ('compound', 10, 7), ('compound', 10, 8), ('compound', 10, 9), ('dep', 2, 10)]
#
#
#  ..........................................................................
#
#
# 6
#
#
#
# The Islamic State of Iraq and the Levant claims responsibility for a suicide bomb attack on a Iraqi Army base Camp Speicher
#
#
#
#
#
#
# Parse: (ROOT
#   (SINV
#     (FRAG
#       (NP
#         (NP (DT The) (JJ Islamic) (NN State))
#         (PP (IN of)
#           (NP
#             (NP (NNP Iraq))
#             (CC and)
#             (NP (DT the) (NNP Levant))))))
#     (VP (VBZ claims)
#       (NP
#         (NP (NN responsibility))
#         (PP (IN for)
#           (NP (DT a) (NN suicide) (NN bomb) (NN attack))))
#       (PP (IN on)
#         (NP (DT a) (JJ Iraqi) (NNP Army) (NN base))))
#     (NP (NNP Camp) (NNP Speicher))))
# Dep Parse: [('ROOT', 0, 9), ('det', 3, 1), ('amod', 3, 2), ('nsubj', 9, 3), ('case', 5, 4), ('nmod', 3, 5), ('cc', 5, 6), ('det', 8, 7), ('conj', 5, 8), ('dobj', 9, 10), ('case', 15, 11), ('det', 15, 12), ('compound', 15, 13), ('compound', 15, 14), ('nmod', 10, 15), ('case', 22, 16), ('det', 22, 17), ('amod', 22, 18), ('compound', 22, 19), ('compound', 22, 20), ('compound', 22, 21), ('nmod', 15, 22)]
#
#
#  ..........................................................................
#
#
# 7
#
#
#
# Fiji warns residents to prepare for the impact of severe tropical cyclone Ula. AFP via France 24
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Fiji))
#     (VP (VBZ warns)
#       (S
#         (NP (NNS residents))
#         (VP (TO to)
#           (VP (VB prepare)
#             (PP (IN for)
#               (NP
#                 (NP (DT the) (NN impact))
#                 (PP (IN of)
#                   (NP (JJ severe) (JJ tropical) (NN cyclone) (NN Ula)))))))))
#     (. .)))
# Dep Parse: [('ROOT', 0, 2), ('nsubj', 2, 1), ('dobj', 2, 3), ('mark', 5, 4), ('xcomp', 2, 5), ('case', 8, 6), ('det', 8, 7), ('nmod', 5, 8), ('case', 13, 9), ('amod', 13, 10), ('amod', 13, 11), ('compound', 13, 12), ('nmod', 8, 13), ('punct', 2, 14), ('ROOT', 0, 1), ('case', 3, 2), ('nmod', 1, 3), ('nummod', 3, 4)]
#
#
#  ..........................................................................
#
#
# 8
#
#
#
# The United Kingdom designates Ascension Island and its surrounding waters in the Atlantic Ocean as a Marine protected area. The reserve will be almost as big as the UK with just over half of the protected area completely closed to fishing. BBC
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT The) (NNP United) (NNP Kingdom))
#     (VP (VBZ designates)
#       (NP
#         (NP (NNP Ascension) (NNP Island))
#         (CC and)
#         (NP
#           (NP (PRP$ its) (JJ surrounding) (NNS waters))
#           (PP (IN in)
#             (NP (DT the) (NNP Atlantic) (NNP Ocean)))))
#       (SBAR (IN as)
#         (S
#           (NP (DT a) (NNP Marine))
#           (VP (VBD protected)
#             (NP (NN area))))))
#     (. .)))
# Dep Parse: [('ROOT', 0, 4), ('det', 3, 1), ('compound', 3, 2), ('nsubj', 4, 3), ('compound', 6, 5), ('dobj', 4, 6), ('cc', 6, 7), ('nmod:poss', 10, 8), ('amod', 10, 9), ('conj', 6, 10), ('case', 14, 11), ('det', 14, 12), ('compound', 14, 13), ('nmod', 10, 14), ('mark', 18, 15), ('det', 17, 16), ('nsubj', 18, 17), ('advcl', 4, 18), ('dobj', 18, 19), ('punct', 4, 20), ('ROOT', 0, 7), ('det', 2, 1), ('nsubj', 7, 2), ('aux', 7, 3), ('cop', 7, 4), ('advmod', 7, 5), ('advmod', 7, 6), ('case', 10, 8), ('det', 10, 9), ('nmod', 7, 10), ('mark', 20, 11), ('advmod', 14, 12), ('advmod', 14, 13), ('nsubj', 20, 14), ('case', 18, 15), ('det', 18, 16), ('amod', 18, 17), ('nmod', 14, 18), ('advmod', 20, 19), ('advcl', 7, 20), ('case', 22, 21), ('nmod', 20, 22), ('punct', 7, 23), ('ROOT', 0, 1)]
#
#
#  ..........................................................................
#
#
# 9
#
#
#
# North Korea may be preparing for an imminent thermonuclear weapon test at its Punggye-ri Nuclear Test Site
#
#
#
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP North) (NNP Korea))
#     (VP (MD may)
#       (VP (VB be)
#         (VP (VBG preparing)
#           (PP (IN for)
#             (NP
#               (NP (DT an) (JJ imminent) (JJ thermonuclear) (NN weapon) (NN test))
#               (PP (IN at)
#                 (NP (PRP$ its) (JJ Punggye-ri) (JJ Nuclear) (NN Test) (NN Site))))))))))
# Dep Parse: [('ROOT', 0, 5), ('compound', 2, 1), ('nsubj', 5, 2), ('aux', 5, 3), ('aux', 5, 4), ('case', 11, 6), ('det', 11, 7), ('amod', 11, 8), ('amod', 11, 9), ('compound', 11, 10), ('nmod', 5, 11), ('case', 17, 12), ('nmod:poss', 17, 13), ('amod', 17, 14), ('amod', 17, 15), ('compound', 17, 16), ('nmod', 11, 17)]
#
#
#  ..........................................................................

# %%
df['NER']
# Out:
# 0        [(A, O), (shooting, CAUSE_OF_DEATH), (takes, O), (place, O), (at, O), (a, O), (pub, O), (in, O), (Tel, CITY), (Aviv, CITY)]
# 1        [(About, O), (one, NUMBER), (thousand, NUMBER), (houses, O), (in, O), (Manila, CITY), ('s, O), (Tondo, LOCATION), (district, O), (in, O), (the, O), (Philippines, COUNTRY), (are, O), (set, O), (ablaze, O), (following, DATE), (New, DATE), (Year, DATE), ('s, DATE), (Eve, DATE), (firecracker, O), (festivities, O), (that, O), (left, O), (one, NUMBER), (dead, O), (and, O), (380, NUMBER), (others, O), (injured, O), (., O), (AP, ORGANIZATION), (via, O), (CTV, ORGANIZATION), (News, ORGANIZATION)]
# 2        [(The, O), (EU-Ukraine, MISC), (Free, IDEOLOGY), (Trade, IDEOLOGY), (deal, O), (officially, O), (comes, O), (into, O), (force, O)]
# 3        [(The, O), (two-child, O), (policy, O), (takes, O), (effect, O), (in, O), (China, COUNTRY)]
# 4        [(/, O), (wiki/List, O), (_, O), (of, O), (_, O), (politicians, O), (_, O), (killed, O), (_, O), (in, O), (_, O), (the, O), (_, O), (Mexican, NATIONALITY), (_, O), (Drug, O), (_, O), (War, CAUSE_OF_DEATH)]
#                                                                                                              ...
# 10419    NaN
# 10420    NaN
# 10421    NaN
# 10422    NaN
# 10423    NaN
# Name: NER, Length: 10424, dtype: object

# %%
from nltk.parse import CoreNLPParser
sNLP = StanfordNLP()
# nlp = StanfordNLP()
# result = CoreNLPParser()
for i in range(0,10):
    text = df.loc[i,'event_summary']
    df.loc[i,"NER"] = sNLP.ner(text)
# sNLP.ner(text)
# pos = []
# for word in result["sentences"][2]["tokens"]:
#     pos.append('{} ({})'.format(word["word"], word["pos"]))
    
# " ".join(pos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-028c1701505f> in <module>
#       5 for i in range(0,10):
#       6     text = df.loc[i,'event_summary']
# ----> 7     df.loc[i,"NER"] = sNLP.ner(text)
#       8 # sNLP.ner(text)
#       9 # pos = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     379                             indexer, self.obj.axes
#     380                         )
# --> 381                         self._setitem_with_indexer(new_indexer, value)
#     382
#     383                         return self.obj
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     525                     if len(labels) != value.shape[1]:
#     526                         raise ValueError(
# --> 527                             "Must have equal len keys and value "
#     528                             "when setting with an ndarray"
#     529                         )
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %%
print(result)
# Out:
# [('UK', 'COUNTRY'), ('is', 'O'), ('my', 'O'), ('favorite', 'O'), ('place', 'O')]
